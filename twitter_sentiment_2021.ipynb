# %%
import pandas as pd
x=pd.read_csv('0000000000002747_training_twitter_x_y_train.csv')

# %%
x.head(3)
# Out:
#              tweet_id airline_sentiment    airline airline_sentiment_gold  \
# 0  567900433542488064          negative  Southwest                    NaN
# 1  569989168903819264          positive  Southwest                    NaN
# 2  568089179520954368          positive     United                    NaN
#
#             name negativereason_gold  retweet_count  \
# 0  ColeyGirouard                 NaN              0
# 1  WalterFaddoul                 NaN              0
# 2      LocalKyle                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @SouthwestAir I am scheduled for the morning, ...         NaN
# 1  @SouthwestAir seeing your workers time in and ...         NaN
# 2  @united Flew ORD to Miami and back and  had gr...         NaN
#
#                tweet_created              tweet_location  \
# 0  2015-02-17 20:16:29 -0800             Washington D.C.
# 1  2015-02-23 14:36:22 -0800  Indianapolis, Indiana; USA
# 2  2015-02-18 08:46:29 -0800                    Illinois
#
#                 user_timezone
# 0      Atlantic Time (Canada)
# 1  Central Time (US & Canada)
# 2  Central Time (US & Canada)

# %%
x.drop(columns=['retweet_count','tweet_coord','negativereason_gold','airline_sentiment_gold'],axis=1)
# Out:
#                  tweet_id airline_sentiment     airline           name  \
# 0      567900433542488064          negative   Southwest  ColeyGirouard
# 1      569989168903819264          positive   Southwest  WalterFaddoul
# 2      568089179520954368          positive      United      LocalKyle
# 3      568928195581513728          negative   Southwest    amccarthy19
# 4      568594180014014464          negative      United        J_Okayy
# ...                   ...               ...         ...            ...
# 10975  569934458364813313           neutral    American  Cottopanama85
# 10976  568564006329434113          positive      United   PaulBEsteves
# 10977  569643648910028801          negative  US Airways    runfixsteve
# 10978  568864981917110272          negative  US Airways     CLChicosky
# 10979  568929299350179840          negative      United     JW_Blocker
#
#                                                     text  \
# 0      @SouthwestAir I am scheduled for the morning, ...
# 1      @SouthwestAir seeing your workers time in and ...
# 2      @united Flew ORD to Miami and back and  had gr...
# 3         @SouthwestAir @dultch97 that's horse radish 😤🐴
# 4      @united so our flight into ORD was delayed bec...
# ...                                                  ...
# 10975                            @AmericanAir followback
# 10976  @united thanks for the help. Wish the phone re...
# 10977  @usairways the. Worst. Ever. #dca #customerser...
# 10978  @nrhodes85: look! Another apology. DO NOT FLY ...
# 10979  @united you are by far the worst airline. 4 pl...
#
#                    tweet_created              tweet_location  \
# 0      2015-02-17 20:16:29 -0800             Washington D.C.
# 1      2015-02-23 14:36:22 -0800  Indianapolis, Indiana; USA
# 2      2015-02-18 08:46:29 -0800                    Illinois
# 3      2015-02-20 16:20:26 -0800                         NaN
# 4      2015-02-19 18:13:11 -0800                         NaN
# ...                          ...                         ...
# 10975  2015-02-23 10:58:58 -0800                 ohio,panama
# 10976  2015-02-19 16:13:17 -0800                    Brooklyn
# 10977  2015-02-22 15:43:24 -0800      St. Augustine, Florida
# 10978  2015-02-20 12:09:15 -0800                         NaN
# 10979  2015-02-20 16:24:49 -0800                         NaN
#
#                     user_timezone
# 0          Atlantic Time (Canada)
# 1      Central Time (US & Canada)
# 2      Central Time (US & Canada)
# 3          Atlantic Time (Canada)
# 4      Eastern Time (US & Canada)
# ...                           ...
# 10975                         NaN
# 10976  Eastern Time (US & Canada)
# 10977                         NaN
# 10978                         NaN
# 10979                         NaN
#
# [10980 rows x 8 columns]

# %%
y_train=list(x['airline_sentiment'])

# %%
x_train=list(x['text'])

# %%
# x_train

# %%
import string
from nltk.corpus import stopwords
stop=set(stopwords.words('english'))
punctuations=string.punctuation
stop.update(list(punctuations))

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
def get_simple_pos_tag(tag):
    if(tag.startswith('J')):
        return wordnet.ADJ
    elif(tag.startswith('V')):
        return wordnet.VERB
    elif(tag.startswith('N')):
        return wordnet.NOUN
    elif(tag.startswith('R')):
        return wordnet.ADJ
    else:
        return wordnet.NOUN

# %%
def clean_review(words):
    output_words=[]
    for w in words:
        if(w.lower() not in stop):
            pos=pos_tag([w])
            tag=get_simple_pos_tag(pos[0][1])
            clean_word=lemmatizer.lemmatize(w,pos=get_simple_pos_tag(tag))
            output_words.append(clean_word)
    return output_words

# %%
from nltk import pos_tag
from nltk.tokenize import word_tokenize
document=[word_tokenize(doc) for doc in x_train]

# %%
# document

# %%
document
# Out:
# [['@',
#   'SouthwestAir',
#   'I',
#   'am',
#   'scheduled',
#   'for',
#   'the',
#   'morning',
#   ',',
#   '2',
#   'days',
#   'after',
#   'the',
#   'fact',
#   ',',
#   'yes',
#   '..',
#   'not',
#   'sure',
#   'why',
#   'my',
#   'evening',
#   'flight',
#   'was',
#   'the',
#   'only',
#   'one',
#   'Cancelled',
#   'Flightled'],
#  ['@',
#   'SouthwestAir',
#   'seeing',
#   'your',
#   'workers',
#   'time',
#   'in',
#   'and',
#   'time',
#   'out',
#   'going',
#   'above',
#   'and',
#   'beyond',
#   'is',
#   'why',
#   'I',
#   'love',
#   'flying',
#   'with',
#   'you',
#   'guys',
#   '.',
#   'Thank',
#   'you',
#   '!'],
#  ['@',
#   'united',
#   'Flew',
#   'ORD',
#   'to',
#   'Miami',
#   'and',
#   'back',
#   'and',
#   'had',
#   'great',
#   'crew',
#   ',',
#   'service',
#   'on',
#   'both',
#   'legs',
#   '.',
#   'THANKS'],
#  ['@', 'SouthwestAir', '@', 'dultch97', 'that', "'s", 'horse', 'radish', '😤🐴'],
#  ['@',
#   'united',
#   'so',
#   'our',
#   'flight',
#   'into',
#   'ORD',
#   'was',
#   'delayed',
#   'because',
#   'of',
#   'Air',
#   'Force',
#   'One',
#   ',',
#   'but',
#   'the',
#   'last',
#   'flight',
#   'to',
#   'SBN',
#   'is',
#   'at',
#   '8:20',
#   ',',
#   '5',
#   'mins',
#   'from',
#   'now',
#   'we',
#   'just',
#   'landed',
#   '.'],
#  ['@',
#   'united',
#   'Why',
#   'did',
#   'you',
#   'load',
#   'us',
#   'in',
#   'this',
#   'flying',
#   'sardine',
#   'can',
#   'if',
#   'you',
#   'knew',
#   'the',
#   'pilots',
#   'were',
#   '2',
#   'hours',
#   'Late',
#   'Flight',
#   '?',
#   '?',
#   '#',
#   'incompetent',
#   'beyond',
#   'belief'],
#  ['@',
#   'JetBlue',
#   'that',
#   'is',
#   'a',
#   'stock',
#   'response',
#   '.',
#   'Delays',
#   'not',
#   'as',
#   'frustrating',
#   'as',
#   'poor',
#   'cust',
#   'serv',
#   '&',
#   'amp',
#   ';',
#   'being',
#   'told',
#   'by',
#   '3',
#   'ppl',
#   'to',
#   'wait',
#   '&',
#   'amp',
#   ';',
#   'they',
#   "'d",
#   'come',
#   'back',
#   'but',
#   'did',
#   'not',
#   '.'],
#  ['@',
#   'JetBlue',
#   'That',
#   "'d",
#   'be',
#   'nice',
#   '!',
#   'Hoping',
#   'to',
#   'rack',
#   'up',
#   'enough',
#   'miles',
#   'to',
#   'take',
#   'a',
#   'trip',
#   'to',
#   'Seattle',
#   'and',
#   'enjoy',
#   'a',
#   'perfect',
#   'latte',
#   'in',
#   'the',
#   'city',
#   'of',
#   'coffee',
#   '.'],
#  ['@',
#   'united',
#   'frankly',
#   'worse',
#   'customer',
#   'service',
#   'ever',
#   '.',
#   'Problems',
#   'will',
#   'happen',
#   ',',
#   'how',
#   'you',
#   'deal',
#   'defines',
#   'a',
#   'company',
#   '.',
#   'Never',
#   'again',
#   'United',
#   '.'],
#  ['@',
#   'SouthwestAir',
#   'yeah',
#   'haha',
#   '.',
#   'Never',
#   'been',
#   'in',
#   'one',
#   '.',
#   'It',
#   "'s",
#   'expensive',
#   '😂😂',
#   'and',
#   'we',
#   'will',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'So',
#   'much',
#   'fun',
#   '!',
#   '#',
#   'destinationdragons'],
#  ['@',
#   'SouthwestAir',
#   'MCO-',
#   '&',
#   'gt',
#   ';',
#   'DCA',
#   'flight',
#   'almost',
#   'full',
#   'of',
#   'people',
#   'screwed',
#   'by',
#   'the',
#   'MSY-DCA',
#   'Cancelled',
#   'Flightation',
#   '.',
#   '@',
#   'united',
#   'and',
#   '@',
#   'USAirways',
#   'did',
#   "n't",
#   'Cancelled',
#   'Flight',
#   '.',
#   'SWA=mistake',
#   '.'],
#  ['@',
#   'JetBlue',
#   'what',
#   "'s",
#   'the',
#   'easiest',
#   'way',
#   'to',
#   'get',
#   'a',
#   'ticket',
#   'receipt',
#   '?',
#   'Can',
#   'I',
#   'get',
#   'one',
#   'at',
#   'check',
#   'in',
#   'or',
#   'can',
#   'I',
#   'get',
#   'one',
#   'online',
#   '?',
#   'Thanks',
#   '!'],
#  ['@',
#   'USAirways',
#   '-',
#   'love',
#   'the',
#   'changes',
#   'in',
#   'the',
#   'lounge',
#   '-',
#   'cheese',
#   ',',
#   'veggies',
#   ',',
#   'olives',
#   'in',
#   'addition',
#   'to',
#   'the',
#   'crackers',
#   'and',
#   'snack',
#   'mix',
#   ','],
#  ['@',
#   'SouthwestAir',
#   'I',
#   'receive',
#   'bad',
#   'customer',
#   'service',
#   'and',
#   'ended',
#   'up',
#   'spending',
#   'several',
#   'hundred',
#   'dollars',
#   'to',
#   'accommodate',
#   'my',
#   'family',
#   'during',
#   'each',
#   'cxl',
#   'flight'],
#  ['@',
#   'USAirways',
#   'you',
#   "'re",
#   'killing',
#   'me',
#   'sche',
#   'a',
#   'flight',
#   'to',
#   'board',
#   '3',
#   'min',
#   'after',
#   'mine',
#   'arrived',
#   'with',
#   'gate',
#   'on',
#   'other',
#   'side',
#   'of',
#   'airport',
#   '#',
#   'genious'],
#  ['@',
#   'USAirways',
#   '8',
#   'weeks',
#   'to',
#   'refund',
#   'this',
#   'ticket',
#   '-',
#   '0372389047497',
#   '?',
#   '!',
#   '?',
#   '-',
#   'totally',
#   'unacceptable',
#   '.',
#   'Fix',
#   'this',
#   'or',
#   'I',
#   "'ll",
#   'put',
#   'it',
#   'on',
#   'blast',
#   'on',
#   'social',
#   'media',
#   'and',
#   'TV'],
#  ['@',
#   'AmericanAir',
#   'no',
#   'private',
#   'msg',
#   'me',
#   'and',
#   'will',
#   'provide',
#   'details',
#   '...',
#   'u',
#   'really',
#   'need',
#   'customer',
#   'svc',
#   'training',
#   'for',
#   'your',
#   'staff'],
#  ['can',
#   'you',
#   'not',
#   '?',
#   'RT',
#   '@',
#   'JetBlue',
#   'Our',
#   'fleet',
#   "'s",
#   'on',
#   'fleek',
#   '.',
#   'http',
#   ':',
#   '//t.co/413GiAL0yl'],
#  ['@',
#   'JetBlue',
#   'any',
#   'info',
#   'on',
#   'why',
#   'flight',
#   '704',
#   'from',
#   'SJU',
#   'to',
#   'JFK',
#   'is',
#   'already',
#   'delayed',
#   '2',
#   '1/2',
#   'hours',
#   '?'],
#  ['@',
#   'AmericanAir',
#   ',',
#   'I',
#   "'ve",
#   'tried',
#   'no',
#   'less',
#   'than',
#   '8',
#   'times',
#   'today',
#   'to',
#   'get',
#   'in',
#   'touch',
#   'with',
#   'your',
#   'service',
#   'desk',
#   'beginning',
#   'at',
#   '8:30',
#   'EST',
#   '.',
#   'I',
#   "'m",
#   'having',
#   'no',
#   'luck',
#   '-help',
#   '!'],
#  ['@',
#   'USAirways',
#   'new',
#   'problem',
#   '...',
#   'had',
#   'wrong',
#   'last',
#   'name',
#   'on',
#   'reservation',
#   'which',
#   'is',
#   'airways',
#   'fixed',
#   '.',
#   'New',
#   'ca',
#   "n't",
#   'get',
#   'through',
#   'TSA'],
#  ['@',
#   'SouthwestAir',
#   'Any',
#   'possible',
#   'chance',
#   'of',
#   'SWA',
#   'bringing',
#   'back',
#   'service',
#   'between',
#   'LGA-BWI',
#   '?',
#   'It',
#   'would',
#   'make',
#   'it',
#   'much',
#   'easier',
#   'to',
#   'connect',
#   'to',
#   'the',
#   'west',
#   'coast',
#   '.'],
#  ['@',
#   'USAirways',
#   '@',
#   'AmericanAir',
#   'who',
#   'runs',
#   'the',
#   'show',
#   'at',
#   'the',
#   'airport',
#   'have',
#   'a',
#   'boarding',
#   'pass',
#   'says',
#   'us',
#   'airways',
#   'and',
#   'I',
#   'have',
#   'to',
#   'wait',
#   'in',
#   'American',
#   'line',
#   '#',
#   'yousuck'],
#  ['@',
#   'united',
#   'computers',
#   'are',
#   'down',
#   'but',
#   'you',
#   'stopped',
#   'giving',
#   'updates',
#   'and',
#   'took',
#   'my',
#   'flight',
#   'info',
#   'off',
#   'the',
#   'app',
#   '.',
#   'That',
#   "'s",
#   'just',
#   'ridiculous',
#   'keep',
#   'people',
#   'updated',
#   '!'],
#  ['@', 'united', 'good', 'fly', '!', '!', '#', 'United', '#', 'businessFirst'],
#  ['@',
#   'united',
#   'I',
#   'am',
#   'flying',
#   'from',
#   'msp',
#   'to',
#   'dxb',
#   ',',
#   'my',
#   'child',
#   'will',
#   'turn',
#   '2',
#   'during',
#   'the',
#   'trip',
#   'do',
#   'I',
#   'have',
#   'to',
#   'buy',
#   'a',
#   'return',
#   'ticket',
#   'for',
#   'my',
#   'child',
#   '?'],
#  ['@',
#   'JetBlue',
#   'loves',
#   'Cancelled',
#   'Flightling',
#   'tickets',
#   'and',
#   'not',
#   'telling',
#   'their',
#   'customers',
#   '#',
#   'flyunited'],
#  ['@',
#   'united',
#   'In',
#   'ORD',
#   ',',
#   'waited',
#   '20',
#   'min',
#   'after',
#   'crew',
#   'members',
#   'left',
#   'before',
#   'gate',
#   'items',
#   'came',
#   '.',
#   'Flight',
#   'attendant',
#   'sarcastically',
#   'said',
#   'good',
#   'luck',
#   'and',
#   'walked',
#   'away',
#   '.'],
#  ['@',
#   'SouthwestAir',
#   'Jason',
#   '(',
#   '108639',
#   ')',
#   'at',
#   'Gate',
#   '#',
#   '3',
#   'in',
#   'SAN',
#   'made',
#   'my',
#   'afternoon',
#   '!',
#   '!',
#   '!',
#   '#',
#   'southwestairlines',
#   '#',
#   'stellarservice',
#   '#',
#   'thanks',
#   '!'],
#  ['@',
#   'AmericanAir',
#   'everything',
#   'for',
#   'sorted',
#   'out',
#   '.',
#   'Thanks',
#   'for',
#   'the',
#   'help',
#   '.',
#   'Excited',
#   'to',
#   'get',
#   'home',
#   'tonight',
#   '!'],
#  ['@',
#   'AmericanAir',
#   'understand',
#   'the',
#   'weather',
#   'but',
#   'would',
#   'be',
#   'nice',
#   'to',
#   'hear',
#   'an',
#   'apology',
#   'on',
#   'the',
#   'phone',
#   'when',
#   'you',
#   'moved',
#   'my',
#   'flight',
#   'to',
#   'an',
#   'inconvenient',
#   'day'],
#  ['@', 'SouthwestAir', 'and', 'thanks', '!'],
#  ['@',
#   'united',
#   'it',
#   "'s",
#   'been',
#   'booked',
#   'into',
#   'first',
#   'class',
#   'with',
#   'curbside',
#   'delivery',
#   '24',
#   'hours',
#   'from',
#   'now',
#   '.',
#   'I',
#   "'m",
#   'counting',
#   'on',
#   'it',
#   '!',
#   '#',
#   'TeamUSA'],
#  ['@',
#   'JetBlue',
#   'Oh',
#   'that',
#   'totally',
#   'looks',
#   'on',
#   'par',
#   'with',
#   '@',
#   'AmericanAir',
#   "'s",
#   'Admirals',
#   'Club',
#   ';',
#   'any',
#   'way',
#   'you',
#   'can',
#   'slide',
#   'us',
#   'a',
#   'couple',
#   'passes',
#   '?',
#   ';',
#   ')'],
#  ['@',
#   'AmericanAir',
#   'We',
#   "'ve",
#   '15',
#   'official',
#   'complaints',
#   'signed',
#   'by',
#   '#',
#   'AmericanAirlines',
#   'Lima',
#   'supervisor',
#   '.',
#   'Customer',
#   'Relations',
#   'pls',
#   'compensate',
#   '4',
#   'the',
#   '10-hour',
#   'delay'],
#  ['@',
#   'JetBlue',
#   'but',
#   'the',
#   '4',
#   'hour',
#   'policy-',
#   'when',
#   'I',
#   'called',
#   'and',
#   'they',
#   'said',
#   'I',
#   'did',
#   "n't",
#   'report',
#   'it',
#   'soon',
#   'enough',
#   '.',
#   'What',
#   'would',
#   'have',
#   'changed',
#   'if',
#   'I',
#   'had',
#   'noticed',
#   'sooner',
#   '?'],
#  ['@',
#   'united',
#   'the',
#   'most',
#   'frustrating',
#   'flying',
#   'experience',
#   '.',
#   'One',
#   'continuous',
#   '``',
#   'I',
#   'dunno',
#   'what',
#   'time',
#   'you',
#   'will',
#   'leave',
#   'today',
#   '.',
#   '``',
#   '.',
#   'Dunno',
#   '?',
#   '!',
#   'That',
#   "'s",
#   'code',
#   'for',
#   '...',
#   '?'],
#  ['@',
#   'SouthwestAir',
#   'Hi',
#   'I',
#   'just',
#   'got',
#   'a',
#   'message',
#   'that',
#   'part',
#   'of',
#   'my',
#   'flights',
#   'is',
#   'Cancelled',
#   'Flightled',
#   '.',
#   'I',
#   'ca',
#   "n't",
#   'rebook',
#   'online',
#   'and',
#   'nobody',
#   'answers',
#   'my',
#   'phone',
#   'call',
#   '.',
#   'Help',
#   'me'],
#  ['@',
#   'SouthwestAir',
#   'I',
#   'need',
#   'updates',
#   'on',
#   'my',
#   'flights',
#   '464',
#   '&',
#   'amp',
#   ';',
#   '3574',
#   '.',
#   'I',
#   'have',
#   'been',
#   'on',
#   'hold',
#   'for',
#   'over',
#   '2',
#   'hours',
#   '.'],
#  ['@',
#   'USAirways',
#   'I',
#   "'m",
#   'supposed',
#   'to',
#   'fly',
#   'through',
#   'Dallas',
#   '.',
#   'Can',
#   'you',
#   'help',
#   'me',
#   'get',
#   'a',
#   'new',
#   'itinerary',
#   '?'],
#  ['@',
#   'AmericanAir',
#   'so',
#   'you',
#   'fail',
#   'again',
#   'flight',
#   'to',
#   'rdu',
#   'sitting',
#   'waiting',
#   'on',
#   'flight',
#   'attendants',
#   '.',
#   'your',
#   'logistics',
#   'are',
#   'not',
#   'good'],
#  ['@',
#   'united',
#   'I',
#   'am',
#   'impressed',
#   'with',
#   'your',
#   'super-fast',
#   'reply',
#   'to',
#   '@',
#   'CGJase'],
#  ['@',
#   'united',
#   'no',
#   'I',
#   'do',
#   "n't",
#   '.',
#   'Spoke',
#   'with',
#   'baggage',
#   'contact',
#   'at',
#   '1-800',
#   'number',
#   '.',
#   'Said',
#   'they',
#   'will',
#   'try',
#   'to',
#   'get',
#   'bags',
#   'to',
#   'stay',
#   'at',
#   'IAD',
#   'for',
#   'pick',
#   'up',
#   'tmrw'],
#  ['@',
#   'USAirways',
#   'Who',
#   'intentionally',
#   'buys',
#   'a',
#   'flight',
#   'with',
#   'a',
#   '10',
#   'hour',
#   'layover',
#   '?',
#   'And',
#   'what',
#   'kind',
#   'of',
#   'airline',
#   'would',
#   'charge',
#   '$',
#   '200',
#   'to',
#   'fix',
#   'it',
#   '?',
#   'Wow',
#   '...',
#   '#',
#   'usairways'],
#  ['@',
#   'SouthwestAir',
#   'do',
#   'you',
#   'do',
#   'auto',
#   'callbacks',
#   'so',
#   'I',
#   'do',
#   "n't",
#   'have',
#   'to',
#   'wait',
#   'on',
#   'hold',
#   '?'],
#  ['@',
#   'united',
#   'can',
#   'I',
#   'get',
#   'your',
#   'service',
#   'desk',
#   '#',
#   'at',
#   'IAD',
#   '?'],
#  ['@',
#   'JetBlue',
#   'your',
#   'blue',
#   'helped',
#   'bring',
#   'out',
#   'the',
#   'color',
#   'of',
#   'my',
#   'eyes',
#   '.',
#   'And',
#   'I',
#   'promise',
#   'I',
#   'did',
#   "n't",
#   'eat',
#   'all',
#   'the',
#   'free',
#   'snacks',
#   '.'],
#  ['@',
#   'united',
#   'Yes',
#   '!',
#   ':',
#   'D',
#   '(',
#   'Y',
#   ')',
#   'From',
#   '@',
#   'therealaviation',
#   'on',
#   'Instagram',
#   ':',
#   ')'],
#  ['@',
#   'JetBlue',
#   'I',
#   'did',
#   'not',
#   'report',
#   'the',
#   'updated',
#   'info',
#   '-',
#   'do',
#   "n't",
#   'know',
#   'how',
#   'to',
#   'reach',
#   'them',
#   'without',
#   'a',
#   'super',
#   'long',
#   'wait',
#   'on',
#   'hold',
#   'at',
#   'your',
#   'main',
#   'number',
#   '.'],
#  ['@',
#   'JetBlue',
#   'I',
#   'want',
#   'to',
#   'enter',
#   'the',
#   'family',
#   'pooling',
#   'contest',
#   ',',
#   'it',
#   'says',
#   '``',
#   'by',
#   '2/19',
#   "''",
#   'on',
#   'the',
#   'website',
#   ',',
#   'can',
#   'I',
#   'please',
#   'enter',
#   'still',
#   '!'],
#  ['@',
#   'USAirways',
#   'and',
#   'that',
#   'you',
#   'can',
#   'choose',
#   'the',
#   'same',
#   'seat',
#   'for',
#   'free',
#   'after',
#   'clicking',
#   '100',
#   'buttons',
#   '.'],
#  ['@', 'united', 'plus', 'what', 'about', 'food', '?', 'And', 'taxis', '?'],
#  ['@',
#   'USAirways',
#   '3hr30min',
#   'right',
#   'now',
#   '...',
#   'any',
#   'end',
#   'in',
#   'sight',
#   '?'],
#  ['@',
#   'SouthwestAir',
#   ',',
#   'you',
#   "'re",
#   'really',
#   'going',
#   'to',
#   'let',
#   '@',
#   'delta',
#   'and',
#   '@',
#   'virginamerica',
#   'get',
#   'the',
#   'best',
#   'of',
#   'you',
#   '?',
#   'http',
#   ':',
#   '//t.co/vUdWJm1lYB'],
#  ['@',
#   'USAirways',
#   'claims',
#   'flight',
#   'Cancelled',
#   'Flighted',
#   'due',
#   'to',
#   'weather',
#   'at',
#   'destination',
#   'but',
#   'Delta',
#   'has',
#   'not',
#   'Cancelled',
#   'Flighted',
#   'flight',
#   'on',
#   'same',
#   'route',
#   '.'],
#  ['@',
#   'JetBlue',
#   'thanks',
#   'so',
#   'much',
#   'for',
#   'help',
#   'Us',
#   ',',
#   'u',
#   'r',
#   'amazing',
#   '!'],
#  ['@',
#   'AmericanAir',
#   'haha',
#   'I',
#   'did',
#   '.',
#   'They',
#   'said',
#   'it',
#   'was',
#   "n't",
#   'their',
#   'fault',
#   'somehow',
#   '?',
#   'You',
#   'guys',
#   'r',
#   'a',
#   'joke'],
#  ['@',
#   'AmericanAir',
#   'your',
#   'customer',
#   'service',
#   'is',
#   'inferior',
#   'to',
#   'that',
#   'of',
#   'a',
#   'nationalized',
#   'third',
#   'world',
#   'nation',
#   "'s",
#   'airline',
#   '.',
#   'Get',
#   'it',
#   'together',
#   '.'],
#  ['@',
#   'AmericanAir',
#   'Why',
#   'does',
#   'your',
#   'iPhone',
#   'app',
#   'not',
#   'have',
#   'any',
#   'sort',
#   'of',
#   'notifications',
#   'option',
#   '?'],
#  ['@', 'united', 'thank', 'you', '!'],
#  ['@',
#   'AmericanAir',
#   'I',
#   "'ve",
#   'been',
#   'trying',
#   'to',
#   'reach',
#   'your',
#   'customer',
#   'service',
#   'for',
#   'TWO',
#   'days',
#   '.',
#   'I',
#   'have',
#   'received',
#   'zero',
#   'response',
#   '.',
#   'Never',
#   'traveling',
#   'AA',
#   'again',
#   '.'],
#  ['@',
#   'united',
#   'flight',
#   '4567',
#   'agent',
#   'now',
#   'wandered',
#   'off',
#   '.',
#   'Pilots',
#   'came',
#   'out',
#   'looking',
#   'for',
#   'her',
#   '.',
#   'Went',
#   'to',
#   'charge',
#   'her',
#   'personal',
#   'phone',
#   'which',
#   'she',
#   "'d",
#   'been',
#   'txting',
#   'on'],
#  ['@',
#   'united',
#   'first',
#   'you',
#   'lost',
#   'all',
#   'my',
#   'bags',
#   ',',
#   'now',
#   'you',
#   'Cancelled',
#   'Flight',
#   'my',
#   'flight',
#   'home',
#   '.',
#   '30',
#   'min',
#   'wait',
#   'to',
#   'talk',
#   'to',
#   'somebody',
#   '#',
#   'poorservice',
#   '#',
#   'notgoodenough'],
#  ['@',
#   'SouthwestAir',
#   'sat',
#   'on',
#   'a',
#   'plane',
#   'for',
#   '2+',
#   'hrs',
#   'on',
#   '2/15',
#   '!',
#   'Then',
#   'we',
#   'finally',
#   'took',
#   'off',
#   '..',
#   ':',
#   '('],
#  ['@', 'JetBlue', 'ANYWHERE', '!', '!', 'http', ':', '//t.co/FeFHPmFPlE'],
#  ['@',
#   'USAirways',
#   'I',
#   'have',
#   'to',
#   'spend',
#   'more',
#   'than',
#   'the',
#   'cost',
#   'of',
#   'the',
#   'flight',
#   'just',
#   'to',
#   'get',
#   'a',
#   'free',
#   'room',
#   'and',
#   'transportation',
#   'to',
#   'and',
#   'from',
#   'the',
#   'airport'],
#  ['@',
#   'SouthwestAir',
#   'understand',
#   'the',
#   'weather',
#   ',',
#   'these',
#   'kids',
#   'need',
#   'to',
#   'get',
#   'home',
#   '!',
#   'Nice',
#   'kids',
#   'doing',
#   'volunteer',
#   'work',
#   'from',
#   'a',
#   'RI',
#   'high',
#   'school',
#   ',',
#   'please',
#   'help'],
#  ['@',
#   'AmericanAir',
#   'My',
#   'friend',
#   'needs',
#   'some',
#   'help',
#   'on',
#   'her',
#   'flt',
#   '(',
#   'she',
#   "'s",
#   'not',
#   'on',
#   'Twiiter',
#   ')',
#   ',',
#   'can',
#   'I',
#   'DM',
#   'you',
#   'her',
#   'info',
#   '?'],
#  ['@',
#   'AmericanAir',
#   'my',
#   'mom',
#   '’',
#   's',
#   'flight',
#   'tomorrow',
#   'Cancelled',
#   'Flighted',
#   'w/',
#   'no',
#   'notice',
#   '.',
#   'Phone',
#   'system',
#   'said',
#   'callback',
#   'in',
#   '2',
#   'hours',
#   'and',
#   'it',
#   '’',
#   's',
#   'been',
#   '4',
#   '.',
#   'I',
#   'need',
#   'to',
#   'go',
#   'to',
#   'bed',
#   '!'],
#  ['@',
#   'americanair',
#   'flight',
#   'veers',
#   'off',
#   'icy',
#   'runway',
#   'at',
#   '@',
#   'dfwairport',
#   '.',
#   'Most',
#   'DFW',
#   'flights',
#   'Cancelled',
#   'Flighted',
#   'Mon',
#   'http',
#   ':',
#   '//t.co/Q37pOWn6uv',
#   '@',
#   'Cowboycerrone',
#   'figures',
#   'right',
#   '?'],
#  ['@',
#   'united',
#   'Could',
#   'you',
#   'tell',
#   'me',
#   'if',
#   'this',
#   'bag',
#   'would',
#   'be',
#   'accepted',
#   'as',
#   'a',
#   'personal',
#   'item',
#   '?',
#   'Can',
#   'i',
#   'bring',
#   'one',
#   'carry-on',
#   'bag',
#   'plus',
#   'this',
#   '?',
#   'http',
#   ':',
#   '//t.co/U390cZpLHl'],
#  ['@',
#   'united',
#   'yo',
#   ',',
#   'you',
#   'need',
#   'a',
#   'new',
#   'website',
#   'really',
#   'badly',
#   '.',
#   'This',
#   'day',
#   'and',
#   'age',
#   '...'],
#  ['@',
#   'SouthwestAir',
#   '@',
#   'TheEllenShow',
#   '@',
#   'Imaginedragons',
#   '@',
#   'kdepetro313',
#   '.what',
#   'a',
#   'great',
#   'first',
#   'night',
#   '.',
#   '#',
#   'DestinationDragons',
#   'http',
#   ':',
#   '//t.co/N3LrFo4UaY'],
#  ['@',
#   'USAirways',
#   'right',
#   'on',
#   '.',
#   'Up',
#   '.',
#   'Up',
#   '&',
#   'amp',
#   ';',
#   'away',
#   '✈️🌞'],
#  ['@',
#   'united',
#   'Now',
#   'about',
#   'two',
#   'dozen',
#   'back',
#   'in',
#   'line',
#   'to',
#   'see',
#   'a',
#   'single',
#   'CSR',
#   'for',
#   'reFlight',
#   'Booking',
#   'Problems',
#   'final',
#   'leg',
#   '.',
#   '(',
#   'Kiosks',
#   'on',
#   'fritz',
#   '.',
#   ')'],
#  ['@',
#   'JetBlue',
#   'Why',
#   'would',
#   'you',
#   'charge',
#   'money',
#   'to',
#   'transfer',
#   'points',
#   'to',
#   'someone',
#   '?'],
#  ['@',
#   'USAirways',
#   'Is',
#   'it',
#   'possible',
#   'to',
#   'earn',
#   'Dividend',
#   'Miles',
#   'for',
#   'a',
#   'passenger',
#   'that',
#   'is',
#   'not',
#   'me',
#   ',',
#   'even',
#   'if',
#   'I',
#   'am',
#   'purchasing',
#   'the',
#   'tickets',
#   '?'],
#  ['Lmfaooo',
#   '“',
#   '@',
#   'JetBlue',
#   ':',
#   'Our',
#   'fleet',
#   "'s",
#   'on',
#   'fleek',
#   '.',
#   'http',
#   ':',
#   '//t.co/1G9RnmYUQe',
#   '”'],
#  ['@',
#   'USAirways',
#   'Is',
#   'there',
#   'a',
#   'phone',
#   'line',
#   'to',
#   'call',
#   'into',
#   'that',
#   'is',
#   "n't",
#   'being',
#   'affected',
#   'by',
#   '``',
#   'bad',
#   'weather',
#   "''",
#   '?',
#   'Trying',
#   'to',
#   'book',
#   'a',
#   'vacation',
#   ',',
#   'here',
#   '...',
#   '👀'],
#  ['@',
#   'AmericanAir',
#   'I',
#   'have',
#   'never',
#   'seen',
#   'such',
#   'incompetency',
#   'from',
#   'a',
#   'gate',
#   'agent',
#   'in',
#   'years',
#   'of',
#   'business',
#   'travel',
#   'DFW',
#   'B16',
#   'gate',
#   'agent',
#   'needs',
#   'training',
#   'or',
#   'new',
#   'job'],
#  ['@',
#   'USAirways',
#   'F623',
#   'DEN',
#   ':',
#   'PHX',
#   'impressive',
#   'lack',
#   'of',
#   'concern',
#   'by',
#   '1hr+',
#   'Late',
#   'Flight',
#   'flight',
#   'attndt',
#   'wrecking',
#   'havoc',
#   'on',
#   'customer',
#   'travel',
#   '#',
#   'smugsmirk',
#   '#',
#   'norush'],
#  ['@',
#   'united',
#   'Have',
#   'clients',
#   'with',
#   'an',
#   '11',
#   'hr',
#   'layover',
#   'at',
#   'IAH',
#   '(',
#   'during',
#   'the',
#   'day',
#   ')',
#   '.',
#   'Will',
#   'they',
#   'have',
#   'to',
#   'claim',
#   '&',
#   'amp',
#   ';',
#   'recheck',
#   'luggage',
#   '.',
#   'Or',
#   'will',
#   'it',
#   'be',
#   'taken',
#   'care',
#   'of',
#   '?'],
#  ['@',
#   'united',
#   'even',
#   'so',
#   ',',
#   'change',
#   'could',
#   'not',
#   'be',
#   'made',
#   'online-',
#   'instructed',
#   'to',
#   'call',
#   'an',
#   'agent-',
#   'maybe',
#   'the',
#   'syastem',
#   'should',
#   'allow',
#   'agents',
#   '2',
#   'link',
#   'passengers',
#   '!'],
#  ['@',
#   'united',
#   'you',
#   'ca',
#   "n't",
#   'claim',
#   '``',
#   'weather',
#   "''",
#   'with',
#   'your',
#   'hardworking',
#   'crew',
#   'pulling',
#   'seats',
#   'out',
#   'of',
#   'a',
#   'plane',
#   '!',
#   'Do',
#   'the',
#   'right',
#   'thing',
#   '.',
#   'But',
#   'we',
#   'both',
#   'know',
#   'you',
#   'wo',
#   "n't"],
#  ['@',
#   'AmericanAir',
#   'finally',
#   'called',
#   '!',
#   'Ca',
#   "n't",
#   'get',
#   'met',
#   'Seattle',
#   'so',
#   'refund',
#   'will',
#   'be',
#   'processed',
#   '.',
#   'Thanks'],
#  ['@',
#   'United',
#   'just',
#   'played',
#   'the',
#   'Most',
#   'bizarre',
#   '``',
#   'safety',
#   "''",
#   'video',
#   'I',
#   "'ve",
#   'ever',
#   'seen',
#   '...',
#   'http',
#   ':',
#   '//t.co/Hlm2Oks6xl'],
#  ['@',
#   'SouthwestAir',
#   'I',
#   "'m",
#   'not',
#   'sure',
#   'I',
#   'did',
#   'the',
#   'messaging',
#   'part',
#   'right',
#   '.',
#   'Please',
#   'let',
#   'me',
#   'know',
#   'if',
#   'you',
#   'received',
#   'it',
#   '.'],
#  ['@',
#   'SouthwestAir',
#   'booked',
#   'the',
#   '8th',
#   '....',
#   'Save',
#   'me',
#   'an',
#   'emergency',
#   'exit',
#   '...',
#   'Got',
#   'ta',
#   'stretch',
#   'out'],
#  ['@',
#   'SouthwestAir',
#   'do',
#   'you',
#   'not',
#   'try',
#   'to',
#   'get',
#   'customers',
#   'to',
#   'their',
#   'destinations',
#   '?',
#   'No',
#   'help',
#   'to',
#   'get',
#   'on',
#   'another',
#   'airline',
#   'if',
#   'you',
#   'had',
#   'no',
#   'flights',
#   'for',
#   '3',
#   'days',
#   '?'],
#  ['@',
#   'JetBlue',
#   'no',
#   '.',
#   'Did',
#   'not',
#   'catch',
#   'his',
#   'name',
#   '.',
#   'I',
#   'am',
#   'sure',
#   'Jason',
#   'will',
#   'know',
#   '.'],
#  ['@',
#   'USAirways',
#   '.',
#   'Yet',
#   'another',
#   'delay/missed',
#   'connection',
#   '....',
#   'and',
#   'your',
#   'customer',
#   'service',
#   'has',
#   'an',
#   'attitude',
#   'with',
#   'me',
#   '?',
#   'Wow',
#   '.'],
#  ['@',
#   'USAirways',
#   'No',
#   'access',
#   'to',
#   'Dividend',
#   'Miles',
#   'and',
#   'for',
#   'a',
#   'week',
#   'the',
#   'automated',
#   'phone',
#   'keeps',
#   'telling',
#   'me',
#   'to',
#   'call',
#   'back',
#   'Late',
#   'Flightr',
#   '.',
#   '#',
#   'FRUSTRATED',
#   '#',
#   'LivePersonPlease'],
#  ['@',
#   'united',
#   'When',
#   'will',
#   'direct',
#   'flights',
#   'from',
#   'Belfast',
#   'Intl',
#   'to',
#   'Newark',
#   'resume',
#   'from',
#   'their',
#   'winter',
#   'break',
#   '?',
#   'Thanks',
#   '.'],
#  ['@',
#   'united',
#   'LGJW7B',
#   '.',
#   'I',
#   'voluntarily',
#   'rerouted',
#   ';',
#   '1st',
#   'leg',
#   'of',
#   'journey',
#   'was',
#   'in',
#   'economy',
#   'and',
#   'was',
#   'supposed',
#   'to',
#   'be',
#   '8B',
#   '.',
#   'Res',
#   'agent',
#   'said',
#   'she',
#   "'d",
#   'reserve',
#   'it',
#   'for',
#   'me'],
#  ['@',
#   'SouthwestAir',
#   'Nashville',
#   'airport',
#   'has',
#   'runways',
#   'open',
#   '.',
#   'It',
#   'appears',
#   'southwest',
#   'is',
#   'only',
#   'airline',
#   'Cancelled',
#   'Flighting',
#   'flights',
#   '.',
#   'Is',
#   'this',
#   'likely',
#   'to',
#   'change',
#   '?'],
#  ['@',
#   'USAirways',
#   'no',
#   'my',
#   'flight',
#   'plans',
#   'have',
#   'been',
#   'delayed',
#   'until',
#   'tuesday',
#   'due',
#   'to',
#   'your',
#   'computer',
#   'crash'],
#  ['@',
#   'SouthwestAir',
#   'This',
#   'is',
#   'unbelievable',
#   '...',
#   'Thank',
#   'you',
#   'so',
#   'much',
#   '!',
#   '#',
#   'DestinationDragons'],
#  ['@',
#   'united',
#   'big',
#   'surprise',
#   '#',
#   'nogate',
#   'waiting',
#   'for',
#   'our',
#   'plane',
#   '.',
#   'Same',
#   'fucken',
#   'issues',
#   'everything',
#   'I',
#   'fly',
#   'you',
#   '.',
#   '#',
#   'fail',
#   '#',
#   'worstairlineever'],
#  ['@',
#   'USAirways',
#   'tough',
#   'night',
#   ',',
#   'two',
#   '90',
#   'minute',
#   'calls',
#   ',',
#   'on',
#   'hold',
#   ',',
#   'delayed',
#   'here',
#   'in',
#   'Phoenix',
#   'for',
#   'two',
#   'days',
#   'because',
#   'of',
#   'one',
#   'aircraft',
#   'not',
#   'ready',
#   '?',
#   'Not',
#   'acceptable'],
#  ['@',
#   'united',
#   'but',
#   'it',
#   "'s",
#   'hard',
#   'to',
#   'stay',
#   'upset',
#   'at',
#   'someone',
#   'when',
#   'they',
#   'at',
#   'least',
#   'TRY',
#   'to',
#   'show',
#   'remorse',
#   '.'],
#  ['@',
#   'united',
#   '50',
#   'min',
#   'on',
#   'hold',
#   'trying',
#   'to',
#   'book',
#   'award',
#   'flight',
#   'because',
#   'site',
#   'errors',
#   'out',
#   '.',
#   'Agents',
#   'ask',
#   'for',
#   'my',
#   'pin',
#   'to',
#   'see',
#   'platinum',
#   'availability',
#   '?',
#   '?',
#   '?',
#   'badbadbad'],
#  ['@',
#   'USAirways',
#   '23',
#   'min',
#   'on',
#   'hold',
#   '...',
#   'Drove',
#   '2.5',
#   'hours',
#   'to',
#   'get',
#   'my',
#   'delayed',
#   'bag',
#   '.',
#   'I',
#   'just',
#   'want',
#   'to',
#   'pick',
#   'it',
#   'up',
#   'at',
#   'SJU',
#   '.'],
#  ['@',
#   'USAirways',
#   'how',
#   'do',
#   'I',
#   'reserve',
#   'my',
#   'seat',
#   'on',
#   'the',
#   'AA',
#   'flight',
#   'I',
#   'transfer',
#   'to',
#   'from',
#   'ORD',
#   'to',
#   'EVV',
#   '?'],
#  ['@',
#   'United',
#   'to',
#   'start',
#   '3xdaily',
#   '@',
#   'EmbraerSA',
#   '#',
#   'ERJ145',
#   'flights',
#   'from',
#   '#',
#   'Chicago',
#   '@',
#   'fly2ohare',
#   'to',
#   '#',
#   'Evansville',
#   'on',
#   '4JUN',
#   '#',
#   'avgeek'],
#  ['@',
#   'united',
#   'flight',
#   '1136',
#   'from',
#   'Chicago',
#   'to',
#   'Houston',
#   'over',
#   '2',
#   'hours',
#   'and',
#   'no',
#   'pretzels',
#   'or',
#   'peanuts',
#   '?',
#   '!',
#   'Seriously',
#   'about',
#   'passed',
#   'out',
#   '.'],
#  ['@',
#   'united',
#   'I',
#   'left',
#   'my',
#   'comment',
#   'with',
#   'customer',
#   'care',
#   '.',
#   'Thanks',
#   'for',
#   'contacting',
#   'me',
#   '.'],
#  ['@', 'united', 'They', 'held', 'the', 'plane', '!', 'Made', 'it', '!', '!'],
#  ['@',
#   'AmericanAir',
#   'That',
#   "'s",
#   'ok',
#   '...',
#   'You',
#   'may',
#   'keep',
#   'my',
#   '$',
#   '25',
#   'and',
#   'lose',
#   'my',
#   'bag',
#   'with',
#   'no',
#   'info',
#   ',',
#   'but',
#   'you',
#   'no',
#   'longer',
#   'have',
#   'my',
#   'trust',
#   '.',
#   'Bad',
#   'way',
#   'to',
#   'handle',
#   'this',
#   '.'],
#  ['@', 'VirginAmerica', 'is', 'that', '#', 'thestarter', '?', '?', '😁'],
#  ['@',
#   'JetBlue',
#   'Learning',
#   'about',
#   'your',
#   'awesome',
#   'twitter',
#   'management',
#   'today',
#   'in',
#   'my',
#   'Social',
#   'Media',
#   'Marketing',
#   'class',
#   '!',
#   'keep',
#   'up',
#   'the',
#   'good',
#   'work',
#   '!',
#   '@',
#   'SXU',
#   '@',
#   'PhD_Mama_'],
#  ['@',
#   'AmericanAir',
#   'dropping',
#   'the',
#   'ball',
#   '.',
#   'Again',
#   '.',
#   'No',
#   'catering',
#   '.',
#   'Plane',
#   'switch',
#   '.',
#   'No',
#   'gate',
#   'attendant',
#   '.',
#   '2',
#   'hours',
#   'Late',
#   'Flight',
#   '.',
#   'Really',
#   'nice',
#   '.'],
#  ['@',
#   'AmericanAir',
#   'good',
#   'care',
#   'of',
#   'their',
#   'customers',
#   'if',
#   'anything',
#   'happen',
#   'to',
#   'then',
#   'take',
#   'you',
#   '@',
#   'Delta',
#   'for',
#   'getting',
#   'me',
#   'back',
#   'to',
#   'NYC',
#   '!',
#   '!',
#   'Screw',
#   'you',
#   '@',
#   'AmericanAir'],
#  ['@',
#   'AmericanAir',
#   'I',
#   'do',
#   "n't",
#   'think',
#   'you',
#   'should',
#   'help',
#   'him',
#   'at',
#   'all',
#   'based',
#   'on',
#   'his',
#   'behavior',
#   '.',
#   'The',
#   'voucher',
#   'and',
#   'cot',
#   'seem',
#   'like',
#   'enough',
#   'lol',
#   '😃'],
#  ['@',
#   'united',
#   'I',
#   'think',
#   'problem',
#   'resolution',
#   'should',
#   'be',
#   'decided',
#   'on',
#   'your',
#   'end',
#   '.',
#   'Especially',
#   'if',
#   'you',
#   "'d",
#   'like',
#   'me',
#   'to',
#   'continue',
#   'flying',
#   'your',
#   'airline',
#   '.'],
#  ['@',
#   'USAirways',
#   'I',
#   "'ve",
#   'been',
#   'on',
#   'hold',
#   'for',
#   '36',
#   'mins',
#   'and',
#   'counting',
#   'cause',
#   'you',
#   'charged',
#   'my',
#   'credit',
#   'card',
#   'for',
#   'bag',
#   'but',
#   'provided',
#   'no',
#   'receipt',
#   'and',
#   'said',
#   'error',
#   '.',
#   'Awful'],
#  ['@',
#   'united',
#   'great',
#   '.',
#   'Looking',
#   'forward',
#   'to',
#   'your',
#   'response',
#   'to',
#   'my',
#   'DM',
#   'then'],
#  ['@',
#   'united',
#   'it',
#   "'s",
#   'my',
#   '21st',
#   'birthday',
#   'and',
#   'my',
#   'sister',
#   'is',
#   'coming',
#   'to',
#   'celebrate',
#   'but',
#   'her',
#   'flights',
#   'keep',
#   'Cancelled',
#   'Flighting',
#   'PLZ',
#   'do',
#   'all',
#   'you',
#   'can',
#   'to',
#   'get',
#   'her',
#   'here',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['@',
#   'USAirways',
#   'UR',
#   'employee',
#   'named',
#   'VAN',
#   '@',
#   'ticket',
#   'counter',
#   'in',
#   '#',
#   'Philadelphia',
#   '.',
#   'EXTREMELY',
#   'RUDE',
#   '!',
#   'a',
#   'Father',
#   'trying',
#   'to',
#   'get',
#   'home',
#   'to',
#   'sick',
#   'kid',
#   'missed',
#   'flight',
#   '.'],
#  ['@',
#   'SouthwestAir',
#   'Horrible',
#   'experience',
#   'ever',
#   'with',
#   'airline',
#   '..',
#   'Have',
#   'to',
#   'reconsider',
#   'any',
#   'future',
#   'flights',
#   '.',
#   'Customer',
#   'service',
#   '...',
#   'http',
#   ':',
#   '//t.co/EczHcmM5vi'],
#  ['@',
#   'AmericanAir',
#   'for',
#   'tomorrow',
#   'some',
#   'sites',
#   'show',
#   'flight',
#   '1642',
#   'from',
#   'ewr',
#   'Cancelled',
#   'Flightled',
#   ',',
#   'is',
#   'it',
#   '?'],
#  ['@',
#   'VirginAmerica',
#   'I',
#   'like',
#   'the',
#   'customer',
#   'service',
#   'but',
#   'a',
#   '40',
#   'min',
#   'delay',
#   'just',
#   'for',
#   'connecting',
#   'passengers',
#   'seems',
#   'too',
#   'long',
#   '.',
#   'VA370'],
#  ['@',
#   'VirginAmerica',
#   'cutest',
#   'salt',
#   'and',
#   'pepper',
#   'shaker',
#   'ever',
#   '.',
#   'Just',
#   'when',
#   'I',
#   'think',
#   'you',
#   'guys',
#   'ca',
#   "n't",
#   'get',
#   'any',
#   'better',
#   'you',
#   'just',
#   'do',
#   '!',
#   'http',
#   ':',
#   '//t.co/vC6Keulg2J'],
#  ['@',
#   'AmericanAir',
#   'Unbelievable',
#   'that',
#   'I',
#   'can',
#   'not',
#   'even',
#   'wait',
#   'on',
#   'hold',
#   'to',
#   'speak',
#   'to',
#   'a',
#   'human',
#   'being',
#   'to',
#   'resolve',
#   'my',
#   'issue',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'The',
#   'system',
#   'simply',
#   'hangs',
#   'up',
#   '!'],
#  ['@',
#   'AmericanAir',
#   'continues',
#   'to',
#   'win',
#   ':',
#   'I',
#   "'ve",
#   'never',
#   'missed',
#   'a',
#   'flight',
#   'before',
#   ',',
#   'but',
#   'a',
#   'nice',
#   'little',
#   'quiet',
#   'gate',
#   'change',
#   'made',
#   'it',
#   'possible',
#   '.',
#   'Sheesh',
#   '.'],
#  ['@',
#   'USAirways',
#   'we',
#   'even',
#   'offered',
#   'to',
#   'fly',
#   'in',
#   'to',
#   'another',
#   'airport',
#   'and',
#   'they',
#   'said',
#   'they',
#   'could',
#   "n't",
#   'do',
#   'that',
#   '.',
#   'No',
#   'explanation',
#   'why',
#   'they',
#   'ca',
#   "n't",
#   '.'],
#  ['@',
#   'USAirways',
#   'the',
#   'phone',
#   'number',
#   'the',
#   'gate',
#   'gave',
#   'me',
#   'does',
#   "n't",
#   'work',
#   'either',
#   '.',
#   'What',
#   'is',
#   'your',
#   'customer',
#   'service',
#   'phone',
#   'number',
#   '?'],
#  ['@', 'JetBlue', 'flight', '1041', 'to', 'Savannah', ',', 'GA'],
#  ['@',
#   'AmericanAir',
#   'yes',
#   'but',
#   'you',
#   'are',
#   'still',
#   'human',
#   'I',
#   'hope',
#   ',',
#   'dealing',
#   'with',
#   'all',
#   'the',
#   'horror',
#   'stories',
#   'people',
#   'share',
#   '...',
#   'I',
#   'complained',
#   'to',
#   'DOT',
#   '.',
#   'Everyone',
#   'should'],
#  ['@',
#   'JetBlue',
#   'they',
#   'are',
#   'now',
#   'being',
#   'sent',
#   'off',
#   'the',
#   'plane',
#   '?',
#   'Does',
#   'anyone',
#   'at',
#   'JetBlue',
#   'have',
#   'a',
#   'clue',
#   '?'],
#  ['@',
#   'SouthwestAir',
#   'do',
#   'you',
#   'have',
#   'all',
#   'winners',
#   'for',
#   '@',
#   'Imaginedragons',
#   '#',
#   'DestinationDragons'],
#  ['@',
#   'united',
#   'quick',
#   '(',
#   'serious',
#   ')',
#   'question',
#   '-',
#   'any',
#   'resources/ratings',
#   'showing',
#   'the',
#   'quality',
#   'of',
#   'service',
#   'is',
#   'better',
#   'than',
#   '8th',
#   'place',
#   '?',
#   'http',
#   ':',
#   '//t.co/deWIthPeW2'],
#  ['@',
#   'united',
#   'can',
#   'you',
#   'not',
#   'get',
#   'the',
#   'first',
#   'flight',
#   'of',
#   'the',
#   'day',
#   'off',
#   'the',
#   'ground',
#   'on',
#   'time',
#   '?',
#   '#',
#   '1531',
#   '.',
#   'Let',
#   "'s",
#   'go',
#   '.......'],
#  ['“',
#   '@',
#   'SouthwestAir',
#   ':',
#   'Southwest',
#   'mobile',
#   'boarding',
#   'passes',
#   'now',
#   'available',
#   'in',
#   'iOS',
#   'Passbook',
#   '!',
#   'http',
#   ':',
#   '//t.co/xmRvR4lGEg',
#   'http',
#   ':',
#   '//t.co/wJoc9f14SU',
#   '”',
#   '@',
#   'tori_leggieri'],
#  ['@', 'SouthwestAir', 'I', "'m", 'stuck', 'in', 'Fort', 'Lauderdale', '.'],
#  ['@',
#   'JetBlue',
#   'I',
#   'clear',
#   'that',
#   'folder',
#   'regularly',
#   'and',
#   'JetBlue',
#   'is',
#   'white',
#   'listed',
#   'so',
#   'it',
#   'never',
#   'got',
#   'to',
#   'me',
#   '.'],
#  ['@',
#   'united',
#   'Keep',
#   'the',
#   'flights',
#   'cheap',
#   'and',
#   'early/on',
#   'time',
#   'and',
#   'you',
#   'are',
#   'good',
#   '.',
#   'Flew',
#   '@',
#   'AmericanAir',
#   'and',
#   'Cancelled',
#   'Flightled',
#   'my',
#   'flight',
#   '4',
#   'times',
#   'last',
#   'month',
#   '.',
#   'United',
#   '&',
#   'gt',
#   ';'],
#  ['@',
#   'JetBlue',
#   'I',
#   'believe',
#   'it',
#   "'s",
#   'Irina',
#   '.',
#   'On',
#   'the',
#   'flip-side',
#   ',',
#   'super',
#   'disappointed',
#   'that',
#   'EatUp',
#   'Cafe',
#   'is',
#   "n't",
#   'available',
#   'on',
#   'this',
#   'BOS',
#   '--',
#   '&',
#   'gt',
#   ';',
#   'SFO',
#   'flight',
#   'today',
#   '.'],
#  ['@',
#   'USAirways',
#   '5534',
#   '.',
#   'That',
#   "'s",
#   'the',
#   'flight',
#   'I',
#   'was',
#   'placed',
#   'on',
#   'after',
#   'original',
#   'flight',
#   'to',
#   'Charlotte',
#   'was',
#   'Cancelled',
#   'Flightled',
#   '.',
#   'Now',
#   '5534',
#   'is',
#   'on',
#   '1hr',
#   'delay'],
#  ['@',
#   'USAirways',
#   'The',
#   'captain',
#   'turned',
#   'off',
#   'the',
#   'seat',
#   'belt',
#   'sign',
#   'so',
#   'people',
#   'can',
#   'get',
#   'up',
#   'and',
#   'walk',
#   'around',
#   '.',
#   'That',
#   "'s",
#   'not',
#   'good',
#   '.'],
#  ['@',
#   'United',
#   'now',
#   'what',
#   '?',
#   '!',
#   '?',
#   'http',
#   ':',
#   '//t.co/5hpSqVRjK8',
#   'flight',
#   'was',
#   'gone',
#   'when',
#   'I',
#   'got',
#   'off',
#   'plane',
#   '!',
#   '#',
#   'BusinessTravel',
#   '#',
#   'goodenoughmother'],
#  ['@',
#   'AmericanAir',
#   'Call',
#   'me',
#   'Chairman',
#   ',',
#   'or',
#   'call',
#   'me',
#   'Emerald',
#   '.',
#   'After',
#   'what',
#   'you',
#   'did',
#   'today',
#   'to',
#   'me',
#   ',',
#   'you',
#   'can',
#   'call',
#   'me',
#   'a',
#   'former',
#   'customer',
#   '.'],
#  ['@',
#   'JetBlue',
#   'we',
#   'saw',
#   'one',
#   ',',
#   'he',
#   'was',
#   'as',
#   'useless',
#   'as',
#   'the',
#   'tsa',
#   'agents',
#   'who',
#   'inspected',
#   'my',
#   'shoes'],
#  ['@', 'united', 'Thank', 'you', 'for', 'your', 'response', '!'],
#  ['@',
#   'AmericanAir',
#   'no',
#   'one',
#   'received',
#   'text',
#   'alerts',
#   ',',
#   'automated',
#   'calls',
#   ',',
#   'anything',
#   'either',
#   '.',
#   'Literally',
#   'no',
#   'information',
#   'as',
#   'to',
#   'what',
#   'was',
#   'happening',
#   '.'],
#  ['@',
#   'USAirways',
#   'made',
#   'it',
#   '!',
#   '!',
#   '!',
#   'Send',
#   'Bloody',
#   'Mary',
#   "'s",
#   'to',
#   'row',
#   '27',
#   '!',
#   '!',
#   '!'],
#  ['@',
#   'united',
#   '5',
#   'gate',
#   'changes',
#   ',',
#   'two',
#   'delays',
#   '.',
#   'Even',
#   'the',
#   'crew',
#   'thinks',
#   'the',
#   'airline',
#   'sucks'],
#  ['@',
#   'USAirways',
#   'Thank',
#   'You',
#   'for',
#   'your',
#   'empathy',
#   'there',
#   'is',
#   'more',
#   'to',
#   'this',
#   'story',
#   'than',
#   'just',
#   'the',
#   'luggage',
#   'but',
#   'thank',
#   'you',
#   'for',
#   'reaching',
#   'out'],
#  ['@',
#   'JetBlue',
#   'Thanks',
#   'JB',
#   '.',
#   'Actually',
#   ',',
#   'As',
#   'a',
#   'birder',
#   'I',
#   'love',
#   'them',
#   'too',
#   '.',
#   'They',
#   'just',
#   'need',
#   'to',
#   'be',
#   'outside',
#   '.',
#   'It',
#   'should',
#   "n't",
#   'be',
#   'too',
#   'hard',
#   'to',
#   'trap',
#   'and',
#   'move',
#   'them',
#   '.'],
#  ['@',
#   'USAirways',
#   'flt',
#   '5302',
#   'CLT',
#   'to',
#   'DAY',
#   'supposed',
#   'to',
#   'depart',
#   '5:51',
#   ';',
#   'the',
#   '6:20',
#   '...',
#   'still',
#   'no',
#   'crew',
#   '.',
#   '#',
#   'schedule/contact',
#   'the',
#   'pilot',
#   '!'],
#  ['@',
#   'JetBlue',
#   'to',
#   'allow',
#   'payment',
#   'by',
#   '#',
#   'Apple',
#   'Pay',
#   '-',
#   'Patriarc',
#   'http',
#   ':',
#   '//t.co/bdUaUZFhW2'],
#  ['@',
#   'united',
#   'and',
#   'now',
#   'your',
#   'rep',
#   'just',
#   'hung',
#   'up',
#   'on',
#   'me',
#   'after',
#   'over',
#   '35',
#   'mins',
#   'on',
#   'hold',
#   'because',
#   'I',
#   'asked',
#   'for',
#   'a',
#   'supervisor',
#   '.',
#   'I',
#   "'m",
#   'furious',
#   'right',
#   'now',
#   '.'],
#  ['@',
#   'AmericanAir',
#   'no',
#   'you',
#   "'re",
#   'not',
#   'you',
#   "'re",
#   'trying',
#   'to',
#   'book',
#   'me',
#   'PAST',
#   'when',
#   'i',
#   'need',
#   '2',
#   'arrive',
#   'but',
#   'you',
#   "'re",
#   'still',
#   'selling',
#   'seats',
#   'on',
#   'the',
#   'day',
#   'I',
#   "'m",
#   'trying',
#   '2',
#   'travel'],
#  ['@',
#   'USAirways',
#   '@',
#   'AmericanAir',
#   'seriously',
#   'with',
#   'all',
#   'the',
#   'service',
#   'issues',
#   'you',
#   'are',
#   'having',
#   'right',
#   'now',
#   'this',
#   'is',
#   'what',
#   'you',
#   'decide',
#   'to',
#   'tweet',
#   '?',
#   '?',
#   'Unbelievable'],
#  ['@',
#   'AmericanAir',
#   'will',
#   'do',
#   '.',
#   'I',
#   'also',
#   'passed',
#   'the',
#   'website',
#   'around',
#   'to',
#   'other',
#   'passengers',
#   '.'],
#  ['@',
#   'united',
#   'clicked',
#   'on',
#   'the',
#   'link',
#   'and',
#   'got',
#   'this',
#   '?',
#   '#',
#   'confused',
#   'http',
#   ':',
#   '//t.co/xMAQcucWZl'],
#  ['@',
#   'AmericanAir',
#   'well',
#   'we',
#   'cleared',
#   'customs',
#   'in',
#   'AUH',
#   '.',
#   'I',
#   'need',
#   'to',
#   'get',
#   'to',
#   'IAH',
#   'after',
#   'I',
#   'arrive',
#   'in',
#   'DFW',
#   '.',
#   'Is',
#   'it',
#   'possible',
#   'to',
#   'retrieve',
#   'my',
#   'luggage',
#   'in',
#   'IAD',
#   '?'],
#  ['@',
#   'SouthwestAir',
#   '@',
#   'TaylorLumsden',
#   'Taylor',
#   '.',
#   'U',
#   'got',
#   'ta',
#   'love',
#   'SWA',
#   'responsiveness',
#   'at',
#   'the',
#   '@',
#   'very',
#   'least',
#   'huh',
#   '?'],
#  ['@',
#   'AmericanAir',
#   'flights',
#   'been',
#   'Cancelled',
#   'Flightled',
#   ',',
#   'ca',
#   "n't",
#   'get',
#   'through',
#   'to',
#   'the',
#   'desk',
#   'and',
#   'nothing',
#   'showing',
#   'online',
#   'under',
#   'my',
#   'reservation',
#   '-',
#   'what',
#   'do',
#   'I',
#   'do',
#   '?'],
#  ['@',
#   'AmericanAir',
#   '@',
#   'USAirways',
#   '-',
#   'I',
#   "'m",
#   'pregnant',
#   'with',
#   'twins',
#   'and',
#   'you',
#   "'re",
#   'going',
#   'to',
#   'abandon',
#   'me',
#   'overnight',
#   'in',
#   'an',
#   'airport',
#   '?',
#   'No',
#   'hotel',
#   '?',
#   'When',
#   'it',
#   "'s",
#   'your',
#   'fault',
#   '?'],
#  ['@',
#   'united',
#   'thanks',
#   'for',
#   'prompt',
#   'response',
#   '.',
#   'Another',
#   'hour',
#   'to',
#   'enjoy',
#   'vacation',
#   '!',
#   'Perhaps',
#   'a',
#   'bug',
#   'in',
#   'the',
#   'app',
#   'as',
#   'it',
#   'still',
#   'shows',
#   '2:55',
#   '.'],
#  ['@',
#   'united',
#   'tried',
#   'that',
#   '.',
#   'Can',
#   'not',
#   'figure',
#   'out',
#   'where',
#   'to',
#   'go',
#   'to',
#   'get',
#   'it',
#   '.'],
#  ['@',
#   'united',
#   'except',
#   'all',
#   'of',
#   'that',
#   'delayed',
#   'the',
#   'flight',
#   'anyway',
#   '.'],
#  ['@', 'JetBlue', 'get', 'flight', '16', 'into', 'the', 'air'],
#  ['@',
#   'united',
#   'let',
#   'me',
#   'assure',
#   'you',
#   'my',
#   'travel',
#   'time',
#   'is',
#   '4h2m',
#   'not',
#   '5h2m',
#   '#',
#   'timezones',
#   '#',
#   'accuratetraveltimes',
#   '#',
#   '3rdtimethishashappened',
#   'http',
#   ':',
#   '//t.co/e0C9bI09cf'],
#  ['@',
#   'united',
#   ':',
#   'thanks',
#   '!',
#   'i',
#   'will',
#   'catch',
#   'my',
#   'conection',
#   '!',
#   ':',
#   ')'],
#  ['“',
#   '@',
#   'JetBlue',
#   ':',
#   'Our',
#   'fleet',
#   "'s",
#   'on',
#   'fleek',
#   '.',
#   'http',
#   ':',
#   '//t.co/aJM3BhJVaa',
#   '”',
#   '#',
#   'foh'],
#  ['@',
#   'VirginAmerica',
#   'I',
#   'am',
#   'all',
#   'about',
#   'the',
#   'in',
#   'flight',
#   'artisanal',
#   'cheese',
#   'and',
#   'wine',
#   'pairing',
#   '.'],
#  ['@',
#   'united',
#   'flight',
#   'UA3364',
#   'been',
#   'sitting',
#   'on',
#   'tarmac',
#   'for',
#   '30',
#   'mins',
#   'with',
#   'no',
#   'report',
#   'as',
#   'to',
#   'why',
#   '...',
#   'any',
#   'input',
#   '?'],
#  ['@', 'USAirways', 'sits', 'on', 'a', 'throne', 'of', 'lies'],
#  ['@',
#   'SouthwestAir',
#   '3',
#   'flights',
#   'Cancelled',
#   'Flightled',
#   'today',
#   '.',
#   'Now',
#   'we',
#   'have',
#   'been',
#   'on',
#   'hold',
#   'for',
#   'over',
#   'an',
#   'hour',
#   '!'],
#  ['@',
#   'SouthwestAir',
#   'Late',
#   'Flightly',
#   'you',
#   "'ve",
#   'always',
#   'been',
#   'Late',
#   'Flight',
#   '!',
#   'Please',
#   'get',
#   'back',
#   'to',
#   'the',
#   'old',
#   '#',
#   'SWA',
#   '!',
#   '!'],
#  ['@',
#   'AmericanAir',
#   'My',
#   'ex-boyfriend',
#   'picks',
#   'up',
#   'my',
#   'calls',
#   'more',
#   'than',
#   'you',
#   'do',
#   '!',
#   '#',
#   'Cancelled',
#   'Flightedflight',
#   '#',
#   'nocustomerservice',
#   '#',
#   'americanairlines',
#   '#',
#   'FAIL'],
#  ['@',
#   'SouthwestAir',
#   'I',
#   'WOULD',
#   'DO',
#   'ANYTHING',
#   'FOR',
#   'tickets',
#   'to',
#   'the',
#   'VEGAS',
#   '...',
#   'ANYTHING',
#   '.',
#   'I',
#   'love',
#   'imagine',
#   'dragons',
#   'so',
#   'much',
#   '!',
#   '!'],
#  ['@',
#   'SouthwestAir',
#   'thanks',
#   'for',
#   'your',
#   'attention',
#   ',',
#   'I',
#   "'ve",
#   'been',
#   'flying',
#   'southwest',
#   'for',
#   '3',
#   'years',
#   'and',
#   'have',
#   "n't",
#   'had',
#   'this',
#   'issue',
#   'in',
#   'the',
#   'past',
#   '.'],
#  ['@',
#   'USAirways',
#   'never',
#   'let',
#   "'s",
#   'me',
#   'down',
#   ',',
#   'every',
#   '.',
#   'Single',
#   '.',
#   'Flight',
#   '.',
#   'Gets',
#   'delayed',
#   '.'],
#  ['@',
#   'USAirways',
#   'me',
#   'and',
#   'my',
#   'wife',
#   'will',
#   'be',
#   'flying',
#   'out',
#   'of',
#   'atlanta',
#   'to',
#   'vegas',
#   'on',
#   'March',
#   '7th',
#   'since',
#   'could',
#   "n't",
#   'get',
#   'any',
#   'out',
#   'of',
#   'tricities',
#   'here',
#   'in',
#   'Tn'],
#  ['@',
#   'united',
#   'Flight',
#   'UA1665',
#   'got',
#   'delayed',
#   '2',
#   'hours',
#   'due',
#   'to',
#   'a',
#   'mechanical',
#   'issue',
#   '...',
#   'could',
#   'use',
#   'a',
#   'free',
#   'drink',
#   'or',
#   '3',
#   'to',
#   'make',
#   'up',
#   'for',
#   'this',
#   'inconvenience'],
#  ['@',
#   'VirginAmerica',
#   'DREAM',
#   'http',
#   ':',
#   '//t.co/oA2dRfAoQ2',
#   'http',
#   ':',
#   '//t.co/lWWdAc2kHx'],
#  ['@',
#   'SouthwestAir',
#   'I',
#   "'m",
#   'in',
#   'line',
#   'at',
#   'the',
#   'airport',
#   'right',
#   'now',
#   '.',
#   'Will',
#   'you',
#   'cover',
#   'hotel',
#   'fair',
#   'or',
#   'am',
#   'I',
#   'to',
#   'sleep',
#   'in',
#   'the',
#   'airport',
#   '?'],
#  ['@',
#   'JetBlue',
#   'I',
#   'do',
#   "n't",
#   'know-',
#   'no',
#   'one',
#   'would',
#   'tell',
#   'me',
#   'where',
#   'they',
#   'were',
#   'coming',
#   'from',
#   '-',
#   'I',
#   'would',
#   'guess',
#   'so',
#   'as',
#   'that',
#   "'s",
#   'where',
#   'we',
#   'had',
#   'all',
#   'the',
#   'changes',
#   'to',
#   'flights'],
#  ['@',
#   'AmericanAir',
#   'no',
#   'worries',
#   'you',
#   "'re",
#   'swamped',
#   'I',
#   'know',
#   'just',
#   'dmd',
#   'back',
#   'THANK',
#   'U'],
#  ['@',
#   'SouthwestAir',
#   'i',
#   'forgot',
#   'to',
#   'put',
#   'my',
#   'tsa',
#   'pre',
#   'number',
#   'in',
#   'before',
#   'I',
#   'checked',
#   'in',
#   '.',
#   'It',
#   'is',
#   'now',
#   'in',
#   'my',
#   'profile',
#   'but',
#   'will',
#   'it',
#   'be',
#   'on',
#   'my',
#   'boarding',
#   'pass',
#   'in',
#   'the',
#   'am'],
#  ['@', 'SouthwestAir', 'have', 'five', 'people', 'shown', 'up', 'yet'],
#  ['@',
#   'AmericanAir',
#   'I',
#   "'ve",
#   'never',
#   'had',
#   'anything',
#   'bad',
#   'to',
#   'say',
#   'until',
#   'now',
#   '.',
#   'No',
#   'love',
#   'for',
#   'faithful',
#   'customers',
#   '.'],
#  ['@',
#   'SouthwestAir',
#   ':',
#   'Hello',
#   '..',
#   'are',
#   'flights',
#   'taking',
#   'off',
#   'from',
#   '@',
#   'DallasLoveField',
#   'airport',
#   'this',
#   'noon',
#   '.',
#   'Am',
#   'supposed',
#   'to',
#   'travel',
#   'on',
#   'flight',
#   '376',
#   'to',
#   'San',
#   'antonio'],
#  ['@',
#   'SouthwestAir',
#   'I',
#   'love',
#   'and',
#   'appreciate',
#   'the',
#   'fact',
#   'that',
#   'you',
#   'guys',
#   'rarely',
#   'Cancelled',
#   'Flight',
#   'flights',
#   'and',
#   'are',
#   'on',
#   'time',
#   ',',
#   'but',
#   'I',
#   'need',
#   'a',
#   'Cancelled',
#   'Flightlation',
#   'this',
#   'time',
#   '.',
#   '🙏'],
#  ['@', 'AmericanAir', 'Connection', 'is', 'US2065'],
#  ['@',
#   'united',
#   'all',
#   'good',
#   'man',
#   'it',
#   'is',
#   "n't",
#   'your',
#   'fault',
#   'that',
#   'plane',
#   'is',
#   'having',
#   'maintenance',
#   'issues'],
#  ['@',
#   'AmericanAir',
#   'while',
#   'I',
#   "'m",
#   'sensitive',
#   'to',
#   'this',
#   'fact',
#   ',',
#   'I',
#   'do',
#   "n't",
#   'believe',
#   'that',
#   'warrants',
#   'poor',
#   'service',
#   '.',
#   'A',
#   'little',
#   'help',
#   '&',
#   'amp',
#   ';',
#   'compassion',
#   'goes',
#   'a',
#   'long',
#   'way',
#   '.'],
#  ['@',
#   'jetblue',
#   'all',
#   'your',
#   'online',
#   'resources',
#   'say',
#   'we',
#   "'re",
#   'on',
#   'time',
#   ',',
#   'but',
#   'clearly',
#   'we',
#   'are',
#   'not',
#   '.',
#   'This',
#   'is',
#   'not',
#   'very',
#   'information',
#   'age',
#   'of',
#   'you',
#   '...'],
#  ['@',
#   'united',
#   'You',
#   'make',
#   'it',
#   'hard',
#   'to',
#   'fly',
#   'with',
#   'you',
#   '.',
#   'Delayed',
#   'over',
#   'an',
#   'hour',
#   'and',
#   'now',
#   'the',
#   'plane',
#   'is',
#   'turning',
#   'around',
#   '&',
#   'amp',
#   ';',
#   'heading',
#   'back',
#   'to',
#   'the',
#   'gate',
#   '.',
#   '#',
#   'connection',
#   '?'],
#  ['@',
#   'USAirways',
#   'your',
#   'people',
#   'are',
#   'kind',
#   'and',
#   'hardworking',
#   'the',
#   'infrastructure',
#   'you',
#   'have',
#   'given',
#   'them',
#   'is',
#   'horrid',
#   '#',
#   'massivefail',
#   '#',
#   'failphone',
#   '#',
#   'fail'],
#  ['@',
#   'JetBlue',
#   'THANKS',
#   '!',
#   '!',
#   'Her',
#   '80th',
#   'bday',
#   'is',
#   'Saturday',
#   '.',
#   'We',
#   "'re",
#   'having',
#   'an',
#   'aviation',
#   'themed',
#   'surprise',
#   'party',
#   'for',
#   'her',
#   '.'],
#  ['@',
#   'JetBlue',
#   'Airways',
#   'Reveals',
#   "'Bluemanity",
#   "'",
#   'Livery',
#   '-',
#   'TravelPulse',
#   'http',
#   ':',
#   '//t.co/fTTfyFMvCO'],
#  ['@',
#   'USAirways',
#   '@',
#   'JosephTReis',
#   'Dont',
#   'bother',
#   '.',
#   'They',
#   'dont',
#   'pick',
#   'up',
#   'the',
#   'phone',
#   '.',
#   'Worst',
#   'customer',
#   'service',
#   'going'],
#  ['@',
#   'AmericanAir',
#   'Are',
#   'you',
#   'expecting',
#   'any',
#   'delays',
#   'out',
#   'of',
#   '#',
#   'DFW',
#   'tomorrow',
#   'morning',
#   '?'],
#  ['@',
#   'USAirways',
#   'flight',
#   '1808',
#   'is',
#   'not',
#   'leaving',
#   'at',
#   '2:45',
#   'because',
#   'we',
#   'have',
#   "n't",
#   'even',
#   'begun',
#   'to',
#   'board',
#   'yet',
#   '.',
#   'Please',
#   'update',
#   'your',
#   'website',
#   'ASAP'],
#  ['@',
#   'AmericanAir',
#   'what',
#   'an',
#   'incredibly',
#   'arrogant',
#   'thing',
#   'to',
#   'say',
#   'while',
#   'I',
#   'sit',
#   'here',
#   'at',
#   "O'Hare",
#   'waiting',
#   'for',
#   'your',
#   'incompetent',
#   'airlines',
#   'to',
#   'refuel',
#   'on',
#   'a',
#   '...'],
#  ['@',
#   'JetBlue',
#   'Airline',
#   'trouble',
#   'this',
#   'winter',
#   '&',
#   'amp',
#   ';',
#   'not',
#   'getting',
#   'good',
#   'customer',
#   'service',
#   '?',
#   'contact',
#   'http',
#   ':',
#   '//t.co/aQjn4HwNaC',
#   'we',
#   'negotiate',
#   'resolutions',
#   'for',
#   'You',
#   '!'],
#  ['@',
#   'united',
#   'thankful',
#   'for',
#   'great',
#   'service',
#   'in',
#   'Newark',
#   '.',
#   'Seats',
#   'fixed',
#   'and',
#   'I',
#   'was',
#   'seated',
#   'with',
#   'my',
#   'daughter',
#   '!',
#   'Fab',
#   'landing',
#   'in',
#   'Fort',
#   'Myers',
#   '!'],
#  ['@',
#   'united',
#   'feeling',
#   'like',
#   'a',
#   'true',
#   'united',
#   'customer',
#   'stuck.on',
#   'the',
#   'tarmac',
#   'in',
#   'dc',
#   'for',
#   'over',
#   '2',
#   'hrs',
#   '.',
#   'UNITEDFAIL'],
#  ['@',
#   'united',
#   'it',
#   'is',
#   'cool',
#   '.',
#   'Your',
#   'customer',
#   'told',
#   'me',
#   'they',
#   'did',
#   "n't",
#   'care',
#   'either',
#   '.',
#   'It',
#   'is',
#   'expected'],
#  ['@',
#   'SouthwestAir',
#   'when',
#   'does',
#   'today',
#   "'s",
#   'scavenger',
#   'hunt',
#   'start',
#   '?',
#   'I',
#   "'m",
#   'trying',
#   'to',
#   'help',
#   'my',
#   'little',
#   'brother',
#   'win',
#   '!',
#   '#',
#   'DestinationDragons'],
#  ['@',
#   'united',
#   '&',
#   'lt',
#   ';',
#   '&',
#   'lt',
#   ';',
#   '&',
#   'lt',
#   ';',
#   '&',
#   'lt',
#   ';',
#   '&',
#   'lt',
#   ';',
#   '--',
#   '--',
#   '--',
#   '-',
#   'shoddy',
#   'customer',
#   'service',
#   '.',
#   'Of',
#   'no',
#   'use',
#   'whatsoever',
#   '.',
#   '#',
#   'unitedairline'],
#  ['@',
#   'JetBlue',
#   'Any',
#   'option',
#   'for',
#   'luggage',
#   'assistance',
#   'on',
#   'the',
#   'ground',
#   'at',
#   'HPN',
#   '?',
#   'Flight',
#   '2168',
#   'delayed',
#   '2+',
#   'hours',
#   '&',
#   'amp',
#   ';',
#   'we',
#   'will',
#   'have',
#   '2',
#   'sleeping',
#   'kids',
#   'when',
#   'we',
#   'land'],
#  ['@', 'SouthwestAir', 'I', 'DM', "'d", 'you'],
#  ['@',
#   'united',
#   'yep—used',
#   'that',
#   'twice',
#   ';',
#   'no',
#   'case',
#   'id',
#   'numbers',
#   'assigned',
#   ';',
#   'just',
#   'tried',
#   'it',
#   'again-get',
#   'screen',
#   'that',
#   'says',
#   ',',
#   '“',
#   'thank',
#   'you',
#   'for',
#   'submitting',
#   'your',
#   'request',
#   '”'],
#  ['@',
#   'AmericanAir',
#   'You',
#   'guys',
#   'did',
#   'an',
#   'amazing',
#   'job',
#   'today',
#   '!',
#   'Know',
#   'it',
#   '’',
#   's',
#   'hard',
#   ';',
#   'thanks',
#   'to',
#   'Kate',
#   'Appleton',
#   'for',
#   'all',
#   'her',
#   'hard',
#   'work',
#   'reFlight',
#   'Booking',
#   'Problems',
#   'my',
#   'friends',
#   'and',
#   'me',
#   '!'],
#  ['@',
#   'AmericanAir',
#   'you',
#   'really',
#   'need',
#   'some',
#   'customer',
#   'service',
#   'training',
#   'for',
#   'your',
#   'unhappy',
#   'EEs',
#   'in',
#   'the',
#   'morning',
#   'in',
#   'Chicago',
#   '.',
#   'Gate',
#   'K20',
#   'at',
#   '430',
#   'chking',
#   'her',
#   'schd'],
#  ['@', 'SouthwestAir', 'your', 'employees', 'were', 'great', '!'],
#  ['@',
#   'AmericanAir',
#   '@',
#   'SouljaCoy',
#   'what',
#   'is',
#   'AA',
#   'going',
#   'to',
#   'do',
#   'to',
#   'fix',
#   'their',
#   'utterly',
#   'embarrassing',
#   'customer',
#   'service',
#   '?',
#   'You',
#   'wo',
#   "n't",
#   'even',
#   'answer',
#   'the',
#   'dang',
#   'phone',
#   '!'],
#  ['@',
#   'SouthwestAir',
#   'Please',
#   'bring',
#   'back',
#   'RDU',
#   'to',
#   'FLL',
#   'direct',
#   'route',
#   '!',
#   'I',
#   'noticed',
#   'it',
#   'is',
#   'missing',
#   'starting',
#   'in',
#   'Late',
#   'Flight',
#   'August',
#   '!',
#   'The',
#   'flights',
#   'are',
#   'always',
#   'packed',
#   '!'],
#  ['@', 'USAirways', 'does', "n't", 'want', 'me', 'to', 'get', 'home'],
#  ['@',
#   'USAirways',
#   'The',
#   'phone',
#   'line',
#   'disconnects',
#   '.',
#   'How',
#   'can',
#   'I',
#   'be',
#   'in',
#   'the',
#   'queue',
#   'to',
#   'be',
#   'answered',
#   'when',
#   'the',
#   'phone',
#   'line',
#   'simply',
#   'disconnects',
#   'when',
#   'I',
#   'call',
#   '?'],
#  ['@',
#   'JetBlue',
#   'I',
#   "'m",
#   'sitting',
#   'on',
#   'the',
#   'plane',
#   '.',
#   'Too',
#   'many',
#   'predictable',
#   'mechanical',
#   'problems',
#   '.',
#   'Still',
#   'onboard',
#   '.',
#   'This',
#   'is',
#   'getting',
#   'bad',
#   '...'],
#  ['@', 'USAirways', '@', 'shivadelrahim', 'what', 'about', 'upgrades', '?'],
#  ['@',
#   'USAirways',
#   'never',
#   'received',
#   'such',
# ...
#   'did',
#   'the',
#   'wifi',
#   'that',
#   'was',
#   'paid',
#   'for',
#   '.',
#   'Boo',
#   ':',
#   '('],
#  ['@',
#   'AmericanAir',
#   'What',
#   "'s",
#   'with',
#   'your',
#   'baggage',
#   'handlers',
#   'calling',
#   'out',
#   'at',
#   'DFW',
#   'today',
#   '?',
#   'No',
#   'luggage',
#   'onboard',
#   'the',
#   'planes',
#   '.'],
#  ['@',
#   'USAirways',
#   'so',
#   'I',
#   'would',
#   'have',
#   'to',
#   'go',
#   'though',
#   'the',
#   'entire',
#   'process',
#   'again',
#   'just',
#   'to',
#   'get',
#   'you',
#   'people',
#   'on',
#   'the',
#   'phone',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '#',
#   'usairwayssucks'],
#  ['@',
#   'USAirways',
#   'you',
#   'have',
#   'to',
#   'be',
#   'crazy',
#   '!',
#   'Treated',
#   'my',
#   'mom',
#   'very',
#   'poorly',
#   '.',
#   'Not',
#   'happy',
#   '!',
#   '#',
#   'usairwaysfail'],
#  ['@', 'SouthwestAir', 'how', 'many', 'are', 'left', '?', '!'],
#  ['@',
#   'USAirways',
#   'You',
#   'all',
#   'work',
#   'hard',
#   'at',
#   'making',
#   'sure',
#   'things',
#   'flow',
#   'smoothly',
#   '.',
#   'Keeping',
#   'positive',
#   '.'],
#  ['@',
#   'USAirways',
#   'Do',
#   "n't",
#   'blame',
#   'it',
#   'on',
#   'weather',
#   '.',
#   'Rep',
#   'at',
#   'counter',
#   'cost',
#   'me',
#   'entire',
#   'day',
#   '-',
#   'not',
#   'weather',
#   '.',
#   'Printed',
#   'Boarding',
#   'Pass',
#   'too',
#   'Late',
#   'Flight',
#   '.',
#   '#',
#   'TakeResponsibility'],
#  ['@',
#   'united',
#   'thanks',
#   'for',
#   'updating',
#   'me',
#   'about',
#   'the',
#   '1+',
#   'hour',
#   'delay',
#   'the',
#   'exact',
#   'second',
#   'I',
#   'got',
#   'to',
#   'ATL',
#   '.',
#   '🙅🙅🙅'],
#  ['@',
#   'united',
#   'How',
#   'is',
#   'this',
#   'considered',
#   '``',
#   'on',
#   'time',
#   "''",
#   'if',
#   'it',
#   "'s",
#   'arriving',
#   'at',
#   'destination',
#   'half',
#   'hour',
#   'Late',
#   'Flightr',
#   'than',
#   'scheduled',
#   '?',
#   'http',
#   ':',
#   '//t.co/YMFTw1uyHr'],
#  ['@',
#   'AmericanAir',
#   'if',
#   'it',
#   'I',
#   'have',
#   'not',
#   'rebooked',
#   'did',
#   "n't",
#   'get',
#   'notified',
#   'that',
#   'it',
#   'was',
#   'Cancelled',
#   'Flightled'],
#  ['@',
#   'USAirways',
#   '#',
#   'ShoutOut',
#   '2',
#   'Kristie',
#   '(',
#   'sp',
#   '?',
#   ')',
#   'from',
#   'Gate4',
#   '@',
#   'PVD',
#   'today',
#   '.',
#   'She',
#   "'s",
#   'a',
#   '#',
#   'RockStar',
#   ',',
#   'was',
#   'a',
#   'tremendous',
#   'help',
#   'in',
#   'a',
#   'tough',
#   'situation',
#   '.',
#   '#',
#   'PromoteThatGirl'],
#  ['@',
#   'united',
#   'this',
#   'is',
#   'for',
#   'a',
#   'check-in',
#   'luggage',
#   '.',
#   'Employee',
#   'told',
#   'me',
#   'not',
#   'to',
#   'include',
#   'wheels',
#   'in',
#   'the',
#   'dimensions',
#   '.'],
#  ['@',
#   'united',
#   '25',
#   'minute',
#   'hold',
#   'is',
#   '1',
#   'hr',
#   '.',
#   '25',
#   'min',
#   '.',
#   '@',
#   'ABC11_WTVD'],
#  ['@',
#   'USAirways',
#   'You',
#   'guys',
#   'are',
#   'screwing',
#   'up',
#   'my',
#   'trip',
#   '.',
#   'Thanks',
#   'for',
#   'nothing',
#   '.',
#   '#',
#   'lazy'],
#  ['@',
#   'united',
#   'the',
#   'passengers',
#   'waited',
#   'inside',
#   'the',
#   'flight',
#   'on',
#   'the',
#   'runway',
#   'and',
#   'returned',
#   'back',
#   'in',
#   'o',
#   'gate',
#   'that',
#   'should',
#   'not',
#   'count',
#   'as',
#   'a',
#   'valid',
#   'journey'],
#  ['@',
#   'USAirways',
#   'Frustrating',
#   'days',
#   '!',
#   'No',
#   'flights',
#   'home',
#   ',',
#   'changed',
#   'airlines',
#   '.',
#   'Thank',
#   'you',
#   'PHL',
#   'USAirway',
#   'employees',
#   '&',
#   'amp',
#   ';',
#   '@',
#   'united',
#   'for',
#   'help',
#   'getting',
#   'me',
#   'back',
#   'to',
#   'IAH',
#   '.'],
#  ['@',
#   'united',
#   'u',
#   'guys',
#   'did',
#   'it',
#   'again',
#   'changed',
#   'ages',
#   'and',
#   'double',
#   'booked',
#   'seats',
#   'so',
#   'I',
#   'had',
#   'to',
#   'I',
#   "'ve",
#   'even',
#   'though',
#   'I',
#   'have',
#   'platinum',
#   'and',
#   'the',
#   'other',
#   'person',
#   'none'],
#  ['@',
#   'USAirways',
#   'Cancelled',
#   'Flightled',
#   'the',
#   'last',
#   'part',
#   'of',
#   'a',
#   'ticket',
#   'and',
#   'am',
#   'confused',
#   'from',
#   'the',
#   'email',
#   'I',
#   'received',
#   'whether',
#   'value',
#   'remains',
#   '.',
#   'Is',
#   'there',
#   'someone',
#   'I',
#   'can',
#   'ask',
#   '?'],
#  ['@',
#   'united',
#   'If',
#   'a',
#   'business',
#   'decision',
#   'is',
#   'made',
#   'that',
#   'inconveniences',
#   'and',
#   'possibly',
#   'causes',
#   'lost',
#   'customers',
#   ',',
#   'is',
#   'it',
#   'a',
#   'good',
#   'business',
#   'decision',
#   '?',
#   '#',
#   'Cranky'],
#  ['@',
#   'USAirways',
#   'my',
#   'flight',
#   'got',
#   'Cancelled',
#   'Flightled',
#   'to',
#   'Charlotte',
#   '.',
#   'Been',
#   'on',
#   'hold',
#   'for',
#   'an',
#   'hour',
#   ',',
#   'pls',
#   'pick',
#   'up',
#   '!'],
#  ['@', 'VirginAmerica', 'wow', 'this', 'just', 'blew', 'my', 'mind'],
#  ['@',
#   'AmericanAir',
#   'AA2416',
#   'on',
#   'time',
#   'and',
#   'awesome',
#   'flight',
#   '.',
#   'Great',
#   'job',
#   'American',
#   '!'],
#  ['@',
#   'SouthwestAir',
#   'did',
#   "n't",
#   'realize',
#   'no',
#   'clothes',
#   'until',
#   'at',
#   'hotel',
#   '-',
#   'suggestions',
#   '?'],
#  ['@',
#   'SouthwestAir',
#   'got',
#   'mine',
#   '!',
#   'Just',
#   'in',
#   'time',
#   'for',
#   'the',
#   'wife',
#   'and',
#   'my',
#   '15th',
#   'anniversary',
#   '!'],
#  ['“',
#   '@',
#   'SouthwestAir',
#   ':',
#   '@',
#   'pancho_joe',
#   'No',
#   ',',
#   'no',
#   ',',
#   'you',
#   'must',
#   "'ve",
#   'heard',
#   'us',
#   'wrong',
#   '.',
#   'Sweet',
#   'mixtape',
#   ',',
#   'though',
#   "''",
#   '4',
#   'the',
#   'record',
#   ',',
#   'I',
#   'did',
#   "n't",
#   'leave',
#   'the',
#   '80',
#   "'s",
#   ',',
#   'the',
#   '80',
#   "'s",
#   'left',
#   'me'],
#  ['@',
#   'AmericanAir',
#   'Sitting',
#   'at',
#   'the',
#   'gate',
#   'on',
#   'Flight',
#   '719',
#   'for',
#   'an',
#   'hour',
#   'due',
#   'to',
#   'Sabre',
#   'being',
#   'down',
#   '.',
#   'What',
#   'backup',
#   'plan',
#   'is',
#   'in',
#   'place',
#   'if',
#   'Sabre',
#   'can',
#   'not',
#   'be',
#   'fixed',
#   '?'],
#  ['@',
#   'SouthwestAir',
#   'is',
#   'my',
#   'favorite',
#   'airlines',
#   '.',
#   'I',
#   "'ve",
#   'never',
#   'had',
#   'issues',
#   'with',
#   'them',
#   '.',
#   'Plus',
#   'there',
#   'crew',
#   'is',
#   'entertaining',
#   '.'],
#  ['@',
#   'USAirways',
#   'I',
#   'made',
#   'it',
#   '!',
#   'Thanks',
#   'for',
#   'the',
#   'help',
#   '!'],
#  ['@',
#   'USAirways',
#   'is',
#   'utterly',
#   'unreliable',
#   '!',
#   'They',
#   'did',
#   "n't",
#   'schedule',
#   'a',
#   'pilot',
#   'for',
#   'their',
#   'US624',
#   'flight',
#   'out',
#   'of',
#   'Seattle',
#   '-',
#   'flights',
#   'are',
#   'delayed',
#   '#',
#   'usairwaysfail'],
#  ['@',
#   'southwestair',
#   'TREMENDOUS',
#   'job',
#   '.',
#   'Atlanta',
#   'Airport',
#   'saw',
#   'SW',
#   'celebrate',
#   'Mardi',
#   'Gras',
#   '.',
#   'Another',
#   'reason',
#   'I',
#   "'m",
#   'nuts',
#   'for',
#   'you',
#   'guys',
#   '!',
#   'http',
#   ':',
#   '//t.co/8WBzOrRn3C'],
#  ['@',
#   'united',
#   'it',
#   'seems',
#   'like',
#   'no',
#   'one',
#   'from',
#   'United',
#   'can',
#   'help',
#   'me',
#   '.',
#   'Lots',
#   'of',
#   'fingers',
#   'pointed',
#   ',',
#   'zero',
#   'people',
#   'stepping',
#   'up',
#   '.',
#   'At',
#   'least',
#   'the',
#   'gate',
#   'has',
#   'Oreos'],
#  ['@',
#   'SouthwestAir',
#   '8FKQW',
#   'is',
#   'the',
#   'conf',
#   '#',
#   '.',
#   'Thanks',
#   'for',
#   'the',
#   'reply'],
#  ['@',
#   'united',
#   'rebooked',
#   '24',
#   'hours',
#   'after',
#   'original',
#   'flight',
#   ',',
#   'to',
#   'say',
#   'your',
#   'handling',
#   'of',
#   'situation',
#   'was',
#   'bad',
#   'would',
#   'be',
#   'an',
#   'understatement',
#   '.'],
#  ['@',
#   'AmericanAir',
#   'are',
#   'flights',
#   'leaving',
#   'Dallas',
#   'right',
#   'now',
#   '?',
#   'In',
#   'Maui',
#   'trying',
#   'to',
#   'figure',
#   'out',
#   'how',
#   'delayed',
#   'flight',
#   '7',
#   'is',
#   'going',
#   'to',
#   'be'],
#  ['@',
#   'SouthwestAir',
#   'One',
#   'heck',
#   'of',
#   'an',
#   'airline',
#   'http',
#   ':',
#   '//t.co/CyoOnZfTdC'],
#  ['@',
#   'SouthwestAir',
#   'flying',
#   'flight',
#   '3130',
#   'tonight',
#   'at',
#   '7:20',
#   'from',
#   'PBI-',
#   'I',
#   'have',
#   'boarding',
#   'position',
#   'C-42',
#   '.',
#   'Is',
#   'it',
#   'overbooked',
#   '?',
#   'Really',
#   'do',
#   "n't",
#   'want',
#   'to',
#   'be',
#   'bumped',
#   '!'],
#  ['@',
#   'JetBlue',
#   'Clients',
#   'got',
#   'ZERO',
#   ',',
#   'in',
#   '32',
#   'years',
#   'career',
#   'never',
#   'thought',
#   'this',
#   'was',
#   'possible.2',
#   'suitcases',
#   'worth',
#   'thousands',
#   'of',
#   '$',
#   '$',
#   'in',
#   'Italian',
#   'clothing',
#   'robbed',
#   '.'],
#  ['@',
#   'USAirways',
#   'now',
#   'what',
#   '?',
#   'You',
#   'Cancelled',
#   'Flightled',
#   'my',
#   'flight',
#   'again',
#   '...',
#   'Are',
#   'you',
#   'paying',
#   'for',
#   'my',
#   'hotel',
#   '?'],
#  ['@',
#   'AmericanAir',
#   'Your',
#   'response',
#   'has',
#   'been',
#   'incredible',
#   '.',
#   'Truly',
#   'amazed',
#   'at',
#   'the',
#   'steps',
#   'you',
#   'have',
#   'taken',
#   'to',
#   'enhance',
#   'your',
#   'customer',
#   'relations',
#   '.',
#   'Big',
#   'thank',
#   'you',
#   '😄'],
#  ['@',
#   'AmericanAir',
#   'just',
#   'wow',
#   'Regina',
#   'just',
#   'told',
#   'me',
#   'I',
#   'ca',
#   "n't",
#   'file',
#   'or',
#   'request',
#   'a',
#   'lost',
#   'bag',
#   'statement',
#   'until',
#   'I',
#   'finish',
#   'my',
#   'travel',
#   '.',
#   'So',
#   'until',
#   'I',
#   'get',
#   'to',
#   'DC',
#   'argg'],
#  ['@',
#   'united',
#   'since',
#   'I',
#   'have',
#   'an',
#   'international',
#   'connection',
#   'at',
#   '9am',
#   ',',
#   'I',
#   "'m",
#   'hoping',
#   'for',
#   'the',
#   'same',
#   'thing',
#   '!'],
#  ['@', 'JetBlue', 'all', 'day'],
#  ['@',
#   'united',
#   'how',
#   'long',
#   'will',
#   'it',
#   'take',
#   'for',
#   'miles',
#   'that',
#   'i',
#   're-purchased',
#   '(',
#   'they',
#   'had',
#   'expired',
#   ')',
#   'to',
#   'show',
#   'up',
#   '?',
#   'I',
#   'recieved',
#   'an',
#   'email',
#   'that',
#   'the',
#   'request',
#   'had',
#   'been',
#   '..'],
#  ['@',
#   'united',
#   'is',
#   'probably',
#   'the',
#   'least',
#   'satisfactory',
#   'airline',
#   'I',
#   "'ve",
#   'ever',
#   'been',
#   'on',
#   '.',
#   'Never',
#   'fails',
#   'to',
#   'disappoint',
#   '.'],
#  ['@',
#   'United',
#   'Airlines',
#   'Is',
#   'Changing',
#   'Its',
#   'MileagePlus',
#   'Program',
#   ':',
#   'Winners',
#   'And',
#   'Losers',
#   'http',
#   ':',
#   '//t.co/F1yvAiO9ul',
#   'http',
#   ':',
#   '//t.co/vGlx6Ykwqg'],
#  ['@',
#   'AmericanAir',
#   '@',
#   'SeguineJ',
#   'AA',
#   '-',
#   'this',
#   'is',
#   'a',
#   'joke',
#   ',',
#   'right',
#   '?',
#   'That',
#   'line',
#   'is',
#   "n't",
#   'even',
#   'accepting',
#   'calls',
#   'right',
#   'now',
#   '-',
#   'they',
#   'just',
#   'hang',
#   'up',
#   '.'],
#  ['@',
#   'united',
#   'nonrefundable',
#   ',',
#   'hence',
#   'I',
#   'wrote',
#   '$',
#   '200',
#   '!',
#   'Does',
#   "n't",
#   'make',
#   'sense',
#   'for',
#   'my',
#   '150',
#   'credit',
#   '.',
#   '#',
#   'nothanks'],
#  ['@',
#   'JetBlue',
#   'Even',
#   '5',
#   'years',
#   'after',
#   'the',
#   'earthquake',
#   '...',
#   'Haiti',
#   'still',
#   'needs',
#   'helps',
#   'in',
#   'rebuilding',
#   '#',
#   'flyingitforward'],
#  ['@',
#   'USAirways',
#   'despite',
#   'mechanical',
#   'issues',
#   'and',
#   'many',
#   'delays',
#   'followed',
#   'by',
#   'a',
#   'Cancelled',
#   'Flightlation',
#   ',',
#   'still',
#   'getting',
#   'to',
#   'Vegas',
#   'thanks',
#   'to',
#   'great',
#   'gate',
#   'agents',
#   '!'],
#  ['@',
#   'JetBlue',
#   'no',
#   'excuse',
#   'though',
#   'for',
#   '3',
#   'gate',
#   'changes',
#   'though',
#   '.'],
#  ['@',
#   'JetBlue',
#   'I',
#   'may',
#   'need',
#   'to',
#   '.',
#   'I',
#   'had',
#   'a',
#   '40',
#   'minute',
#   'layover',
#   'and',
#   'now',
#   'have',
#   'a',
#   '15',
#   'min',
#   'delay',
#   'on',
#   'my',
#   'first',
#   'flight',
#   '.'],
#  ['@',
#   'united',
#   'How',
#   'do',
#   'I',
#   'get',
#   'reimbursed',
#   'for',
#   'hotel',
#   'and',
#   'taxis',
#   'for',
#   'the',
#   'Cancelled',
#   'Flightation',
#   '?'],
#  ['@',
#   'AmericanAir',
#   'but',
#   'have',
#   'been',
#   'yet',
#   'to',
#   'receive',
#   'assistance',
#   'from',
#   'one',
#   'of',
#   'your',
#   'agents',
#   'in',
#   'securing',
#   'a',
#   'new',
#   'connection',
#   '.',
#   'Many',
#   'will',
#   'now',
#   'miss',
#   'work',
#   'tomorrow',
#   '.'],
#  ['@',
#   'USAirways',
#   '@',
#   'British_Airways',
#   'three',
#   'hour',
#   'flight',
#   'delay',
#   '.',
#   'On',
#   'the',
#   'phone',
#   'for',
#   '45min',
#   'and',
#   'counting',
#   '.'],
#  ['@',
#   'AmericanAir',
#   '#',
#   '2298',
#   '.',
#   'Everyone',
#   'else',
#   'was',
#   'outstanding',
#   '.'],
#  ['@',
#   'united',
#   '-',
#   'I',
#   'think',
#   'she',
#   'was',
#   'having',
#   'a',
#   'rough',
#   'moment',
#   'w/',
#   'a',
#   'bad',
#   'passenger',
#   'from',
#   'an',
#   'earlier',
#   'flight',
#   '.',
#   'Things',
#   'got',
#   'considerably',
#   'better',
#   '.',
#   'Thanks',
#   '!'],
#  ['@', 'USAirways', 'thanks', '!'],
#  ['@',
#   'AmericanAir',
#   'I',
#   'Cancelled',
#   'Flightled',
#   'my',
#   'ticket',
#   'and',
#   'is',
#   'taking',
#   'two',
#   'months',
#   '++',
#   'to',
#   'refund',
#   'and',
#   'still',
#   'waiting',
#   '!'],
#  ['@', 'USAirways', 'should', ',', 'but', 'didn', '’', 't', '.'],
#  ['@',
#   'USAirways',
#   'shout',
#   'out',
#   'to',
#   'the',
#   'pilots',
#   'and',
#   'FC',
#   'attendant',
#   '(',
#   'Eliz',
#   ')',
#   'of',
#   'US',
#   '673',
#   '.',
#   'Super',
#   'strong',
#   'crosswinds',
#   'during',
#   'landing',
#   '.',
#   'Eliz',
#   'did',
#   'a',
#   'super',
#   'job',
#   'throughout'],
#  ['@',
#   'united',
#   'I',
#   'see',
#   'you',
#   'coming',
#   'to',
#   'get',
#   'me',
#   'and',
#   '@',
#   'AggieMensGolf',
#   'in',
#   'Hawaii',
#   '!',
#   '#',
#   '12thMan',
#   'http',
#   ':',
#   '//t.co/G8DKa3Edhf'],
#  ['@',
#   'AmericanAir',
#   '@',
#   'dfwairport',
#   'you',
#   '2',
#   'together',
#   'are',
#   'the',
#   'best',
#   'part',
#   'of',
#   'flying',
#   '!'],
#  ['@',
#   'united',
#   'to',
#   'Late',
#   'Flight',
#   'now',
#   ',',
#   'but',
#   'in',
#   'future',
#   'flights',
#   ',',
#   'train',
#   'staff',
#   'better',
#   'to',
#   'handle',
#   'emergency',
#   'situations',
#   ',',
#   'and',
#   'ground',
#   'staff',
#   'in',
#   'Customer',
#   'Service'],
#  ['@',
#   'united',
#   'oh',
#   'united',
#   ',',
#   'how',
#   'much',
#   'I',
#   'despise',
#   'thee',
#   '!'],
#  ['@',
#   'United',
#   'Airlines',
#   "'",
#   'CEO',
#   'Jeff',
#   'Smisek',
#   ':',
#   'Disloyal',
#   'to',
#   'Loyal',
#   'Workers',
#   'http',
#   ':',
#   '//t.co/0cevY3P42b',
#   'via',
#   '@',
#   'HuffPostBiz'],
#  ['@',
#   'united',
#   '3/10',
#   'disappointed',
#   'in',
#   'the',
#   'service',
#   '.',
#   'Will',
#   'be',
#   'missing',
#   'my',
#   'connection',
#   'after',
#   'over',
#   'an',
#   'hour',
#   'delay',
#   '+',
#   'cramped',
#   'seats',
#   '.',
#   'At',
#   'least',
#   'their',
#   'app',
#   'is',
#   'good'],
#  ['@',
#   'AmericanAir',
#   'we',
#   'had',
#   'to',
#   'sit',
#   'in',
#   'the',
#   'airport',
#   'a',
#   'long',
#   'periolodicly',
#   'time',
#   '.',
#   'the',
#   'planes',
#   'were',
#   'nasty'],
#  ['@', 'united', '618', 'was', 'flight', 'out', 'of', 'Houston'],
#  ['@', 'united', 'fuck', 'you', 'for', 'not', 'caring', '😢'],
#  ['@',
#   'SouthwestAir',
#   'do',
#   'you',
#   'have',
#   'any',
#   'info',
#   'about',
#   'when',
#   '#',
#   'DestinationDragons',
#   'winners',
#   'will',
#   'be',
#   'announced',
#   '?',
#   'me',
#   '&',
#   'amp',
#   ';',
#   'my',
#   'best',
#   'friend',
#   'are',
#   'hoping',
#   'to',
#   'win',
#   '.',
#   'thanks',
#   '!'],
#  ['@', 'SouthwestAir', 'Thanks'],
#  ['@',
#   'SouthwestAir',
#   'can',
#   'tweet',
#   'through',
#   'the',
#   'weekend/',
#   'bad',
#   'weather',
#   ',',
#   'but',
#   'closes',
#   'down',
#   'customer',
#   'relations',
#   'center',
#   'to',
#   'process',
#   'refunds',
#   'for',
#   'Cancelled',
#   'Flighted',
#   'flights',
#   '.'],
#  ['@',
#   'SouthwestAir',
#   'missing',
#   'out',
#   'on',
#   'over',
#   '6,000',
#   'points',
#   'in',
#   'one',
#   'account',
#   '.',
#   'They',
#   "'re",
#   'now',
#   'spread',
#   'over',
#   'four',
#   'assuming',
#   'I',
#   'create',
#   'accounts',
#   'for',
#   'them'],
#  ['@',
#   'united',
#   'I',
#   'used',
#   'to',
#   'be',
#   'a',
#   'committed',
#   '#',
#   'ContinentalAirlines',
#   'flyer',
#   'until',
#   'merger',
#   '.',
#   'I',
#   'remember',
#   'now',
#   'why',
#   'I',
#   'switched',
#   'to',
#   '@',
#   'SouthwestAir',
#   '#',
#   'CommunicationFail'],
#  ['@',
#   'united',
#   'I',
#   'will',
#   ',',
#   'as',
#   'soon',
#   'as',
#   'I',
#   'am',
#   'done',
#   'with',
#   'my',
#   'article',
#   '.',
#   'Thanks',
#   '!',
#   '~Tom'],
#  ['@',
#   'AmericanAir',
#   'you',
#   "'re",
#   'not',
#   'finding',
#   'it',
#   'bc',
#   '@',
#   'united',
#   'rebooked',
#   'us',
#   'on',
#   'your',
#   'airline',
#   'when',
#   'they',
#   'realized',
#   'they',
#   'could',
#   "n't",
#   'get',
#   'us',
#   'home',
#   '-',
#   'and',
#   'we',
#   "'re",
#   'at',
#   'ORD'],
#  ['@', 'USAirways', 'I', 'gave', 'up', 'http', ':', '//t.co/2eDgc6TbLs'],
#  ['@',
#   'USAirways',
#   'ticket',
#   'couldnt',
#   'be',
#   'used',
#   'bc',
#   'unable',
#   'to',
#   'get',
#   'to',
#   'departing',
#   'dest',
#   '(',
#   'RSW',
#   ')',
#   'bc',
#   'of',
#   'blizzard',
#   'in',
#   'BOS',
#   '.',
#   'Told',
#   'only',
#   'way',
#   'to',
#   'use',
#   'credit',
#   'is',
#   '$',
#   '200',
#   'fine'],
#  ...]

# %%
x_train2=[clean_review(doc) for doc in document]

# %%
x_train2
# Out:
# [['SouthwestAir',
#   'scheduled',
#   'morning',
#   '2',
#   'day',
#   'fact',
#   'yes',
#   '..',
#   'sure',
#   'evening',
#   'flight',
#   'one',
#   'Cancelled',
#   'Flightled'],
#  ['SouthwestAir',
#   'seeing',
#   'worker',
#   'time',
#   'time',
#   'going',
#   'beyond',
#   'love',
#   'flying',
#   'guy',
#   'Thank'],
#  ['united',
#   'Flew',
#   'ORD',
#   'Miami',
#   'back',
#   'great',
#   'crew',
#   'service',
#   'leg',
#   'THANKS'],
#  ['SouthwestAir', 'dultch97', "'s", 'horse', 'radish', '😤🐴'],
#  ['united',
#   'flight',
#   'ORD',
#   'delayed',
#   'Air',
#   'Force',
#   'One',
#   'last',
#   'flight',
#   'SBN',
#   '8:20',
#   '5',
#   'min',
#   'landed'],
#  ['united',
#   'load',
#   'u',
#   'flying',
#   'sardine',
#   'knew',
#   'pilot',
#   '2',
#   'hour',
#   'Late',
#   'Flight',
#   'incompetent',
#   'beyond',
#   'belief'],
#  ['JetBlue',
#   'stock',
#   'response',
#   'Delays',
#   'frustrating',
#   'poor',
#   'cust',
#   'serv',
#   'amp',
#   'told',
#   '3',
#   'ppl',
#   'wait',
#   'amp',
#   "'d",
#   'come',
#   'back'],
#  ['JetBlue',
#   "'d",
#   'nice',
#   'Hoping',
#   'rack',
#   'enough',
#   'mile',
#   'take',
#   'trip',
#   'Seattle',
#   'enjoy',
#   'perfect',
#   'latte',
#   'city',
#   'coffee'],
#  ['united',
#   'frankly',
#   'worse',
#   'customer',
#   'service',
#   'ever',
#   'Problems',
#   'happen',
#   'deal',
#   'defines',
#   'company',
#   'Never',
#   'United'],
#  ['SouthwestAir',
#   'yeah',
#   'haha',
#   'Never',
#   'one',
#   "'s",
#   'expensive',
#   '😂😂',
#   'much',
#   'fun',
#   'destinationdragons'],
#  ['SouthwestAir',
#   'MCO-',
#   'gt',
#   'DCA',
#   'flight',
#   'almost',
#   'full',
#   'people',
#   'screwed',
#   'MSY-DCA',
#   'Cancelled',
#   'Flightation',
#   'united',
#   'USAirways',
#   "n't",
#   'Cancelled',
#   'Flight',
#   'SWA=mistake'],
#  ['JetBlue',
#   "'s",
#   'easiest',
#   'way',
#   'get',
#   'ticket',
#   'receipt',
#   'get',
#   'one',
#   'check',
#   'get',
#   'one',
#   'online',
#   'Thanks'],
#  ['USAirways',
#   'love',
#   'change',
#   'lounge',
#   'cheese',
#   'veggie',
#   'olive',
#   'addition',
#   'cracker',
#   'snack',
#   'mix'],
#  ['SouthwestAir',
#   'receive',
#   'bad',
#   'customer',
#   'service',
#   'ended',
#   'spending',
#   'several',
#   'hundred',
#   'dollar',
#   'accommodate',
#   'family',
#   'cxl',
#   'flight'],
#  ['USAirways',
#   "'re",
#   'killing',
#   'sche',
#   'flight',
#   'board',
#   '3',
#   'min',
#   'mine',
#   'arrived',
#   'gate',
#   'side',
#   'airport',
#   'genious'],
#  ['USAirways',
#   '8',
#   'week',
#   'refund',
#   'ticket',
#   '0372389047497',
#   'totally',
#   'unacceptable',
#   'Fix',
#   "'ll",
#   'put',
#   'blast',
#   'social',
#   'medium',
#   'TV'],
#  ['AmericanAir',
#   'private',
#   'msg',
#   'provide',
#   'detail',
#   '...',
#   'u',
#   'really',
#   'need',
#   'customer',
#   'svc',
#   'training',
#   'staff'],
#  ['RT', 'JetBlue', 'fleet', "'s", 'fleek', 'http', '//t.co/413GiAL0yl'],
#  ['JetBlue',
#   'info',
#   'flight',
#   '704',
#   'SJU',
#   'JFK',
#   'already',
#   'delayed',
#   '2',
#   '1/2',
#   'hour'],
#  ['AmericanAir',
#   "'ve",
#   'tried',
#   'le',
#   '8',
#   'time',
#   'today',
#   'get',
#   'touch',
#   'service',
#   'desk',
#   'beginning',
#   '8:30',
#   'EST',
#   "'m",
#   'luck',
#   '-help'],
#  ['USAirways',
#   'new',
#   'problem',
#   '...',
#   'wrong',
#   'last',
#   'name',
#   'reservation',
#   'airway',
#   'fixed',
#   'New',
#   'ca',
#   "n't",
#   'get',
#   'TSA'],
#  ['SouthwestAir',
#   'possible',
#   'chance',
#   'SWA',
#   'bringing',
#   'back',
#   'service',
#   'LGA-BWI',
#   'would',
#   'make',
#   'much',
#   'easier',
#   'connect',
#   'west',
#   'coast'],
#  ['USAirways',
#   'AmericanAir',
#   'run',
#   'show',
#   'airport',
#   'boarding',
#   'pas',
#   'say',
#   'u',
#   'airway',
#   'wait',
#   'American',
#   'line',
#   'yousuck'],
#  ['united',
#   'computer',
#   'stopped',
#   'giving',
#   'update',
#   'took',
#   'flight',
#   'info',
#   'app',
#   "'s",
#   'ridiculous',
#   'keep',
#   'people',
#   'updated'],
#  ['united', 'good', 'fly', 'United', 'businessFirst'],
#  ['united',
#   'flying',
#   'msp',
#   'dxb',
#   'child',
#   'turn',
#   '2',
#   'trip',
#   'buy',
#   'return',
#   'ticket',
#   'child'],
#  ['JetBlue',
#   'love',
#   'Cancelled',
#   'Flightling',
#   'ticket',
#   'telling',
#   'customer',
#   'flyunited'],
#  ['united',
#   'ORD',
#   'waited',
#   '20',
#   'min',
#   'crew',
#   'member',
#   'left',
#   'gate',
#   'item',
#   'came',
#   'Flight',
#   'attendant',
#   'sarcastically',
#   'said',
#   'good',
#   'luck',
#   'walked',
#   'away'],
#  ['SouthwestAir',
#   'Jason',
#   '108639',
#   'Gate',
#   '3',
#   'SAN',
#   'made',
#   'afternoon',
#   'southwestairlines',
#   'stellarservice',
#   'thanks'],
#  ['AmericanAir',
#   'everything',
#   'sorted',
#   'Thanks',
#   'help',
#   'Excited',
#   'get',
#   'home',
#   'tonight'],
#  ['AmericanAir',
#   'understand',
#   'weather',
#   'would',
#   'nice',
#   'hear',
#   'apology',
#   'phone',
#   'moved',
#   'flight',
#   'inconvenient',
#   'day'],
#  ['SouthwestAir', 'thanks'],
#  ['united',
#   "'s",
#   'booked',
#   'first',
#   'class',
#   'curbside',
#   'delivery',
#   '24',
#   'hour',
#   "'m",
#   'counting',
#   'TeamUSA'],
#  ['JetBlue',
#   'Oh',
#   'totally',
#   'look',
#   'par',
#   'AmericanAir',
#   "'s",
#   'Admirals',
#   'Club',
#   'way',
#   'slide',
#   'u',
#   'couple',
#   'pass'],
#  ['AmericanAir',
#   "'ve",
#   '15',
#   'official',
#   'complaint',
#   'signed',
#   'AmericanAirlines',
#   'Lima',
#   'supervisor',
#   'Customer',
#   'Relations',
#   'pls',
#   'compensate',
#   '4',
#   '10-hour',
#   'delay'],
#  ['JetBlue',
#   '4',
#   'hour',
#   'policy-',
#   'called',
#   'said',
#   "n't",
#   'report',
#   'soon',
#   'enough',
#   'would',
#   'changed',
#   'noticed',
#   'sooner'],
#  ['united',
#   'frustrating',
#   'flying',
#   'experience',
#   'One',
#   'continuous',
#   '``',
#   'dunno',
#   'time',
#   'leave',
#   'today',
#   '``',
#   'Dunno',
#   "'s",
#   'code',
#   '...'],
#  ['SouthwestAir',
#   'Hi',
#   'got',
#   'message',
#   'part',
#   'flight',
#   'Cancelled',
#   'Flightled',
#   'ca',
#   "n't",
#   'rebook',
#   'online',
#   'nobody',
#   'answer',
#   'phone',
#   'call',
#   'Help'],
#  ['SouthwestAir',
#   'need',
#   'update',
#   'flight',
#   '464',
#   'amp',
#   '3574',
#   'hold',
#   '2',
#   'hour'],
#  ['USAirways',
#   "'m",
#   'supposed',
#   'fly',
#   'Dallas',
#   'help',
#   'get',
#   'new',
#   'itinerary'],
#  ['AmericanAir',
#   'fail',
#   'flight',
#   'rdu',
#   'sitting',
#   'waiting',
#   'flight',
#   'attendant',
#   'logistics',
#   'good'],
#  ['united', 'impressed', 'super-fast', 'reply', 'CGJase'],
#  ['united',
#   "n't",
#   'Spoke',
#   'baggage',
#   'contact',
#   '1-800',
#   'number',
#   'Said',
#   'try',
#   'get',
#   'bag',
#   'stay',
#   'IAD',
#   'pick',
#   'tmrw'],
#  ['USAirways',
#   'intentionally',
#   'buy',
#   'flight',
#   '10',
#   'hour',
#   'layover',
#   'kind',
#   'airline',
#   'would',
#   'charge',
#   '200',
#   'fix',
#   'Wow',
#   '...',
#   'usairways'],
#  ['SouthwestAir', 'auto', 'callback', "n't", 'wait', 'hold'],
#  ['united', 'get', 'service', 'desk', 'IAD'],
#  ['JetBlue',
#   'blue',
#   'helped',
#   'bring',
#   'color',
#   'eye',
#   'promise',
#   "n't",
#   'eat',
#   'free',
#   'snack'],
#  ['united', 'Yes', 'therealaviation', 'Instagram'],
#  ['JetBlue',
#   'report',
#   'updated',
#   'info',
#   "n't",
#   'know',
#   'reach',
#   'without',
#   'super',
#   'long',
#   'wait',
#   'hold',
#   'main',
#   'number'],
#  ['JetBlue',
#   'want',
#   'enter',
#   'family',
#   'pooling',
#   'contest',
#   'say',
#   '``',
#   '2/19',
#   "''",
#   'website',
#   'please',
#   'enter',
#   'still'],
#  ['USAirways', 'choose', 'seat', 'free', 'clicking', '100', 'button'],
#  ['united', 'plus', 'food', 'taxi'],
#  ['USAirways', '3hr30min', 'right', '...', 'end', 'sight'],
#  ['SouthwestAir',
#   "'re",
#   'really',
#   'going',
#   'let',
#   'delta',
#   'virginamerica',
#   'get',
#   'best',
#   'http',
#   '//t.co/vUdWJm1lYB'],
#  ['USAirways',
#   'claim',
#   'flight',
#   'Cancelled',
#   'Flighted',
#   'due',
#   'weather',
#   'destination',
#   'Delta',
#   'Cancelled',
#   'Flighted',
#   'flight',
#   'route'],
#  ['JetBlue', 'thanks', 'much', 'help', 'Us', 'u', 'r', 'amazing'],
#  ['AmericanAir',
#   'haha',
#   'said',
#   "n't",
#   'fault',
#   'somehow',
#   'guy',
#   'r',
#   'joke'],
#  ['AmericanAir',
#   'customer',
#   'service',
#   'inferior',
#   'nationalized',
#   'third',
#   'world',
#   'nation',
#   "'s",
#   'airline',
#   'Get',
#   'together'],
#  ['AmericanAir', 'iPhone', 'app', 'sort', 'notification', 'option'],
#  ['united', 'thank'],
#  ['AmericanAir',
#   "'ve",
#   'trying',
#   'reach',
#   'customer',
#   'service',
#   'TWO',
#   'day',
#   'received',
#   'zero',
#   'response',
#   'Never',
#   'traveling',
#   'AA'],
#  ['united',
#   'flight',
#   '4567',
#   'agent',
#   'wandered',
#   'Pilots',
#   'came',
#   'looking',
#   'Went',
#   'charge',
#   'personal',
#   'phone',
#   "'d",
#   'txting'],
#  ['united',
#   'first',
#   'lost',
#   'bag',
#   'Cancelled',
#   'Flight',
#   'flight',
#   'home',
#   '30',
#   'min',
#   'wait',
#   'talk',
#   'somebody',
#   'poorservice',
#   'notgoodenough'],
#  ['SouthwestAir', 'sat', 'plane', '2+', 'hr', '2/15', 'finally', 'took', '..'],
#  ['JetBlue', 'ANYWHERE', 'http', '//t.co/FeFHPmFPlE'],
#  ['USAirways',
#   'spend',
#   'cost',
#   'flight',
#   'get',
#   'free',
#   'room',
#   'transportation',
#   'airport'],
#  ['SouthwestAir',
#   'understand',
#   'weather',
#   'kid',
#   'need',
#   'get',
#   'home',
#   'Nice',
#   'kid',
#   'volunteer',
#   'work',
#   'RI',
#   'high',
#   'school',
#   'please',
#   'help'],
#  ['AmericanAir',
#   'friend',
#   'need',
#   'help',
#   'flt',
#   "'s",
#   'Twiiter',
#   'DM',
#   'info'],
#  ['AmericanAir',
#   'mom',
#   '’',
#   'flight',
#   'tomorrow',
#   'Cancelled',
#   'Flighted',
#   'w/',
#   'notice',
#   'Phone',
#   'system',
#   'said',
#   'callback',
#   '2',
#   'hour',
#   '’',
#   '4',
#   'need',
#   'go',
#   'bed'],
#  ['americanair',
#   'flight',
#   'veers',
#   'icy',
#   'runway',
#   'dfwairport',
#   'DFW',
#   'flight',
#   'Cancelled',
#   'Flighted',
#   'Mon',
#   'http',
#   '//t.co/Q37pOWn6uv',
#   'Cowboycerrone',
#   'figure',
#   'right'],
#  ['united',
#   'Could',
#   'tell',
#   'bag',
#   'would',
#   'accepted',
#   'personal',
#   'item',
#   'bring',
#   'one',
#   'carry-on',
#   'bag',
#   'plus',
#   'http',
#   '//t.co/U390cZpLHl'],
#  ['united',
#   'yo',
#   'need',
#   'new',
#   'website',
#   'really',
#   'badly',
#   'day',
#   'age',
#   '...'],
#  ['SouthwestAir',
#   'TheEllenShow',
#   'Imaginedragons',
#   'kdepetro313',
#   '.what',
#   'great',
#   'first',
#   'night',
#   'DestinationDragons',
#   'http',
#   '//t.co/N3LrFo4UaY'],
#  ['USAirways', 'right', 'amp', 'away', '✈️🌞'],
#  ['united',
#   'two',
#   'dozen',
#   'back',
#   'line',
#   'see',
#   'single',
#   'CSR',
#   'reFlight',
#   'Booking',
#   'Problems',
#   'final',
#   'leg',
#   'Kiosks',
#   'fritz'],
#  ['JetBlue', 'would', 'charge', 'money', 'transfer', 'point', 'someone'],
#  ['USAirways',
#   'possible',
#   'earn',
#   'Dividend',
#   'Miles',
#   'passenger',
#   'even',
#   'purchasing',
#   'ticket'],
#  ['Lmfaooo',
#   '“',
#   'JetBlue',
#   'fleet',
#   "'s",
#   'fleek',
#   'http',
#   '//t.co/1G9RnmYUQe',
#   '”'],
#  ['USAirways',
#   'phone',
#   'line',
#   'call',
#   "n't",
#   'affected',
#   '``',
#   'bad',
#   'weather',
#   "''",
#   'Trying',
#   'book',
#   'vacation',
#   '...',
#   '👀'],
#  ['AmericanAir',
#   'never',
#   'seen',
#   'incompetency',
#   'gate',
#   'agent',
#   'year',
#   'business',
#   'travel',
#   'DFW',
#   'B16',
#   'gate',
#   'agent',
#   'need',
#   'training',
#   'new',
#   'job'],
#  ['USAirways',
#   'F623',
#   'DEN',
#   'PHX',
#   'impressive',
#   'lack',
#   'concern',
#   '1hr+',
#   'Late',
#   'Flight',
#   'flight',
#   'attndt',
#   'wrecking',
#   'havoc',
#   'customer',
#   'travel',
#   'smugsmirk',
#   'norush'],
#  ['united',
#   'client',
#   '11',
#   'hr',
#   'layover',
#   'IAH',
#   'day',
#   'claim',
#   'amp',
#   'recheck',
#   'luggage',
#   'taken',
#   'care'],
#  ['united',
#   'even',
#   'change',
#   'could',
#   'made',
#   'online-',
#   'instructed',
#   'call',
#   'agent-',
#   'maybe',
#   'syastem',
#   'allow',
#   'agent',
#   '2',
#   'link',
#   'passenger'],
#  ['united',
#   'ca',
#   "n't",
#   'claim',
#   '``',
#   'weather',
#   "''",
#   'hardworking',
#   'crew',
#   'pulling',
#   'seat',
#   'plane',
#   'right',
#   'thing',
#   'know',
#   'wo',
#   "n't"],
#  ['AmericanAir',
#   'finally',
#   'called',
#   'Ca',
#   "n't",
#   'get',
#   'met',
#   'Seattle',
#   'refund',
#   'processed',
#   'Thanks'],
#  ['United',
#   'played',
#   'bizarre',
#   '``',
#   'safety',
#   "''",
#   'video',
#   "'ve",
#   'ever',
#   'seen',
#   '...',
#   'http',
#   '//t.co/Hlm2Oks6xl'],
#  ['SouthwestAir',
#   "'m",
#   'sure',
#   'messaging',
#   'part',
#   'right',
#   'Please',
#   'let',
#   'know',
#   'received'],
#  ['SouthwestAir',
#   'booked',
#   '8th',
#   '....',
#   'Save',
#   'emergency',
#   'exit',
#   '...',
#   'Got',
#   'ta',
#   'stretch'],
#  ['SouthwestAir',
#   'try',
#   'get',
#   'customer',
#   'destination',
#   'help',
#   'get',
#   'another',
#   'airline',
#   'flight',
#   '3',
#   'day'],
#  ['JetBlue', 'catch', 'name', 'sure', 'Jason', 'know'],
#  ['USAirways',
#   'Yet',
#   'another',
#   'delay/missed',
#   'connection',
#   '....',
#   'customer',
#   'service',
#   'attitude',
#   'Wow'],
#  ['USAirways',
#   'access',
#   'Dividend',
#   'Miles',
#   'week',
#   'automated',
#   'phone',
#   'keep',
#   'telling',
#   'call',
#   'back',
#   'Late',
#   'Flightr',
#   'FRUSTRATED',
#   'LivePersonPlease'],
#  ['united',
#   'direct',
#   'flight',
#   'Belfast',
#   'Intl',
#   'Newark',
#   'resume',
#   'winter',
#   'break',
#   'Thanks'],
#  ['united',
#   'LGJW7B',
#   'voluntarily',
#   'rerouted',
#   '1st',
#   'leg',
#   'journey',
#   'economy',
#   'supposed',
#   '8B',
#   'Res',
#   'agent',
#   'said',
#   "'d",
#   'reserve'],
#  ['SouthwestAir',
#   'Nashville',
#   'airport',
#   'runway',
#   'open',
#   'appears',
#   'southwest',
#   'airline',
#   'Cancelled',
#   'Flighting',
#   'flight',
#   'likely',
#   'change'],
#  ['USAirways',
#   'flight',
#   'plan',
#   'delayed',
#   'tuesday',
#   'due',
#   'computer',
#   'crash'],
#  ['SouthwestAir',
#   'unbelievable',
#   '...',
#   'Thank',
#   'much',
#   'DestinationDragons'],
#  ['united',
#   'big',
#   'surprise',
#   'nogate',
#   'waiting',
#   'plane',
#   'fucken',
#   'issue',
#   'everything',
#   'fly',
#   'fail',
#   'worstairlineever'],
#  ['USAirways',
#   'tough',
#   'night',
#   'two',
#   '90',
#   'minute',
#   'call',
#   'hold',
#   'delayed',
#   'Phoenix',
#   'two',
#   'day',
#   'one',
#   'aircraft',
#   'ready',
#   'acceptable'],
#  ['united',
#   "'s",
#   'hard',
#   'stay',
#   'upset',
#   'someone',
#   'least',
#   'TRY',
#   'show',
#   'remorse'],
#  ['united',
#   '50',
#   'min',
#   'hold',
#   'trying',
#   'book',
#   'award',
#   'flight',
#   'site',
#   'error',
#   'Agents',
#   'ask',
#   'pin',
#   'see',
#   'platinum',
#   'availability',
#   'badbadbad'],
#  ['USAirways',
#   '23',
#   'min',
#   'hold',
#   '...',
#   'Drove',
#   '2.5',
#   'hour',
#   'get',
#   'delayed',
#   'bag',
#   'want',
#   'pick',
#   'SJU'],
#  ['USAirways', 'reserve', 'seat', 'AA', 'flight', 'transfer', 'ORD', 'EVV'],
#  ['United',
#   'start',
#   '3xdaily',
#   'EmbraerSA',
#   'ERJ145',
#   'flight',
#   'Chicago',
#   'fly2ohare',
#   'Evansville',
#   '4JUN',
#   'avgeek'],
#  ['united',
#   'flight',
#   '1136',
#   'Chicago',
#   'Houston',
#   '2',
#   'hour',
#   'pretzel',
#   'peanut',
#   'Seriously',
#   'passed'],
#  ['united', 'left', 'comment', 'customer', 'care', 'Thanks', 'contacting'],
#  ['united', 'held', 'plane', 'Made'],
#  ['AmericanAir',
#   "'s",
#   'ok',
#   '...',
#   'may',
#   'keep',
#   '25',
#   'lose',
#   'bag',
#   'info',
#   'longer',
#   'trust',
#   'Bad',
#   'way',
#   'handle'],
#  ['VirginAmerica', 'thestarter', '😁'],
#  ['JetBlue',
#   'Learning',
#   'awesome',
#   'twitter',
#   'management',
#   'today',
#   'Social',
#   'Media',
#   'Marketing',
#   'class',
#   'keep',
#   'good',
#   'work',
#   'SXU',
#   'PhD_Mama_'],
#  ['AmericanAir',
#   'dropping',
#   'ball',
#   'catering',
#   'Plane',
#   'switch',
#   'gate',
#   'attendant',
#   '2',
#   'hour',
#   'Late',
#   'Flight',
#   'Really',
#   'nice'],
#  ['AmericanAir',
#   'good',
#   'care',
#   'customer',
#   'anything',
#   'happen',
#   'take',
#   'Delta',
#   'getting',
#   'back',
#   'NYC',
#   'Screw',
#   'AmericanAir'],
#  ['AmericanAir',
#   "n't",
#   'think',
#   'help',
#   'based',
#   'behavior',
#   'voucher',
#   'cot',
#   'seem',
#   'like',
#   'enough',
#   'lol',
#   '😃'],
#  ['united',
#   'think',
#   'problem',
#   'resolution',
#   'decided',
#   'end',
#   'Especially',
#   "'d",
#   'like',
#   'continue',
#   'flying',
#   'airline'],
#  ['USAirways',
#   "'ve",
#   'hold',
#   '36',
#   'min',
#   'counting',
#   'cause',
#   'charged',
#   'credit',
#   'card',
#   'bag',
#   'provided',
#   'receipt',
#   'said',
#   'error',
#   'Awful'],
#  ['united', 'great', 'Looking', 'forward', 'response', 'DM'],
#  ['united',
#   "'s",
#   '21st',
#   'birthday',
#   'sister',
#   'coming',
#   'celebrate',
#   'flight',
#   'keep',
#   'Cancelled',
#   'Flighting',
#   'PLZ',
#   'get'],
#  ['USAirways',
#   'UR',
#   'employee',
#   'named',
#   'VAN',
#   'ticket',
#   'counter',
#   'Philadelphia',
#   'EXTREMELY',
#   'RUDE',
#   'Father',
#   'trying',
#   'get',
#   'home',
#   'sick',
#   'kid',
#   'missed',
#   'flight'],
#  ['SouthwestAir',
#   'Horrible',
#   'experience',
#   'ever',
#   'airline',
#   '..',
#   'reconsider',
#   'future',
#   'flight',
#   'Customer',
#   'service',
#   '...',
#   'http',
#   '//t.co/EczHcmM5vi'],
#  ['AmericanAir',
#   'tomorrow',
#   'site',
#   'show',
#   'flight',
#   '1642',
#   'ewr',
#   'Cancelled',
#   'Flightled'],
#  ['VirginAmerica',
#   'like',
#   'customer',
#   'service',
#   '40',
#   'min',
#   'delay',
#   'connecting',
#   'passenger',
#   'seems',
#   'long',
#   'VA370'],
#  ['VirginAmerica',
#   'cutest',
#   'salt',
#   'pepper',
#   'shaker',
#   'ever',
#   'think',
#   'guy',
#   'ca',
#   "n't",
#   'get',
#   'better',
#   'http',
#   '//t.co/vC6Keulg2J'],
#  ['AmericanAir',
#   'Unbelievable',
#   'even',
#   'wait',
#   'hold',
#   'speak',
#   'human',
#   'resolve',
#   'issue',
#   'system',
#   'simply',
#   'hang'],
#  ['AmericanAir',
#   'continues',
#   'win',
#   "'ve",
#   'never',
#   'missed',
#   'flight',
#   'nice',
#   'little',
#   'quiet',
#   'gate',
#   'change',
#   'made',
#   'possible',
#   'Sheesh'],
#  ['USAirways',
#   'even',
#   'offered',
#   'fly',
#   'another',
#   'airport',
#   'said',
#   'could',
#   "n't",
#   'explanation',
#   'ca',
#   "n't"],
#  ['USAirways',
#   'phone',
#   'number',
#   'gate',
#   'gave',
#   "n't",
#   'work',
#   'either',
#   'customer',
#   'service',
#   'phone',
#   'number'],
#  ['JetBlue', 'flight', '1041', 'Savannah', 'GA'],
#  ['AmericanAir',
#   'yes',
#   'still',
#   'human',
#   'hope',
#   'dealing',
#   'horror',
#   'story',
#   'people',
#   'share',
#   '...',
#   'complained',
#   'DOT',
#   'Everyone'],
#  ['JetBlue', 'sent', 'plane', 'anyone', 'JetBlue', 'clue'],
#  ['SouthwestAir', 'winner', 'Imaginedragons', 'DestinationDragons'],
#  ['united',
#   'quick',
#   'serious',
#   'question',
#   'resources/ratings',
#   'showing',
#   'quality',
#   'service',
#   'better',
#   '8th',
#   'place',
#   'http',
#   '//t.co/deWIthPeW2'],
#  ['united',
#   'get',
#   'first',
#   'flight',
#   'day',
#   'ground',
#   'time',
#   '1531',
#   'Let',
#   "'s",
#   'go',
#   '.......'],
#  ['“',
#   'SouthwestAir',
#   'Southwest',
#   'mobile',
#   'boarding',
#   'pass',
#   'available',
#   'iOS',
#   'Passbook',
#   'http',
#   '//t.co/xmRvR4lGEg',
#   'http',
#   '//t.co/wJoc9f14SU',
#   '”',
#   'tori_leggieri'],
#  ['SouthwestAir', "'m", 'stuck', 'Fort', 'Lauderdale'],
#  ['JetBlue',
#   'clear',
#   'folder',
#   'regularly',
#   'JetBlue',
#   'white',
#   'listed',
#   'never',
#   'got'],
#  ['united',
#   'Keep',
#   'flight',
#   'cheap',
#   'early/on',
#   'time',
#   'good',
#   'Flew',
#   'AmericanAir',
#   'Cancelled',
#   'Flightled',
#   'flight',
#   '4',
#   'time',
#   'last',
#   'month',
#   'United',
#   'gt'],
#  ['JetBlue',
#   'believe',
#   "'s",
#   'Irina',
#   'flip-side',
#   'super',
#   'disappointed',
#   'EatUp',
#   'Cafe',
#   "n't",
#   'available',
#   'BOS',
#   '--',
#   'gt',
#   'SFO',
#   'flight',
#   'today'],
#  ['USAirways',
#   '5534',
#   "'s",
#   'flight',
#   'placed',
#   'original',
#   'flight',
#   'Charlotte',
#   'Cancelled',
#   'Flightled',
#   '5534',
#   '1hr',
#   'delay'],
#  ['USAirways',
#   'captain',
#   'turned',
#   'seat',
#   'belt',
#   'sign',
#   'people',
#   'get',
#   'walk',
#   'around',
#   "'s",
#   'good'],
#  ['United',
#   'http',
#   '//t.co/5hpSqVRjK8',
#   'flight',
#   'gone',
#   'got',
#   'plane',
#   'BusinessTravel',
#   'goodenoughmother'],
#  ['AmericanAir',
#   'Call',
#   'Chairman',
#   'call',
#   'Emerald',
#   'today',
#   'call',
#   'former',
#   'customer'],
#  ['JetBlue', 'saw', 'one', 'useless', 'tsa', 'agent', 'inspected', 'shoe'],
#  ['united', 'Thank', 'response'],
#  ['AmericanAir',
#   'one',
#   'received',
#   'text',
#   'alert',
#   'automated',
#   'call',
#   'anything',
#   'either',
#   'Literally',
#   'information',
#   'happening'],
#  ['USAirways', 'made', 'Send', 'Bloody', 'Mary', "'s", 'row', '27'],
#  ['united',
#   '5',
#   'gate',
#   'change',
#   'two',
#   'delay',
#   'Even',
#   'crew',
#   'think',
#   'airline',
#   'suck'],
#  ['USAirways', 'Thank', 'empathy', 'story', 'luggage', 'thank', 'reaching'],
#  ['JetBlue',
#   'Thanks',
#   'JB',
#   'Actually',
#   'birder',
#   'love',
#   'need',
#   'outside',
#   "n't",
#   'hard',
#   'trap',
#   'move'],
#  ['USAirways',
#   'flt',
#   '5302',
#   'CLT',
#   'DAY',
#   'supposed',
#   'depart',
#   '5:51',
#   '6:20',
#   '...',
#   'still',
#   'crew',
#   'schedule/contact',
#   'pilot'],
#  ['JetBlue',
#   'allow',
#   'payment',
#   'Apple',
#   'Pay',
#   'Patriarc',
#   'http',
#   '//t.co/bdUaUZFhW2'],
#  ['united',
#   'rep',
#   'hung',
#   '35',
#   'min',
#   'hold',
#   'asked',
#   'supervisor',
#   "'m",
#   'furious',
#   'right'],
#  ['AmericanAir',
#   "'re",
#   "'re",
#   'trying',
#   'book',
#   'PAST',
#   'need',
#   '2',
#   'arrive',
#   "'re",
#   'still',
#   'selling',
#   'seat',
#   'day',
#   "'m",
#   'trying',
#   '2',
#   'travel'],
#  ['USAirways',
#   'AmericanAir',
#   'seriously',
#   'service',
#   'issue',
#   'right',
#   'decide',
#   'tweet',
#   'Unbelievable'],
#  ['AmericanAir', 'also', 'passed', 'website', 'around', 'passenger'],
#  ['united', 'clicked', 'link', 'got', 'confused', 'http', '//t.co/xMAQcucWZl'],
#  ['AmericanAir',
#   'well',
#   'cleared',
#   'custom',
#   'AUH',
#   'need',
#   'get',
#   'IAH',
#   'arrive',
#   'DFW',
#   'possible',
#   'retrieve',
#   'luggage',
#   'IAD'],
#  ['SouthwestAir',
#   'TaylorLumsden',
#   'Taylor',
#   'U',
#   'got',
#   'ta',
#   'love',
#   'SWA',
#   'responsiveness',
#   'least',
#   'huh'],
#  ['AmericanAir',
#   'flight',
#   'Cancelled',
#   'Flightled',
#   'ca',
#   "n't",
#   'get',
#   'desk',
#   'nothing',
#   'showing',
#   'online',
#   'reservation'],
#  ['AmericanAir',
#   'USAirways',
#   "'m",
#   'pregnant',
#   'twin',
#   "'re",
#   'going',
#   'abandon',
#   'overnight',
#   'airport',
#   'hotel',
#   "'s",
#   'fault'],
#  ['united',
#   'thanks',
#   'prompt',
#   'response',
#   'Another',
#   'hour',
#   'enjoy',
#   'vacation',
#   'Perhaps',
#   'bug',
#   'app',
#   'still',
#   'show',
#   '2:55'],
#  ['united', 'tried', 'figure', 'go', 'get'],
#  ['united', 'except', 'delayed', 'flight', 'anyway'],
#  ['JetBlue', 'get', 'flight', '16', 'air'],
#  ['united',
#   'let',
#   'assure',
#   'travel',
#   'time',
#   '4h2m',
#   '5h2m',
#   'timezones',
#   'accuratetraveltimes',
#   '3rdtimethishashappened',
#   'http',
#   '//t.co/e0C9bI09cf'],
#  ['united', 'thanks', 'catch', 'conection'],
#  ['“',
#   'JetBlue',
#   'fleet',
#   "'s",
#   'fleek',
#   'http',
#   '//t.co/aJM3BhJVaa',
#   '”',
#   'foh'],
#  ['VirginAmerica', 'flight', 'artisanal', 'cheese', 'wine', 'pairing'],
#  ['united',
#   'flight',
#   'UA3364',
#   'sitting',
#   'tarmac',
#   '30',
#   'min',
#   'report',
#   '...',
#   'input'],
#  ['USAirways', 'sits', 'throne', 'lie'],
#  ['SouthwestAir',
#   '3',
#   'flight',
#   'Cancelled',
#   'Flightled',
#   'today',
#   'hold',
#   'hour'],
#  ['SouthwestAir',
#   'Late',
#   'Flightly',
#   "'ve",
#   'always',
#   'Late',
#   'Flight',
#   'Please',
#   'get',
#   'back',
#   'old',
#   'SWA'],
#  ['AmericanAir',
#   'ex-boyfriend',
#   'pick',
#   'call',
#   'Cancelled',
#   'Flightedflight',
#   'nocustomerservice',
#   'americanairlines',
#   'FAIL'],
#  ['SouthwestAir',
#   'WOULD',
#   'ANYTHING',
#   'ticket',
#   'VEGAS',
#   '...',
#   'ANYTHING',
#   'love',
#   'imagine',
#   'dragon',
#   'much'],
#  ['SouthwestAir',
#   'thanks',
#   'attention',
#   "'ve",
#   'flying',
#   'southwest',
#   '3',
#   'year',
#   "n't",
#   'issue',
#   'past'],
#  ['USAirways',
#   'never',
#   'let',
#   "'s",
#   'every',
#   'Single',
#   'Flight',
#   'Gets',
#   'delayed'],
#  ['USAirways',
#   'wife',
#   'flying',
#   'atlanta',
#   'vega',
#   'March',
#   '7th',
#   'since',
#   'could',
#   "n't",
#   'get',
#   'tricities',
#   'Tn'],
#  ['united',
#   'Flight',
#   'UA1665',
#   'got',
#   'delayed',
#   '2',
#   'hour',
#   'due',
#   'mechanical',
#   'issue',
#   '...',
#   'could',
#   'use',
#   'free',
#   'drink',
#   '3',
#   'make',
#   'inconvenience'],
#  ['VirginAmerica',
#   'DREAM',
#   'http',
#   '//t.co/oA2dRfAoQ2',
#   'http',
#   '//t.co/lWWdAc2kHx'],
#  ['SouthwestAir',
#   "'m",
#   'line',
#   'airport',
#   'right',
#   'cover',
#   'hotel',
#   'fair',
#   'sleep',
#   'airport'],
#  ['JetBlue',
#   "n't",
#   'know-',
#   'one',
#   'would',
#   'tell',
#   'coming',
#   'would',
#   'guess',
#   "'s",
#   'change',
#   'flight'],
#  ['AmericanAir',
#   'worry',
#   "'re",
#   'swamped',
#   'know',
#   'dmd',
#   'back',
#   'THANK',
#   'U'],
#  ['SouthwestAir',
#   'forgot',
#   'put',
#   'tsa',
#   'pre',
#   'number',
#   'checked',
#   'profile',
#   'boarding',
#   'pas'],
#  ['SouthwestAir', 'five', 'people', 'shown', 'yet'],
#  ['AmericanAir',
#   "'ve",
#   'never',
#   'anything',
#   'bad',
#   'say',
#   'love',
#   'faithful',
#   'customer'],
#  ['SouthwestAir',
#   'Hello',
#   '..',
#   'flight',
#   'taking',
#   'DallasLoveField',
#   'airport',
#   'noon',
#   'supposed',
#   'travel',
#   'flight',
#   '376',
#   'San',
#   'antonio'],
#  ['SouthwestAir',
#   'love',
#   'appreciate',
#   'fact',
#   'guy',
#   'rarely',
#   'Cancelled',
#   'Flight',
#   'flight',
#   'time',
#   'need',
#   'Cancelled',
#   'Flightlation',
#   'time',
#   '🙏'],
#  ['AmericanAir', 'Connection', 'US2065'],
#  ['united', 'good', 'man', "n't", 'fault', 'plane', 'maintenance', 'issue'],
#  ['AmericanAir',
#   "'m",
#   'sensitive',
#   'fact',
#   "n't",
#   'believe',
#   'warrant',
#   'poor',
#   'service',
#   'little',
#   'help',
#   'amp',
#   'compassion',
#   'go',
#   'long',
#   'way'],
#  ['jetblue',
#   'online',
#   'resource',
#   'say',
#   "'re",
#   'time',
#   'clearly',
#   'information',
#   'age',
#   '...'],
#  ['united',
#   'make',
#   'hard',
#   'fly',
#   'Delayed',
#   'hour',
#   'plane',
#   'turning',
#   'around',
#   'amp',
#   'heading',
#   'back',
#   'gate',
#   'connection'],
#  ['USAirways',
#   'people',
#   'kind',
#   'hardworking',
#   'infrastructure',
#   'given',
#   'horrid',
#   'massivefail',
#   'failphone',
#   'fail'],
#  ['JetBlue',
#   'THANKS',
#   '80th',
#   'bday',
#   'Saturday',
#   "'re",
#   'aviation',
#   'themed',
#   'surprise',
#   'party'],
#  ['JetBlue',
#   'Airways',
#   'Reveals',
#   "'Bluemanity",
#   'Livery',
#   'TravelPulse',
#   'http',
#   '//t.co/fTTfyFMvCO'],
#  ['USAirways',
#   'JosephTReis',
#   'Dont',
#   'bother',
#   'dont',
#   'pick',
#   'phone',
#   'Worst',
#   'customer',
#   'service',
#   'going'],
#  ['AmericanAir', 'expecting', 'delay', 'DFW', 'tomorrow', 'morning'],
#  ['USAirways',
#   'flight',
#   '1808',
#   'leaving',
#   '2:45',
#   "n't",
#   'even',
#   'begun',
#   'board',
#   'yet',
#   'Please',
#   'update',
#   'website',
#   'ASAP'],
#  ['AmericanAir',
#   'incredibly',
#   'arrogant',
#   'thing',
#   'say',
#   'sit',
#   "O'Hare",
#   'waiting',
#   'incompetent',
#   'airline',
#   'refuel',
#   '...'],
#  ['JetBlue',
#   'Airline',
#   'trouble',
#   'winter',
#   'amp',
#   'getting',
#   'good',
#   'customer',
#   'service',
#   'contact',
#   'http',
#   '//t.co/aQjn4HwNaC',
#   'negotiate',
#   'resolution'],
#  ['united',
#   'thankful',
#   'great',
#   'service',
#   'Newark',
#   'Seats',
#   'fixed',
#   'seated',
#   'daughter',
#   'Fab',
#   'landing',
#   'Fort',
#   'Myers'],
#  ['united',
#   'feeling',
#   'like',
#   'true',
#   'united',
#   'customer',
#   'stuck.on',
#   'tarmac',
#   'dc',
#   '2',
#   'hr',
#   'UNITEDFAIL'],
#  ['united', 'cool', 'customer', 'told', "n't", 'care', 'either', 'expected'],
#  ['SouthwestAir',
#   'today',
#   "'s",
#   'scavenger',
#   'hunt',
#   'start',
#   "'m",
#   'trying',
#   'help',
#   'little',
#   'brother',
#   'win',
#   'DestinationDragons'],
#  ['united',
#   'lt',
#   'lt',
#   'lt',
#   'lt',
#   'lt',
#   '--',
#   '--',
#   '--',
#   'shoddy',
#   'customer',
#   'service',
#   'use',
#   'whatsoever',
#   'unitedairline'],
#  ['JetBlue',
#   'option',
#   'luggage',
#   'assistance',
#   'ground',
#   'HPN',
#   'Flight',
#   '2168',
#   'delayed',
#   '2+',
#   'hour',
#   'amp',
#   '2',
#   'sleeping',
#   'kid',
#   'land'],
#  ['SouthwestAir', 'DM', "'d"],
#  ['united',
#   'yep—used',
#   'twice',
#   'case',
#   'id',
#   'number',
#   'assigned',
#   'tried',
#   'again-get',
#   'screen',
#   'say',
#   '“',
#   'thank',
#   'submitting',
#   'request',
#   '”'],
#  ['AmericanAir',
#   'guy',
#   'amazing',
#   'job',
#   'today',
#   'Know',
#   '’',
#   'hard',
#   'thanks',
#   'Kate',
#   'Appleton',
#   'hard',
#   'work',
#   'reFlight',
#   'Booking',
#   'Problems',
#   'friend'],
#  ['AmericanAir',
#   'really',
#   'need',
#   'customer',
#   'service',
#   'training',
#   'unhappy',
#   'EEs',
#   'morning',
#   'Chicago',
#   'Gate',
#   'K20',
#   '430',
#   'chking',
#   'schd'],
#  ['SouthwestAir', 'employee', 'great'],
#  ['AmericanAir',
#   'SouljaCoy',
#   'AA',
#   'going',
#   'fix',
#   'utterly',
#   'embarrassing',
#   'customer',
#   'service',
#   'wo',
#   "n't",
#   'even',
#   'answer',
#   'dang',
#   'phone'],
#  ['SouthwestAir',
#   'Please',
#   'bring',
#   'back',
#   'RDU',
#   'FLL',
#   'direct',
#   'route',
#   'noticed',
#   'missing',
#   'starting',
#   'Late',
#   'Flight',
#   'August',
#   'flight',
#   'always',
#   'packed'],
#  ['USAirways', "n't", 'want', 'get', 'home'],
#  ['USAirways',
#   'phone',
#   'line',
#   'disconnect',
#   'queue',
#   'answered',
#   'phone',
#   'line',
#   'simply',
#   'disconnect',
#   'call'],
#  ['JetBlue',
#   "'m",
#   'sitting',
#   'plane',
#   'many',
#   'predictable',
#   'mechanical',
#   'problem',
#   'Still',
#   'onboard',
#   'getting',
#   'bad',
#   '...'],
#  ['USAirways', 'shivadelrahim', 'upgrade'],
#  ['USAirways',
#   'never',
#   'received',
#   'horrible',
#   'service',
#   'treated',
#   'poorly',
#   'Richard',
#   'P.',
#   'today',
#   'excuse',
#   'attitude',
#   'amp',
#   'ripping',
#   'ticket'],
#  ['JetBlue',
#   'get',
#   'copy',
#   'last',
#   'flight',
#   'showing',
#   'original',
#   'time',
#   'delay',
#   'need',
#   'work',
#   'Thanks'],
#  ['JetBlue',
#   'get',
#   'honest',
#   'update',
#   'departure',
#   'flite',
#   '454',
#   'plane',
#   'infant',
#   'child'],
#  ['USAirways',
#   'US',
#   '728',
#   'Wait',
#   'gate',
#   'opened',
#   'Back',
#   'go',
#   'Good',
#   'maybe',
#   'get'],
#  ['AmericanAir',
#   'maintenance',
#   'MD80',
#   'sits',
#   'two',
#   'day',
#   'Frozen',
#   'line',
#   'found',
#   'boarded',
#   'Come',
#   'faail',
#   'mci'],
#  ['SouthwestAir',
#   'seriously',
#   'WORST',
#   "n't",
#   'remember',
#   'last',
#   'time',
#   'someone',
#   'knew',
#   'flight',
#   "n't",
#   'delayed',
#   'Cancelled',
#   'Flightled',
#   'etc'],
#  ['united',
#   'wont',
#   'transfer',
#   'flight',
#   'ticket',
#   'accompany',
#   '11',
#   'yr',
#   'old',
#   "'s",
#   'active',
#   'military',
#   'mom',
#   'emergency',
#   'brain',
#   'surgery',
#   'WOW'],
#  ['USAirways',
#   'ticket',
#   'counter',
#   'people',
#   'helping',
#   'want',
#   'charge',
#   'money',
#   'even',
#   'horrible',
#   'day'],
#  ['united',
#   '4',
#   'seg',
#   'flt',
#   'yvr',
#   'zurich',
#   'would',
#   'credit',
#   'mile',
#   '2',
#   'segs',
#   'full',
#   'fare'],
#  ['AmericanAir',
#   'need',
#   'know',
#   "n't",
#   'done',
#   'like',
#   'promised',
#   'would',
#   'yesterday'],
#  ['JetBlue', 'kudos', "'re", 'done', 'heading', 'warmer', 'weather'],
#  ['SouthwestAir',
#   'yall',
#   'trying',
#   'fly',
#   'Chicago',
#   "n't",
#   'live',
#   'Send',
#   'home',
#   'Bullshit',
#   'as',
#   'customer',
#   'service'],
#  ['SouthwestAir',
#   'stay',
#   'Chicago',
#   'overnight',
#   'meet',
#   'bag',
#   'hope',
#   'stay',
#   'put',
#   "n't",
#   'get',
#   'put',
#   'flight'],
#  ['united', 'severely', 'staffed', 'Iah'],
#  ['AmericanAir', 'fantastic', 'thanks', 'try', 'tweet', 'photo', 'view'],
#  ['SouthwestAir',
#   'love',
#   'Companion',
#   'Pass',
#   'qualified',
#   '4th',
#   'year',
#   'HollyMais'],
#  ['AmericanAir',
#   'said',
#   'AA',
#   'provide',
#   'in-flight',
#   'wifi',
#   'route',
#   'China',
#   'based',
#   'federal',
#   'law',
#   'United'],
#  ['SouthwestAir',
#   'boarding',
#   'pass',
#   'compatible',
#   'iPhone',
#   'Passbook',
#   'http',
#   '//t.co/1ESmMnIZEk'],
#  ['USAirways',
#   'disaster',
#   'Flight',
#   '3739',
#   'missed',
#   'passenger',
#   'count',
#   '5',
#   'since',
#   'done',
#   'manually',
#   'Really'],
#  ['JetBlue', 'u', 'suck', 'Big', 'Donkey', 'Balls'],
#  ['SouthwestAir',
#   'Thanks',
#   'Confirmation',
#   'number',
#   'DMed',
#   'Appreciate',
#   'help'],
#  ['JetBlue',
#   "n't",
#   'made',
#   'feel',
#   'like',
#   'criminal',
#   'want',
#   'sit',
#   'near',
#   '5',
#   'year',
#   'old',
#   'flight',
#   'jetblue',
#   'http',
#   '//t.co/qgtCao1J2U'],
#  ['AmericanAir', "'ve", 'already', 'made', 'arrangement'],
#  ['USAirways', 'add', 'frequent', 'flyer', 'number', 'website', 'help'],
#  ['SouthwestAir',
#   'ticket',
#   'booked',
#   '1/27',
#   'CUN',
#   'arrival',
#   'time',
#   'reflect',
#   'CUN',
#   'EST',
#   'time'],
#  ['united',
#   'lot',
#   'unhappy',
#   'cold',
#   'people',
#   'bridge',
#   'freezing',
#   'temp',
#   'hour',
#   'given',
#   'info'],
#  ['jetblue',
#   "'d",
#   'love',
#   'help',
#   'Shanese',
#   'Bryant-Melton',
#   'hard-working',
#   'grandmother',
#   'DC',
#   'go',
#   'Miami',
#   "'s",
#   'bucket',
#   'list',
#   'flyitforward'],
#  ['united',
#   'Want',
#   'book',
#   'multi-city',
#   'fare',
#   'mile',
#   '1of',
#   '2',
#   'flight',
#   'option',
#   'pay',
#   '1st',
#   'flight',
#   'mile',
#   '+2nd',
#   'UMP',
#   'Visa',
#   'Thanks'],
#  ['united', 'email', 'address/username', 'sign-on', 'available', "'s"],
#  ['united', 'yes', "'ve", 'waiting', 'four', 'hour', 'one', 'able', 'help'],
#  ['AmericanAir',
#   'thank',
#   'ca',
#   "n't",
#   'get',
#   'flight',
#   'hold',
#   'Cancelled',
#   'Flights'],
#  ['USAirways',
#   'flight',
#   'scheduled',
#   '730pm',
#   '...',
#   'told',
#   '150am',
#   'flight',
#   'Cancelled',
#   'Flightled',
#   'sitting',
#   'cold',
#   'plane',
#   '2',
#   'hour'],
#  ['united',
#   'Yes',
#   'PLENTY',
#   'seat',
#   'available',
#   'Vicky',
#   'Thomas',
#   'refuse',
#   'give',
#   'one',
#   'million',
#   'mile',
#   'flyer'],
#  ['united',
#   'UA63',
#   'Madrid',
#   'arrived',
#   'agent',
#   'mass',
#   'confusion',
#   'sent',
#   'fro',
#   '3',
#   'UA',
#   'employee',
#   'MaryJo',
#   'rude',
#   'unhelpful'],
#  ['USAirways',
#   'AmericanAir',
#   'terminal',
#   'E',
#   'Miami',
#   'still',
#   'worst',
#   'smelly',
#   'airport',
#   'ever',
#   'Thanks',
#   'nothing'],
#  ['united',
#   'great',
#   'decision',
#   'making',
#   'skill',
#   'flight',
#   'ops',
#   'IAH',
#   'bag',
#   'make',
#   '10',
#   'minute',
#   'connection',
#   "n't",
#   'flight',
#   'pushed',
#   'early',
#   'Disappointed'],
#  ['JetBlue', 'checked', 'yesterday', 'looked', 'like', 'something', 'change'],
#  ['united', 'weighed', '45.5', 'checked', 'bag'],
#  ['USAirways',
#   'check',
#   'online',
#   'state',
#   'status',
#   'closed',
#   'mean',
#   'yet',
#   'able',
#   'reach',
#   'live',
#   'person',
#   '...'],
#  ['united',
#   'asked',
#   'DM',
#   'ignore',
#   'Please',
#   'assist',
#   'changing',
#   'another',
#   'flight',
#   'today-',
#   '21',
#   'Feb',
#   'fra',
#   'mco',
#   'avoiding',
#   'IAD'],
#  ['AmericanAir',
#   'AmericanAirlines',
#   'approach',
#   'mex',
#   '....',
#   'http',
#   '//t.co/se57dmjHiW'],
#  ['united',
#   'amp',
#   'finally',
#   'told',
#   'couldnt',
#   'use',
#   'front',
#   'plane',
#   'restrm',
#   'row7',
#   'though',
#   'myself/others',
#   'row',
#   'behind',
#   'used',
#   'w/no',
#   'issue'],
#  ['AmericanAir',
#   'earlier',
#   'flight',
#   'SAP-',
#   'gt',
#   'Mia',
#   'amp',
#   'Mia',
#   'gt',
#   'New',
#   'York',
#   'lga',
#   '03.03',
#   "'m",
#   'currently',
#   'booked',
#   'flight',
#   '1504',
#   '1102'],
#  ['united',
#   'last',
#   'night',
#   'waited',
#   'forever',
#   'gate',
#   'someone',
#   'corporate',
#   'dispatch',
#   'FORGOT',
#   'call',
#   'crew',
#   'unfriendlyskies'],
#  ['united',
#   'SERIOUSLY',
#   "'s",
#   '2015',
#   'WiFi',
#   '5hr',
#   'flight',
#   'CLE-SFO',
#   '1589',
#   "'re",
#   'airline',
#   'without',
#   'WiFi',
#   '...'],
#  ['united',
#   'told',
#   'changed',
#   'flight',
#   'im',
#   'ottawa',
#   'airport',
#   'AC',
#   'cant',
#   'find',
#   'reservation',
#   'Whats',
#   'wrong'],
#  ['“',
#   'JetBlue',
#   'Analystdoc',
#   'Unfortunately',
#   "'s",
#   'available',
#   'option',
#   'current',
#   'system',
#   'Sorry',
#   'guy',
#   "'s",
#   'certain',
#   'fail',
#   'Fix',
#   'plz'],
#  ['united',
#   "n't",
#   'need',
#   'apology',
#   'need',
#   'bag',
#   'Took',
#   '56',
#   'minute',
#   'landing',
#   'get',
#   'Unacceptable'],
#  ['AmericanAir',
#   'See',
#   'photo',
#   'B787',
#   'scale',
#   'model',
#   'amp',
#   'PN',
#   '320008A',
#   'wheel',
#   'deflator',
#   'specified',
#   'Chapter',
#   '32',
#   'B787',
#   'AMM',
#   'http',
#   '//t.co/kfD4WQRkLW'],
#  ['united',
#   'flying',
#   'STL',
#   'Saturday',
#   'expecting',
#   'ice',
#   'amp',
#   'snow',
#   'start',
#   'looking',
#   'travel',
#   'waiver',
#   'Thanks'],
#  ['AmericanAir', 'thanks', 'getting', 'back', 'find', 'airline', 'future'],
#  ['VirginAmerica', 'know', 'Need', 'spotify', 'stat', 'guiltypleasures'],
#  ['united',
#   'patient',
#   'luxurious',
#   'middle',
#   'seat',
#   'next',
#   'delayed',
#   'flight'],
#  ['USAirways',
#   '4',
#   'hour',
#   'tarmac',
#   'Charleston',
#   'still',
#   'ca',
#   "n't",
#   'get',
#   'response',
#   'week',
#   'Unacceptable'],
#  ['SouthwestAir',
#   "'s",
#   'happened',
#   'customer',
#   'service',
#   '2',
#   'Cancelled',
#   'Flightled',
#   'flight',
#   '2',
#   'day',
#   'amp',
#   'uninformed',
#   'unapologetic',
#   'staff',
#   'nolove',
#   'cali'],
#  ['united',
#   '777',
#   'SFO',
#   'HNL',
#   'ZERO',
#   'entertainment',
#   'system',
#   'youareonyourown'],
#  ['AmericanAir',
#   '3078',
#   'overweight',
#   'pull',
#   '2',
#   'dozen',
#   'passenger',
#   'luggage',
#   'Seriously'],
#  ['JetBlue',
#   'disappointed',
#   'flight',
#   'back',
#   'boston',
#   'PR',
#   'Cancelled',
#   'Flightled',
#   'rebooked',
#   '4',
#   'next',
#   'day',
#   'delayed',
#   'one',
#   'compensation'],
#  ['united', 'better', 'customer', 'service', 'John', 'Wayne', 'airport'],
#  ['AmericanAir',
#   'waiting',
#   'delayed',
#   'plane',
#   'sat',
#   'plane',
#   'hour',
#   'waiting',
#   'Late',
#   'Flight',
#   'passenger',
#   "'s",
#   'BS',
#   '..'],
#  ['united', 'always', 'Helps', 'communicate', 'customer'],
#  ['united',
#   "'re",
#   'customer',
#   'service',
#   'unbelievably',
#   'bad',
#   'Abysmal',
#   "'ve",
#   'phone',
#   'well',
#   '2hrs',
#   'tonight',
#   'Hung',
#   'yr',
#   'ppl',
#   '3x'],
#  ['SouthwestAir',
#   '3rd',
#   'time',
#   'flying',
#   'southwest',
#   'two',
#   'year',
#   'another',
#   'trip',
#   'back',
#   'mx',
#   'October'],
#  ['AmericanAir', 'Priority', 'baggage', 'evidently', 'mean', 'come', 'last'],
#  ['united',
#   'mention',
#   'one',
#   'bag',
#   'infant',
#   'car',
#   'seat',
#   'amp',
#   "'ve",
#   'stuck',
#   'yr',
#   'poor',
#   'replacement',
#   'icy',
#   'mtn',
#   'road'],
#  ['united', 'thanks', 'checking'],
#  ['AmericanAir',
#   'understand',
#   "'m",
#   'even',
#   'put',
#   'hold',
#   'say',
#   '``',
#   'try',
#   'Late',
#   'Flightr',
#   'goodbye',
#   "''"],
#  ['united',
#   'wo',
#   "n't",
#   'check',
#   'carry',
#   'Watched',
#   'handler',
#   'throw',
#   'bag',
#   '--',
#   'miss',
#   'conveyer',
#   'belt',
#   '--',
#   'sat',
#   '10',
#   'min',
#   'http',
#   '//t.co/lyoocx5mSH'],
#  ['SouthwestAir',
#   'rerouted',
#   'bf',
#   "'s",
#   'flight',
#   "'s",
#   'diabetic',
#   'little',
#   'insulin',
#   'even',
#   'though',
#   'tried',
#   'change',
#   'agent',
#   'would',
#   "n't"],
#  ['AmericanAir',
#   "'s",
#   'lot',
#   'talk',
#   'MIA-SFO',
#   '20+',
#   'year',
#   'old',
#   'plane',
#   'nonewplanes',
#   'old',
#   'shame',
#   'http',
#   '//t.co/TwETPXUpPN'],
#  ['AmericanAir',
#   'flight',
#   'dca',
#   'need',
#   'change',
#   'asap',
#   'help',
#   'ca',
#   "n't",
#   'get'],
#  ['united',
#   'change',
#   'Way',
#   'stick',
#   'Premiere',
#   '1K',
#   'loyal',
#   'customer',
#   'make',
#   'thing',
#   'harder',
#   'loyal'],
#  ['USAirways',
#   'ok',
#   '...',
#   'know',
#   'door',
#   'close',
#   '~10',
#   'minute',
#   'takeoff',
#   'stop',
#   'telling',
#   'flight',
#   'leave',
#   '20',
#   'minute',
#   "n't",
#   'boarded'],
#  ['united', 'hope', 'see', 'issue', 'return', 'flight', 'tomorrow'],
#  ['united', 'customer', 'service', '👎'],
#  ['USAirways',
#   'wife',
#   'sick',
#   '3yr-old-twins',
#   'waiting',
#   'line',
#   '2hrs',
#   'see',
#   'agent',
#   'Phone',
#   'agent',
#   'said',
#   'nothing',
#   'til',
#   'Tuesday'],
#  ['JetBlue',
#   'ruining',
#   'vacation',
#   'left',
#   'right',
#   'would',
#   'thought',
#   'airline',
#   'Cancelled',
#   'Flight',
#   'ticket',
#   'without',
#   'telling',
#   'buyer'],
#  ['SouthwestAir',
#   'Guys',
#   "'ve",
#   'got',
#   'something',
#   'inability',
#   'check',
#   'online',
#   'international',
#   'flight',
#   '...',
#   '1/2'],
#  ['USAirways',
#   'Seriously',
#   'flight',
#   'delay',
#   'Cinci',
#   'Philly',
#   'due',
#   'new',
#   'ground',
#   'staff',
#   'miss',
#   'connection',
#   'MAN',
#   'UK',
#   'argue',
#   'hotel',
#   'WTF'],
#  ['united',
#   'line',
#   'Denver',
#   'rebook',
#   'due',
#   'weather',
#   'issue',
#   'BETTER',
#   'http',
#   '//t.co/tmccExYaaQ'],
#  ['USAirways',
#   'redeem',
#   'pas',
#   'admiral',
#   'club',
#   '1',
#   'free',
#   'visit',
#   'barclay',
#   'card',
#   'membership',
#   'bring',
#   'companion'],
#  ['USAirways', 'FAILINGYOURCUSTOMER', 'ONE', 'ONE'],
#  ['JetBlue',
#   'guy',
#   'continue',
#   'impress',
#   'crew',
#   'MCO',
#   'gate',
#   '4helped',
#   'family',
#   'seat',
#   'issue',
#   'professional'],
#  ['SouthwestAir',
#   "n't",
#   'charge',
#   'ticket',
#   'change',
#   'fee',
#   'incur',
#   'mysterious',
#   '``',
#   'cost',
#   "''",
#   'incur',
#   'united'],
#  ['AmericanAir', 'taking', 'call', 'need', 'change', 'flight'],
#  ['USAirways',
#   'flight',
#   '1735',
#   'sitting',
#   'fully',
#   'loaded',
#   'hour',
#   'Air',
#   'conditioning',
#   'barely',
#   'working'],
#  ['JetBlue',
#   'dropping',
#   'passenger',
#   'small',
#   'baby',
#   '3',
#   'infant',
#   'San',
#   'Juan',
#   'terminal',
#   'unloading',
#   'baby',
#   'officer',
#   'writes',
#   'ticket',
#   '75'],
#  ['SouthwestAir',
#   'continue',
#   'amazed',
#   'amazing',
#   'customer',
#   'service',
#   'Thank',
#   'SWA'],
#  ['SouthwestAir',
#   'hilarious',
#   'flight',
#   'attendant',
#   'Vegas',
#   'Detroit',
#   'tonight',
#   'http',
#   '//t.co/nw7vx7DGMF'],
#  ['AmericanAir',
#   'people',
#   'cruel',
#   'stupid',
#   'posting',
#   'personal',
#   'email',
#   'damn',
#   'Internet',
#   'u',
#   'lost',
#   'mind'],
#  ['AmericanAir', 'narrowly', 'made', 'standby', '...', 'lot', 'snag', 'trip'],
#  ['SouthwestAir', 'Thank', 'thankful', 'feelingtheluv'],
#  ['AmericanAir',
#   'Took',
#   'flight',
#   'yesterday',
#   'fron',
#   'TPA-DFW-AUS',
#   'Bag',
#   'went',
#   'IAH',
#   'Today',
#   'bag',
#   'went',
#   'IAH-DFW',
#   'back',
#   'IAH',
#   'Still',
#   'bag'],
#  ['AmericanAir',
#   'one',
#   'agent',
#   'helping',
#   'stagnant',
#   'line',
#   'almost',
#   '100',
#   'customer',
#   'Super'],
#  ['SouthwestAir',
#   'pair',
#   'ticket',
#   'Imaginedragons',
#   'show',
#   'Atlanta',
#   "'d",
#   'love',
#   'go',
#   'DestinationDragons'],
#  ['SouthwestAir',
#   'got',
#   '``',
#   'duped',
#   "''",
#   'w/',
#   'connection',
#   '1st',
#   'flight',
#   'sneaky',
#   'u',
#   'wo',
#   "n't",
#   'give',
#   'seat',
#   'earlier',
#   'flight',
#   'w/',
#   'availability',
#   'Shameful'],
#  ['SouthwestAir', 'really', 'gon', 'na', 'hear', 'mouth', 'bag', 'situation'],
#  ['virginamerica',
#   'phone',
#   'number',
#   'ca',
#   "n't",
#   'find',
#   'call',
#   'flight',
#   'reservation'],
#  ['USAirways',
#   'Thanks',
#   'would',
#   'better',
#   'gate',
#   'agent',
#   'C14',
#   'Charlotte',
#   'boarding',
#   'flight',
#   '1791'],
#  ['JetBlue', 'always', 'pleasure', '☺️'],
#  ['USAirways',
#   'USAirways',
#   'disappoints',
#   'Cancelled',
#   'Flighted',
#   'flight',
#   'Missed',
#   'appointment',
#   'Promised',
#   'refund',
#   'lie'],
#  ['united',
#   'ca',
#   "n't",
#   'get',
#   'anyone',
#   'deal',
#   'person',
#   'Cowardly',
#   'customer',
#   'service',
#   'ca',
#   "n't",
#   'looked',
#   'eye',
#   'anyone'],
#  ['AmericanAir',
#   'something',
#   'wrong',
#   'website',
#   'matter',
#   'flight',
#   'select',
#   'say',
#   "'s",
#   'longer',
#   'available'],
#  ['SouthwestAir',
#   'multiple',
#   'attempt',
#   'finally',
#   'able',
#   'submit',
#   'Late',
#   'Flight',
#   'last',
#   'night'],
#  ['SouthwestAir',
#   'broke',
#   'stroller',
#   'wife',
#   'baby',
#   'gate',
#   'checked',
#   'told',
#   "'s",
#   'problem',
#   'Calling',
#   'List',
#   'Preferred',
#   'line'],
#  ['JetBlue',
#   'unfortunately',
#   'hoping',
#   'catch',
#   'one',
#   'sometime',
#   'near',
#   'future'],
#  ['JetBlue',
#   'mean',
#   'take',
#   'time',
#   'write',
#   'physical',
#   'letter',
#   'fraud',
#   'department',
#   "n't",
#   'email',
#   'telephone',
#   'Right'],
#  ['AmericanAir',
#   'Trip',
#   'cut',
#   '7',
#   'hr',
#   'short',
#   'due',
#   'flight',
#   'change/massive',
#   'layovers/',
#   'peanut',
#   'crackers/',
#   'asked',
#   'H2O',
#   'received',
#   '2oz'],
#  ['united', 'please', 'follow', 'Dm', 'missing', 'bag'],
#  ['USAirways',
#   'please',
#   'secure',
#   "'footrest",
#   'shelf',
#   'business',
#   'class',
#   'A330',
#   'airplane',
#   'http',
#   '//t.co/ZL4bVEXmcJ'],
#  ['AmericanAir', 'maryella_green', 'received', 'actually', 'Thank'],
#  ['JetBlue', 'Amagrino', 'cover', 'cost', 'car', 'service', 'waiting', 'time'],
#  ['AmericanAir',
#   "'ve",
#   'Cancelled',
#   'Flightled',
#   'flight',
#   'First',
#   'priority',
#   'ticket',
#   'bumped',
#   "'re",
#   'losing',
#   'customer',
#   'People',
#   'furious'],
#  ['AmericanAir',
#   'connect',
#   'person',
#   'without',
#   'wait',
#   '2+',
#   'hour',
#   'hold',
#   'still',
#   "n't",
#   'able',
#   'resolve',
#   'problem'],
#  ['USAirways',
#   "'re",
#   'reservation',
#   'number',
#   'none',
#   'Hungary',
#   'phone',
#   'working',
#   'make',
#   'difficult'],
#  ['SouthwestAir',
#   'checked',
#   'right',
#   '24hr',
#   'mark',
#   'Boarding',
#   'C',
#   'group',
#   'kid',
#   'age',
#   '6',
#   'amp',
#   '8',
#   'dnt',
#   'want',
#   'split',
#   'sld'],
#  ['JetBlue',
#   "'m",
#   'flight',
#   'booze',
#   'served',
#   '30',
#   'min',
#   '...',
#   'give',
#   'lostrevenue',
#   'angryandsober',
#   'bachelorpartymishap'],
#  ['AmericanAir',
#   'sweetmel',
#   'weather',
#   'bad',
#   'would',
#   "n't",
#   'folk',
#   'try',
#   'extra',
#   'hard',
#   'communicate',
#   '...',
#   'load',
#   'bag',
#   'onto',
#   'flight',
#   '1320',
#   '...',
#   '...',
#   'anything'],
#  ['AmericanAir',
#   '4369.',
#   '4',
#   'flight',
#   'using',
#   'gate',
#   'w/buses',
#   'plane',
#   'Awful',
#   'boarding',
#   'process',
#   'Hour',
#   'half',
#   'Late',
#   'Flight'],
#  ['united',
#   'staff',
#   'rather',
#   'efficient',
#   'got',
#   'u',
#   'solution',
#   'freaked',
#   'little',
#   'limbo',
#   'air'],
#  ['united',
#   'flight',
#   'vega',
#   'houston',
#   'Cancelled',
#   'Flighted',
#   'morning',
#   '``',
#   'due',
#   'operation',
#   "''",
#   'mean',
#   'Thank',
#   'god',
#   'woke',
#   'early',
#   'today'],
#  ['USAirways',
#   'PHL',
#   'take',
#   'hour',
#   'offload',
#   'bag',
#   'especially',
#   'taking',
#   '30+',
#   'min',
#   'get',
#   'jetway',
#   'get',
#   'plane',
#   'landing'],
#  ['AmericanAir',
#   "'d",
#   'like',
#   'apologize',
#   'gate',
#   'agent',
#   'flight',
#   'AA76',
#   'aware',
#   'zone',
#   '1',
#   'nine',
#   'precious',
#   'gem'],
#  ['AmericanAir',
#   '4hrs',
#   'Late',
#   'Flightr',
#   'get',
#   'call',
#   'back',
#   'immediately',
#   'disconnected'],
#  ['USAirways',
#   'wo',
#   "n't",
#   'waive',
#   '200',
#   'fee',
#   'due',
#   'neptune',
#   'Ca',
#   "n't",
#   'use',
#   'credit',
#   'w/o',
#   'paying',
#   'fee',
#   'Couldnt',
#   'get',
#   'destination',
#   'use',
#   'tic',
#   'waivethefee'],
#  ['insulting',
#   'USAirways',
#   'AmericanAir',
#   'offer',
#   '``',
#   'non',
#   'required',
#   '50',
#   'voucher',
#   'goodwill',
#   'offering',
#   '..',
#   'least',
#   'bag',
#   'fly',
#   'round',
#   'trip'],
#  ['USAirways',
#   'ca',
#   "n't",
#   'even',
#   'use',
#   'return',
#   'flight',
#   'home',
#   'change',
#   'fee',
#   'charge',
#   'expensive',
#   'forcing',
#   'purchase',
#   'new',
#   'ticket'],
#  ['united', "'m", 'rebooked', 'line', '300', 'people', 'deep'],
#  ['USAirways',
#   'cust',
#   'serv',
#   'rep',
#   'unable',
#   'change',
#   'reservation',
#   'system',
#   'Check',
#   'unaware',
#   'Cancelled',
#   'Flights',
#   'got',
#   'word',
#   'night'],
#  ['united',
#   'give',
#   'service',
#   'terrible',
#   "n't",
#   'forced',
#   'use',
#   'United',
#   'certain',
#   'route',
#   'never',
#   'would'],
#  ['SouthwestAir',
#   'get',
#   'kind',
#   'update',
#   'delayed',
#   'flight',
#   'Boston',
#   'Houston',
#   '7:30',
#   'Really',
#   'need',
#   'back',
#   'home',
#   'tonight'],
#  ['SouthwestAir',
#   'impression',
#   '8',
#   'hour',
#   'delay',
#   'flight',
#   'equipment',
#   'failure',
#   'compensation',
#   'offered'],
#  ['SouthwestAir',
#   'Looks',
#   'like',
#   "'On",
#   'February',
#   '19',
#   '2015',
#   'open',
#   'schedule',
#   'sale',
#   'October',
#   '30',
#   '2015',
#   'know',
#   'time'],
#  ['AmericanAir',
#   'would',
#   'appreciated',
#   'please',
#   "n't",
#   'send',
#   'page',
#   'long',
#   'form',
#   'amp',
#   'limited',
#   'character',
#   'Direct',
#   'email'],
#  ['USAirways', 'email'],
#  ['united',
#   'diverted',
#   'missed',
#   'connecting',
#   'flight',
#   'told',
#   'bag',
#   "'s",
#   'way',
#   'MSY',
#   'people',
#   'cared'],
#  ['united', 'need', 'assistance', 'Line', 'door', 'travelling', '3', 'kid'],
#  ['united',
#   '100',
#   'put',
#   'together',
#   'serious',
#   'email',
#   'issue',
#   'arose',
#   'vacation',
#   'due',
#   'staff',
#   'post'],
#  ['AmericanAir',
#   'upon',
#   'entering',
#   'plane',
#   '2',
#   'USAirways',
#   'stewardess',
#   '``',
#   'water',
#   "''",
#   '``',
#   "n't",
#   'please',
#   'take',
#   'seat',
#   "''"],
#  ['JetBlue',
#   'amount',
#   'money',
#   'spent',
#   'hotel',
#   'WEEK',
#   'bc',
#   'flight',
#   'Cancelled',
#   'Flightlation',
#   'another',
#   'flight',
#   "n't",
#   'make',
#   'money',
#   'lost'],
#  ['USAirways',
#   'Flight',
#   '830',
#   'CLT',
#   'Phl',
#   '1st',
#   'list.Someone',
#   'else',
#   'got',
#   'spot',
#   'Rude',
#   'employee',
#   'coach',
#   'Wouldt',
#   'give',
#   'ID',
#   'Said',
#   'cute',
#   'red',
#   'head'],
#  ['AmericanAir',
#   'thanks',
#   'Bummer',
#   'Poor',
#   'planning',
#   'part',
#   'assume',
#   'card',
#   'Passbook',
#   'wo',
#   "n't",
#   'work',
#   'either'],
#  ['USAirways', 'still', 'cricket', 'customer', 'service'],
#  ['united', '1k', "'m", 'always', 'hoping', 'improvement'],
#  ['AmericanAir',
#   'merger',
#   'USAirways',
#   'usairwis',
#   'cluster',
#   'inefficiency',
#   'misinformation',
#   'going',
#   'done'],
#  ['SouthwestAir', 'much', 'respect'],
#  ['SouthwestAir', 'really', 'easy', 'local', 'get', 'strip', 'book'],
#  ['USAirways',
#   'Charlotte',
#   'Staff',
#   'need',
#   'prayer',
#   '....',
#   'disappointed',
#   'response',
#   'mishap',
#   '......',
#   'lotttttttt',
#   'pissed',
#   'people'],
#  ['SouthwestAir',
#   'unscheduled',
#   'aircraft',
#   'change',
#   'please',
#   'better',
#   'system',
#   'place',
#   'worth',
# ...
#   'GRR',
#   'GEG',
#   'Feb',
#   'Ca',
#   "n't",
#   'find',
#   'online'],
#  ['USAirways',
#   'AskPayPal',
#   'completed',
#   "'s",
#   'case',
#   'still',
#   'say',
#   '``',
#   'progress',
#   "''",
#   'Paypal',
#   "'s",
#   'website',
#   'reserved',
#   '13th'],
#  ['SouthwestAir-',
#   'Wife',
#   "'s",
#   'RR',
#   'pt',
#   'expired',
#   'day',
#   'ago',
#   'planning',
#   'Flight',
#   'Booking',
#   'Problems',
#   'trip',
#   'today',
#   'Anything',
#   'u',
#   'tight',
#   'budget',
#   '...'],
#  ['SouthwestAir',
#   'hold',
#   '45',
#   'minute',
#   'trying',
#   'rebook',
#   'Cancelled',
#   'Flightled',
#   'flight',
#   'companion',
#   'ticket',
#   'Help'],
#  ['USAirways',
#   'worst',
#   'experience',
#   'time',
#   'never',
#   'ever',
#   'ever',
#   'travel',
#   'EVER'],
#  ['AmericanAir',
#   'went',
#   'check',
#   'flight',
#   '24',
#   'hr',
#   'advance',
#   'husband',
#   'seated',
#   'separately',
#   '6hr',
#   'flight',
#   'happen'],
#  ['USAirways', 'GregWallace66', 'Yea', 'give', '5', 'cent', 'dollar'],
#  ['AmericanAir', 'second', 'pic', 'CDG'],
#  ['SouthwestAir', 'thank'],
#  ['united', 'thanks'],
#  ['united', 'okay', 'Thanks'],
#  ['AmericanAir',
#   'really',
#   'appreciate',
#   'great',
#   'customer',
#   'service',
#   '...',
#   'One',
#   'service',
#   'agent',
#   'hung',
#   'asking',
#   'legitimate',
#   'question'],
#  ['SouthwestAir', 'Still', "n't", 'heard', 'thing'],
#  ['AmericanAir',
#   'chariot',
#   'tonight',
#   'angle',
#   'look',
#   'like',
#   '787',
#   'http',
#   '//t.co/3ZZKQWWbJz'],
#  ['USAirways',
#   'flight4592',
#   'LET',
#   'US',
#   'PLANE',
#   'please',
#   'go',
#   'gate',
#   'absurd'],
#  ['JetBlue',
#   'sorry',
#   'specified',
#   'meant',
#   'ground',
#   'traffic',
#   'trying',
#   'get',
#   'terminal'],
#  ['AmericanAir', 'u', 'air', 'point', 'combined'],
#  ['USAirways', 'hold', 'reservation', '30', 'min', 'already', 'worstairline'],
#  ['SouthwestAir', 'contact', 'missing', 'Rapid', 'Rewards', 'credit'],
#  ['JetBlue', "'s", 'poop', 'barely', 'work'],
#  ['USAirways',
#   'still',
#   'rep',
#   'talk',
#   '3',
#   'day',
#   'Late',
#   'Flightr',
#   'U',
#   'r',
#   'asking',
#   'checkin',
#   'flight',
#   'tmrw',
#   'refund',
#   'requested',
#   'Deal',
#   'w'],
#  ['JetBlue', 'haha', 'TY', 'know', 'time', 'lane', 'open', 'Logan'],
#  ['USAirways',
#   'happened',
#   'u',
#   'could',
#   "n't",
#   'get',
#   'u',
#   'home',
#   'next',
#   'day',
#   'flydelta',
#   'flysouthwest',
#   'flyjetblue',
#   'theyareallbetter',
#   'stillnobags'],
#  ['“',
#   'JetBlue',
#   'fleet',
#   "'s",
#   'fleek',
#   'http',
#   '//t.co/tLGoihqkvS',
#   '”',
#   '😐',
#   'make',
#   'stop'],
#  ['JetBlue', 'Customer', 'year', 'http', '//t.co/epqqONHO2H'],
#  ['AmericanAir',
#   'Extend',
#   'rtn',
#   'flight',
#   'bereavement',
#   '22nd',
#   'could',
#   'change',
#   'fee',
#   'dropped',
#   'told',
#   'no.Worse',
#   'day',
#   'life',
#   'badcustomerservice'],
#  ['SouthwestAir',
#   'App',
#   'Updated',
#   'Passbook',
#   'Support',
#   'http',
#   '//t.co/WrWqrUblPs',
#   'via',
#   'ubergizmo'],
#  ['JetBlue',
#   'sooo',
#   'earlier',
#   'said',
#   'couldnt',
#   'fly',
#   'school',
#   'trip',
#   '😏'],
#  ['united', 'took', 'screenshot', 'emailed', 'Let', "'s", 'DM', 'figure'],
#  ['USAirways', 'kidding', 'Oy'],
#  ['USAirways', 'flight', 'full'],
#  ['USAirways',
#   'Stuck',
#   'Philadelphia',
#   'airport',
#   '32',
#   'hour',
#   'due',
#   '``',
#   'maintenance',
#   "''",
#   'Dreading',
#   'flight',
#   'back',
#   'home',
#   'Disgusting'],
#  ['SouthwestAir',
#   'service',
#   'promotion',
#   'moment',
#   'ModeloDeNegocio',
#   'innovation',
#   'innovacion',
#   'BusinessModel'],
#  ['united', 'newest', 'delay', 'right', 'http', '//t.co/96fTLZWtvO'],
#  ['united',
#   'Hello',
#   'United',
#   'take',
#   'care',
#   'call',
#   'center',
#   'Mexico',
#   'City',
#   'Office',
#   'Terrible',
#   'attitude',
#   'lady',
#   'helping'],
#  ['JetBlue',
#   'offer',
#   'service',
#   'Daytona',
#   'Beach',
#   'New',
#   'York',
#   'Albany',
#   'Business',
#   'Review',
#   'http',
#   '//t.co/dUhBJ41jHx'],
#  ['AmericanAir',
#   "'m",
#   'trying',
#   'choose',
#   'seat',
#   'every',
#   'time',
#   'go',
#   'next',
#   'flight',
#   'get',
#   'system',
#   'error'],
#  ['JetBlue',
#   '...',
#   "n't",
#   'heard',
#   'anyone',
#   'week',
#   'nonstop',
#   'flight',
#   'baggage',
#   'lost/stolen',
#   'customer',
#   'service',
#   '👎'],
#  ['JetBlue',
#   "'ve",
#   'delayed',
#   'almost',
#   '2',
#   'hr',
#   'take',
#   'JetBlue',
#   "'ve",
#   'good',
#   'luck',
#   'today',
#   'really',
#   'frustrating'],
#  ['JetBlue',
#   'w/',
#   '70',
#   'upgrade',
#   'Unsure',
#   'ca',
#   "n't",
#   'switch',
#   'someone',
#   'around',
#   'called',
#   '24',
#   'hr',
#   'advance',
#   'reason'],
#  ['JetBlue', 'Great', 'thanks'],
#  ['united',
#   'thank',
#   'getting',
#   'daughter',
#   'home',
#   'americanair',
#   'Cancelled',
#   'Flightled',
#   'flight',
#   'Nashville'],
#  ['united',
#   'yes',
#   '...',
#   'ride',
#   'home',
#   'would',
#   'perfect',
#   '..',
#   'fete',
#   'one',
#   'would',
#   'assume',
#   'possible',
#   'charging',
#   '1600',
#   'domestic',
#   'flight',
#   '...',
#   'Ps',
#   'deplaned'],
#  ['SouthwestAir',
#   'Totally',
#   'ruined',
#   'birthday',
#   'weekend',
#   'Cancelled',
#   'Flighting',
#   'flight',
#   'reason',
#   'offer',
#   'point',
#   'drink',
#   'transport',
#   'nolove',
#   'cali'],
#  ['united',
#   'nope',
#   'need',
#   'little',
#   'red',
#   'stamp',
#   'counter',
#   'Check',
#   'wreck',
#   'son',
#   'http',
#   '//t.co/0pRGySvuRm'],
#  ['united', 'referral', 'program', 'Milageplus', 'explorer', 'card'],
#  ['AmericanAir',
#   'guy',
#   'fail',
#   '..',
#   'need',
#   'use',
#   'voucher',
#   'ticket',
#   'ca',
#   "n't",
#   'online',
#   'yourphonesystemsucks'],
#  ['SouthwestAir',
#   'look',
#   'like',
#   '1',
#   'yr',
#   'anni',
#   'trip',
#   'replaced',
#   'w',
#   'someone',
#   "'s",
#   'itinerary',
#   'Worried',
#   'abt',
#   'c',
#   'flight',
#   'http',
#   '//t.co/BApE6RuMNE'],
#  ['AmericanAir',
#   'thanks',
#   'finally',
#   'letting',
#   'get',
#   'book',
#   'flight',
#   'Frustration',
#   'set',
#   '...',
#   'donedeal',
#   'talktoahuman'],
#  ['united',
#   'took',
#   'one',
#   'window',
#   'Also',
#   'fun',
#   'get',
#   'motion',
#   'sick',
#   'http',
#   '//t.co/m81rV0blxs'],
#  ['JetBlue', 'keep', 'getting', 'better', 'water', 'plane'],
#  ['JetBlue', 'thank', 'Hopefully', "'s", 'soon', 'supposed', 'leave', '11:23'],
#  ['united',
#   'Thank',
#   "y'all",
#   'amazing',
#   'airline',
#   'know',
#   'treat',
#   'customer',
#   'guy',
#   'rock'],
#  ['SouthwestAir',
#   'sent',
#   'looking',
#   'functionality',
#   'app',
#   'though',
#   'one',
#   'click',
#   'action'],
#  ['AmericanAir',
#   'need',
#   'help',
#   'record',
#   'locator',
#   'bringing',
#   'TWO',
#   'different',
#   'flight',
#   'system',
#   'One',
#   'op',
#   'AA',
#   'amp',
#   'one',
#   'US',
#   'Airways'],
#  ['JetBlue',
#   "'s",
#   'okay',
#   '...',
#   "'m",
#   'actually',
#   'tea',
#   'kinda',
#   'guy',
#   'anyway',
#   'Thanks'],
#  ['united',
#   'Held',
#   'almost',
#   '45',
#   'minute',
#   'promised',
#   'free',
#   'movie',
#   "n't",
#   'work',
#   'neither',
#   'wifi',
#   'paid',
#   'Boo'],
#  ['AmericanAir',
#   "'s",
#   'baggage',
#   'handler',
#   'calling',
#   'DFW',
#   'today',
#   'luggage',
#   'onboard',
#   'plane'],
#  ['USAirways',
#   'would',
#   'go',
#   'though',
#   'entire',
#   'process',
#   'get',
#   'people',
#   'phone',
#   'usairwayssucks'],
#  ['USAirways', 'crazy', 'Treated', 'mom', 'poorly', 'happy', 'usairwaysfail'],
#  ['SouthwestAir', 'many', 'left'],
#  ['USAirways',
#   'work',
#   'hard',
#   'making',
#   'sure',
#   'thing',
#   'flow',
#   'smoothly',
#   'Keeping',
#   'positive'],
#  ['USAirways',
#   "n't",
#   'blame',
#   'weather',
#   'Rep',
#   'counter',
#   'cost',
#   'entire',
#   'day',
#   'weather',
#   'Printed',
#   'Boarding',
#   'Pass',
#   'Late',
#   'Flight',
#   'TakeResponsibility'],
#  ['united',
#   'thanks',
#   'updating',
#   '1+',
#   'hour',
#   'delay',
#   'exact',
#   'second',
#   'got',
#   'ATL',
#   '🙅🙅🙅'],
#  ['united',
#   'considered',
#   '``',
#   'time',
#   "''",
#   "'s",
#   'arriving',
#   'destination',
#   'half',
#   'hour',
#   'Late',
#   'Flightr',
#   'scheduled',
#   'http',
#   '//t.co/YMFTw1uyHr'],
#  ['AmericanAir',
#   'rebooked',
#   "n't",
#   'get',
#   'notified',
#   'Cancelled',
#   'Flightled'],
#  ['USAirways',
#   'ShoutOut',
#   '2',
#   'Kristie',
#   'sp',
#   'Gate4',
#   'PVD',
#   'today',
#   "'s",
#   'RockStar',
#   'tremendous',
#   'help',
#   'tough',
#   'situation',
#   'PromoteThatGirl'],
#  ['united',
#   'check-in',
#   'luggage',
#   'Employee',
#   'told',
#   'include',
#   'wheel',
#   'dimension'],
#  ['united', '25', 'minute', 'hold', '1', 'hr', '25', 'min', 'ABC11_WTVD'],
#  ['USAirways', 'guy', 'screwing', 'trip', 'Thanks', 'nothing', 'lazy'],
#  ['united',
#   'passenger',
#   'waited',
#   'inside',
#   'flight',
#   'runway',
#   'returned',
#   'back',
#   'gate',
#   'count',
#   'valid',
#   'journey'],
#  ['USAirways',
#   'Frustrating',
#   'day',
#   'flight',
#   'home',
#   'changed',
#   'airline',
#   'Thank',
#   'PHL',
#   'USAirway',
#   'employee',
#   'amp',
#   'united',
#   'help',
#   'getting',
#   'back',
#   'IAH'],
#  ['united',
#   'u',
#   'guy',
#   'changed',
#   'age',
#   'double',
#   'booked',
#   'seat',
#   "'ve",
#   'even',
#   'though',
#   'platinum',
#   'person',
#   'none'],
#  ['USAirways',
#   'Cancelled',
#   'Flightled',
#   'last',
#   'part',
#   'ticket',
#   'confused',
#   'email',
#   'received',
#   'whether',
#   'value',
#   'remains',
#   'someone',
#   'ask'],
#  ['united',
#   'business',
#   'decision',
#   'made',
#   'inconvenience',
#   'possibly',
#   'cause',
#   'lost',
#   'customer',
#   'good',
#   'business',
#   'decision',
#   'Cranky'],
#  ['USAirways',
#   'flight',
#   'got',
#   'Cancelled',
#   'Flightled',
#   'Charlotte',
#   'hold',
#   'hour',
#   'pls',
#   'pick'],
#  ['VirginAmerica', 'wow', 'blew', 'mind'],
#  ['AmericanAir',
#   'AA2416',
#   'time',
#   'awesome',
#   'flight',
#   'Great',
#   'job',
#   'American'],
#  ['SouthwestAir', "n't", 'realize', 'clothes', 'hotel', 'suggestion'],
#  ['SouthwestAir', 'got', 'mine', 'time', 'wife', '15th', 'anniversary'],
#  ['“',
#   'SouthwestAir',
#   'pancho_joe',
#   'must',
#   "'ve",
#   'heard',
#   'u',
#   'wrong',
#   'Sweet',
#   'mixtape',
#   'though',
#   "''",
#   '4',
#   'record',
#   "n't",
#   'leave',
#   '80',
#   "'s",
#   '80',
#   "'s",
#   'left'],
#  ['AmericanAir',
#   'Sitting',
#   'gate',
#   'Flight',
#   '719',
#   'hour',
#   'due',
#   'Sabre',
#   'backup',
#   'plan',
#   'place',
#   'Sabre',
#   'fixed'],
#  ['SouthwestAir',
#   'favorite',
#   'airline',
#   "'ve",
#   'never',
#   'issue',
#   'Plus',
#   'crew',
#   'entertaining'],
#  ['USAirways', 'made', 'Thanks', 'help'],
#  ['USAirways',
#   'utterly',
#   'unreliable',
#   "n't",
#   'schedule',
#   'pilot',
#   'US624',
#   'flight',
#   'Seattle',
#   'flight',
#   'delayed',
#   'usairwaysfail'],
#  ['southwestair',
#   'TREMENDOUS',
#   'job',
#   'Atlanta',
#   'Airport',
#   'saw',
#   'SW',
#   'celebrate',
#   'Mardi',
#   'Gras',
#   'Another',
#   'reason',
#   "'m",
#   'nut',
#   'guy',
#   'http',
#   '//t.co/8WBzOrRn3C'],
#  ['united',
#   'seems',
#   'like',
#   'one',
#   'United',
#   'help',
#   'Lots',
#   'finger',
#   'pointed',
#   'zero',
#   'people',
#   'stepping',
#   'least',
#   'gate',
#   'Oreos'],
#  ['SouthwestAir', '8FKQW', 'conf', 'Thanks', 'reply'],
#  ['united',
#   'rebooked',
#   '24',
#   'hour',
#   'original',
#   'flight',
#   'say',
#   'handling',
#   'situation',
#   'bad',
#   'would',
#   'understatement'],
#  ['AmericanAir',
#   'flight',
#   'leaving',
#   'Dallas',
#   'right',
#   'Maui',
#   'trying',
#   'figure',
#   'delayed',
#   'flight',
#   '7',
#   'going'],
#  ['SouthwestAir', 'One', 'heck', 'airline', 'http', '//t.co/CyoOnZfTdC'],
#  ['SouthwestAir',
#   'flying',
#   'flight',
#   '3130',
#   'tonight',
#   '7:20',
#   'PBI-',
#   'boarding',
#   'position',
#   'C-42',
#   'overbooked',
#   'Really',
#   "n't",
#   'want',
#   'bumped'],
#  ['JetBlue',
#   'Clients',
#   'got',
#   'ZERO',
#   '32',
#   'year',
#   'career',
#   'never',
#   'thought',
#   'possible.2',
#   'suitcase',
#   'worth',
#   'thousand',
#   'Italian',
#   'clothing',
#   'robbed'],
#  ['USAirways', 'Cancelled', 'Flightled', 'flight', '...', 'paying', 'hotel'],
#  ['AmericanAir',
#   'response',
#   'incredible',
#   'Truly',
#   'amazed',
#   'step',
#   'taken',
#   'enhance',
#   'customer',
#   'relation',
#   'Big',
#   'thank',
#   '😄'],
#  ['AmericanAir',
#   'wow',
#   'Regina',
#   'told',
#   'ca',
#   "n't",
#   'file',
#   'request',
#   'lost',
#   'bag',
#   'statement',
#   'finish',
#   'travel',
#   'get',
#   'DC',
#   'argg'],
#  ['united',
#   'since',
#   'international',
#   'connection',
#   '9am',
#   "'m",
#   'hoping',
#   'thing'],
#  ['JetBlue', 'day'],
#  ['united',
#   'long',
#   'take',
#   'mile',
#   're-purchased',
#   'expired',
#   'show',
#   'recieved',
#   'email',
#   'request',
#   '..'],
#  ['united',
#   'probably',
#   'least',
#   'satisfactory',
#   'airline',
#   "'ve",
#   'ever',
#   'Never',
#   'fails',
#   'disappoint'],
#  ['United',
#   'Airlines',
#   'Changing',
#   'MileagePlus',
#   'Program',
#   'Winners',
#   'Losers',
#   'http',
#   '//t.co/F1yvAiO9ul',
#   'http',
#   '//t.co/vGlx6Ykwqg'],
#  ['AmericanAir',
#   'SeguineJ',
#   'AA',
#   'joke',
#   'right',
#   'line',
#   "n't",
#   'even',
#   'accepting',
#   'call',
#   'right',
#   'hang'],
#  ['united',
#   'nonrefundable',
#   'hence',
#   'wrote',
#   '200',
#   "n't",
#   'make',
#   'sense',
#   '150',
#   'credit',
#   'nothanks'],
#  ['JetBlue',
#   'Even',
#   '5',
#   'year',
#   'earthquake',
#   '...',
#   'Haiti',
#   'still',
#   'need',
#   'help',
#   'rebuilding',
#   'flyingitforward'],
#  ['USAirways',
#   'despite',
#   'mechanical',
#   'issue',
#   'many',
#   'delay',
#   'followed',
#   'Cancelled',
#   'Flightlation',
#   'still',
#   'getting',
#   'Vegas',
#   'thanks',
#   'great',
#   'gate',
#   'agent'],
#  ['JetBlue', 'excuse', 'though', '3', 'gate', 'change', 'though'],
#  ['JetBlue',
#   'may',
#   'need',
#   '40',
#   'minute',
#   'layover',
#   '15',
#   'min',
#   'delay',
#   'first',
#   'flight'],
#  ['united', 'get', 'reimbursed', 'hotel', 'taxi', 'Cancelled', 'Flightation'],
#  ['AmericanAir',
#   'yet',
#   'receive',
#   'assistance',
#   'one',
#   'agent',
#   'securing',
#   'new',
#   'connection',
#   'Many',
#   'miss',
#   'work',
#   'tomorrow'],
#  ['USAirways',
#   'British_Airways',
#   'three',
#   'hour',
#   'flight',
#   'delay',
#   'phone',
#   '45min',
#   'counting'],
#  ['AmericanAir', '2298', 'Everyone', 'else', 'outstanding'],
#  ['united',
#   'think',
#   'rough',
#   'moment',
#   'w/',
#   'bad',
#   'passenger',
#   'earlier',
#   'flight',
#   'Things',
#   'got',
#   'considerably',
#   'better',
#   'Thanks'],
#  ['USAirways', 'thanks'],
#  ['AmericanAir',
#   'Cancelled',
#   'Flightled',
#   'ticket',
#   'taking',
#   'two',
#   'month',
#   '++',
#   'refund',
#   'still',
#   'waiting'],
#  ['USAirways', '’'],
#  ['USAirways',
#   'shout',
#   'pilot',
#   'FC',
#   'attendant',
#   'Eliz',
#   'US',
#   '673',
#   'Super',
#   'strong',
#   'crosswind',
#   'landing',
#   'Eliz',
#   'super',
#   'job',
#   'throughout'],
#  ['united',
#   'see',
#   'coming',
#   'get',
#   'AggieMensGolf',
#   'Hawaii',
#   '12thMan',
#   'http',
#   '//t.co/G8DKa3Edhf'],
#  ['AmericanAir', 'dfwairport', '2', 'together', 'best', 'part', 'flying'],
#  ['united',
#   'Late',
#   'Flight',
#   'future',
#   'flight',
#   'train',
#   'staff',
#   'better',
#   'handle',
#   'emergency',
#   'situation',
#   'ground',
#   'staff',
#   'Customer',
#   'Service'],
#  ['united', 'oh', 'united', 'much', 'despise', 'thee'],
#  ['United',
#   'Airlines',
#   'CEO',
#   'Jeff',
#   'Smisek',
#   'Disloyal',
#   'Loyal',
#   'Workers',
#   'http',
#   '//t.co/0cevY3P42b',
#   'via',
#   'HuffPostBiz'],
#  ['united',
#   '3/10',
#   'disappointed',
#   'service',
#   'missing',
#   'connection',
#   'hour',
#   'delay',
#   'cramped',
#   'seat',
#   'least',
#   'app',
#   'good'],
#  ['AmericanAir',
#   'sit',
#   'airport',
#   'long',
#   'periolodicly',
#   'time',
#   'plane',
#   'nasty'],
#  ['united', '618', 'flight', 'Houston'],
#  ['united', 'fuck', 'caring', '😢'],
#  ['SouthwestAir',
#   'info',
#   'DestinationDragons',
#   'winner',
#   'announced',
#   'amp',
#   'best',
#   'friend',
#   'hoping',
#   'win',
#   'thanks'],
#  ['SouthwestAir', 'Thanks'],
#  ['SouthwestAir',
#   'tweet',
#   'weekend/',
#   'bad',
#   'weather',
#   'close',
#   'customer',
#   'relation',
#   'center',
#   'process',
#   'refund',
#   'Cancelled',
#   'Flighted',
#   'flight'],
#  ['SouthwestAir',
#   'missing',
#   '6,000',
#   'point',
#   'one',
#   'account',
#   "'re",
#   'spread',
#   'four',
#   'assuming',
#   'create',
#   'account'],
#  ['united',
#   'used',
#   'committed',
#   'ContinentalAirlines',
#   'flyer',
#   'merger',
#   'remember',
#   'switched',
#   'SouthwestAir',
#   'CommunicationFail'],
#  ['united', 'soon', 'done', 'article', 'Thanks', '~Tom'],
#  ['AmericanAir',
#   "'re",
#   'finding',
#   'bc',
#   'united',
#   'rebooked',
#   'u',
#   'airline',
#   'realized',
#   'could',
#   "n't",
#   'get',
#   'u',
#   'home',
#   "'re",
#   'ORD'],
#  ['USAirways', 'gave', 'http', '//t.co/2eDgc6TbLs'],
#  ['USAirways',
#   'ticket',
#   'couldnt',
#   'used',
#   'bc',
#   'unable',
#   'get',
#   'departing',
#   'dest',
#   'RSW',
#   'bc',
#   'blizzard',
#   'BOS',
#   'Told',
#   'way',
#   'use',
#   'credit',
#   '200',
#   'fine'],
#  ...]

# %%
x_train3=[' '.join(doc) for doc in x_train2]

# %%
x_train3
# Out:
# ['SouthwestAir scheduled morning 2 day fact yes .. sure evening flight one Cancelled Flightled',
#  'SouthwestAir seeing worker time time going beyond love flying guy Thank',
#  'united Flew ORD Miami back great crew service leg THANKS',
#  "SouthwestAir dultch97 's horse radish 😤🐴",
#  'united flight ORD delayed Air Force One last flight SBN 8:20 5 min landed',
#  'united load u flying sardine knew pilot 2 hour Late Flight incompetent beyond belief',
#  "JetBlue stock response Delays frustrating poor cust serv amp told 3 ppl wait amp 'd come back",
#  "JetBlue 'd nice Hoping rack enough mile take trip Seattle enjoy perfect latte city coffee",
#  'united frankly worse customer service ever Problems happen deal defines company Never United',
#  "SouthwestAir yeah haha Never one 's expensive 😂😂 much fun destinationdragons",
#  "SouthwestAir MCO- gt DCA flight almost full people screwed MSY-DCA Cancelled Flightation united USAirways n't Cancelled Flight SWA=mistake",
#  "JetBlue 's easiest way get ticket receipt get one check get one online Thanks",
#  'USAirways love change lounge cheese veggie olive addition cracker snack mix',
#  'SouthwestAir receive bad customer service ended spending several hundred dollar accommodate family cxl flight',
#  "USAirways 're killing sche flight board 3 min mine arrived gate side airport genious",
#  "USAirways 8 week refund ticket 0372389047497 totally unacceptable Fix 'll put blast social medium TV",
#  'AmericanAir private msg provide detail ... u really need customer svc training staff',
#  "RT JetBlue fleet 's fleek http //t.co/413GiAL0yl",
#  'JetBlue info flight 704 SJU JFK already delayed 2 1/2 hour',
#  "AmericanAir 've tried le 8 time today get touch service desk beginning 8:30 EST 'm luck -help",
#  "USAirways new problem ... wrong last name reservation airway fixed New ca n't get TSA",
#  'SouthwestAir possible chance SWA bringing back service LGA-BWI would make much easier connect west coast',
#  'USAirways AmericanAir run show airport boarding pas say u airway wait American line yousuck',
#  "united computer stopped giving update took flight info app 's ridiculous keep people updated",
#  'united good fly United businessFirst',
#  'united flying msp dxb child turn 2 trip buy return ticket child',
#  'JetBlue love Cancelled Flightling ticket telling customer flyunited',
#  'united ORD waited 20 min crew member left gate item came Flight attendant sarcastically said good luck walked away',
#  'SouthwestAir Jason 108639 Gate 3 SAN made afternoon southwestairlines stellarservice thanks',
#  'AmericanAir everything sorted Thanks help Excited get home tonight',
#  'AmericanAir understand weather would nice hear apology phone moved flight inconvenient day',
#  'SouthwestAir thanks',
#  "united 's booked first class curbside delivery 24 hour 'm counting TeamUSA",
#  "JetBlue Oh totally look par AmericanAir 's Admirals Club way slide u couple pass",
#  "AmericanAir 've 15 official complaint signed AmericanAirlines Lima supervisor Customer Relations pls compensate 4 10-hour delay",
#  "JetBlue 4 hour policy- called said n't report soon enough would changed noticed sooner",
#  "united frustrating flying experience One continuous `` dunno time leave today `` Dunno 's code ...",
#  "SouthwestAir Hi got message part flight Cancelled Flightled ca n't rebook online nobody answer phone call Help",
#  'SouthwestAir need update flight 464 amp 3574 hold 2 hour',
#  "USAirways 'm supposed fly Dallas help get new itinerary",
#  'AmericanAir fail flight rdu sitting waiting flight attendant logistics good',
#  'united impressed super-fast reply CGJase',
#  "united n't Spoke baggage contact 1-800 number Said try get bag stay IAD pick tmrw",
#  'USAirways intentionally buy flight 10 hour layover kind airline would charge 200 fix Wow ... usairways',
#  "SouthwestAir auto callback n't wait hold",
#  'united get service desk IAD',
#  "JetBlue blue helped bring color eye promise n't eat free snack",
#  'united Yes therealaviation Instagram',
#  "JetBlue report updated info n't know reach without super long wait hold main number",
#  "JetBlue want enter family pooling contest say `` 2/19 '' website please enter still",
#  'USAirways choose seat free clicking 100 button',
#  'united plus food taxi',
#  'USAirways 3hr30min right ... end sight',
#  "SouthwestAir 're really going let delta virginamerica get best http //t.co/vUdWJm1lYB",
#  'USAirways claim flight Cancelled Flighted due weather destination Delta Cancelled Flighted flight route',
#  'JetBlue thanks much help Us u r amazing',
#  "AmericanAir haha said n't fault somehow guy r joke",
#  "AmericanAir customer service inferior nationalized third world nation 's airline Get together",
#  'AmericanAir iPhone app sort notification option',
#  'united thank',
#  "AmericanAir 've trying reach customer service TWO day received zero response Never traveling AA",
#  "united flight 4567 agent wandered Pilots came looking Went charge personal phone 'd txting",
#  'united first lost bag Cancelled Flight flight home 30 min wait talk somebody poorservice notgoodenough',
#  'SouthwestAir sat plane 2+ hr 2/15 finally took ..',
#  'JetBlue ANYWHERE http //t.co/FeFHPmFPlE',
#  'USAirways spend cost flight get free room transportation airport',
#  'SouthwestAir understand weather kid need get home Nice kid volunteer work RI high school please help',
#  "AmericanAir friend need help flt 's Twiiter DM info",
#  'AmericanAir mom ’ flight tomorrow Cancelled Flighted w/ notice Phone system said callback 2 hour ’ 4 need go bed',
#  'americanair flight veers icy runway dfwairport DFW flight Cancelled Flighted Mon http //t.co/Q37pOWn6uv Cowboycerrone figure right',
#  'united Could tell bag would accepted personal item bring one carry-on bag plus http //t.co/U390cZpLHl',
#  'united yo need new website really badly day age ...',
#  'SouthwestAir TheEllenShow Imaginedragons kdepetro313 .what great first night DestinationDragons http //t.co/N3LrFo4UaY',
#  'USAirways right amp away ✈️🌞',
#  'united two dozen back line see single CSR reFlight Booking Problems final leg Kiosks fritz',
#  'JetBlue would charge money transfer point someone',
#  'USAirways possible earn Dividend Miles passenger even purchasing ticket',
#  "Lmfaooo “ JetBlue fleet 's fleek http //t.co/1G9RnmYUQe ”",
#  "USAirways phone line call n't affected `` bad weather '' Trying book vacation ... 👀",
#  'AmericanAir never seen incompetency gate agent year business travel DFW B16 gate agent need training new job',
#  'USAirways F623 DEN PHX impressive lack concern 1hr+ Late Flight flight attndt wrecking havoc customer travel smugsmirk norush',
#  'united client 11 hr layover IAH day claim amp recheck luggage taken care',
#  'united even change could made online- instructed call agent- maybe syastem allow agent 2 link passenger',
#  "united ca n't claim `` weather '' hardworking crew pulling seat plane right thing know wo n't",
#  "AmericanAir finally called Ca n't get met Seattle refund processed Thanks",
#  "United played bizarre `` safety '' video 've ever seen ... http //t.co/Hlm2Oks6xl",
#  "SouthwestAir 'm sure messaging part right Please let know received",
#  'SouthwestAir booked 8th .... Save emergency exit ... Got ta stretch',
#  'SouthwestAir try get customer destination help get another airline flight 3 day',
#  'JetBlue catch name sure Jason know',
#  'USAirways Yet another delay/missed connection .... customer service attitude Wow',
#  'USAirways access Dividend Miles week automated phone keep telling call back Late Flightr FRUSTRATED LivePersonPlease',
#  'united direct flight Belfast Intl Newark resume winter break Thanks',
#  "united LGJW7B voluntarily rerouted 1st leg journey economy supposed 8B Res agent said 'd reserve",
#  'SouthwestAir Nashville airport runway open appears southwest airline Cancelled Flighting flight likely change',
#  'USAirways flight plan delayed tuesday due computer crash',
#  'SouthwestAir unbelievable ... Thank much DestinationDragons',
#  'united big surprise nogate waiting plane fucken issue everything fly fail worstairlineever',
#  'USAirways tough night two 90 minute call hold delayed Phoenix two day one aircraft ready acceptable',
#  "united 's hard stay upset someone least TRY show remorse",
#  'united 50 min hold trying book award flight site error Agents ask pin see platinum availability badbadbad',
#  'USAirways 23 min hold ... Drove 2.5 hour get delayed bag want pick SJU',
#  'USAirways reserve seat AA flight transfer ORD EVV',
#  'United start 3xdaily EmbraerSA ERJ145 flight Chicago fly2ohare Evansville 4JUN avgeek',
#  'united flight 1136 Chicago Houston 2 hour pretzel peanut Seriously passed',
#  'united left comment customer care Thanks contacting',
#  'united held plane Made',
#  "AmericanAir 's ok ... may keep 25 lose bag info longer trust Bad way handle",
#  'VirginAmerica thestarter 😁',
#  'JetBlue Learning awesome twitter management today Social Media Marketing class keep good work SXU PhD_Mama_',
#  'AmericanAir dropping ball catering Plane switch gate attendant 2 hour Late Flight Really nice',
#  'AmericanAir good care customer anything happen take Delta getting back NYC Screw AmericanAir',
#  "AmericanAir n't think help based behavior voucher cot seem like enough lol 😃",
#  "united think problem resolution decided end Especially 'd like continue flying airline",
#  "USAirways 've hold 36 min counting cause charged credit card bag provided receipt said error Awful",
#  'united great Looking forward response DM',
#  "united 's 21st birthday sister coming celebrate flight keep Cancelled Flighting PLZ get",
#  'USAirways UR employee named VAN ticket counter Philadelphia EXTREMELY RUDE Father trying get home sick kid missed flight',
#  'SouthwestAir Horrible experience ever airline .. reconsider future flight Customer service ... http //t.co/EczHcmM5vi',
#  'AmericanAir tomorrow site show flight 1642 ewr Cancelled Flightled',
#  'VirginAmerica like customer service 40 min delay connecting passenger seems long VA370',
#  "VirginAmerica cutest salt pepper shaker ever think guy ca n't get better http //t.co/vC6Keulg2J",
#  'AmericanAir Unbelievable even wait hold speak human resolve issue system simply hang',
#  "AmericanAir continues win 've never missed flight nice little quiet gate change made possible Sheesh",
#  "USAirways even offered fly another airport said could n't explanation ca n't",
#  "USAirways phone number gate gave n't work either customer service phone number",
#  'JetBlue flight 1041 Savannah GA',
#  'AmericanAir yes still human hope dealing horror story people share ... complained DOT Everyone',
#  'JetBlue sent plane anyone JetBlue clue',
#  'SouthwestAir winner Imaginedragons DestinationDragons',
#  'united quick serious question resources/ratings showing quality service better 8th place http //t.co/deWIthPeW2',
#  "united get first flight day ground time 1531 Let 's go .......",
#  '“ SouthwestAir Southwest mobile boarding pass available iOS Passbook http //t.co/xmRvR4lGEg http //t.co/wJoc9f14SU ” tori_leggieri',
#  "SouthwestAir 'm stuck Fort Lauderdale",
#  'JetBlue clear folder regularly JetBlue white listed never got',
#  'united Keep flight cheap early/on time good Flew AmericanAir Cancelled Flightled flight 4 time last month United gt',
#  "JetBlue believe 's Irina flip-side super disappointed EatUp Cafe n't available BOS -- gt SFO flight today",
#  "USAirways 5534 's flight placed original flight Charlotte Cancelled Flightled 5534 1hr delay",
#  "USAirways captain turned seat belt sign people get walk around 's good",
#  'United http //t.co/5hpSqVRjK8 flight gone got plane BusinessTravel goodenoughmother',
#  'AmericanAir Call Chairman call Emerald today call former customer',
#  'JetBlue saw one useless tsa agent inspected shoe',
#  'united Thank response',
#  'AmericanAir one received text alert automated call anything either Literally information happening',
#  "USAirways made Send Bloody Mary 's row 27",
#  'united 5 gate change two delay Even crew think airline suck',
#  'USAirways Thank empathy story luggage thank reaching',
#  "JetBlue Thanks JB Actually birder love need outside n't hard trap move",
#  'USAirways flt 5302 CLT DAY supposed depart 5:51 6:20 ... still crew schedule/contact pilot',
#  'JetBlue allow payment Apple Pay Patriarc http //t.co/bdUaUZFhW2',
#  "united rep hung 35 min hold asked supervisor 'm furious right",
#  "AmericanAir 're 're trying book PAST need 2 arrive 're still selling seat day 'm trying 2 travel",
#  'USAirways AmericanAir seriously service issue right decide tweet Unbelievable',
#  'AmericanAir also passed website around passenger',
#  'united clicked link got confused http //t.co/xMAQcucWZl',
#  'AmericanAir well cleared custom AUH need get IAH arrive DFW possible retrieve luggage IAD',
#  'SouthwestAir TaylorLumsden Taylor U got ta love SWA responsiveness least huh',
#  "AmericanAir flight Cancelled Flightled ca n't get desk nothing showing online reservation",
#  "AmericanAir USAirways 'm pregnant twin 're going abandon overnight airport hotel 's fault",
#  'united thanks prompt response Another hour enjoy vacation Perhaps bug app still show 2:55',
#  'united tried figure go get',
#  'united except delayed flight anyway',
#  'JetBlue get flight 16 air',
#  'united let assure travel time 4h2m 5h2m timezones accuratetraveltimes 3rdtimethishashappened http //t.co/e0C9bI09cf',
#  'united thanks catch conection',
#  "“ JetBlue fleet 's fleek http //t.co/aJM3BhJVaa ” foh",
#  'VirginAmerica flight artisanal cheese wine pairing',
#  'united flight UA3364 sitting tarmac 30 min report ... input',
#  'USAirways sits throne lie',
#  'SouthwestAir 3 flight Cancelled Flightled today hold hour',
#  "SouthwestAir Late Flightly 've always Late Flight Please get back old SWA",
#  'AmericanAir ex-boyfriend pick call Cancelled Flightedflight nocustomerservice americanairlines FAIL',
#  'SouthwestAir WOULD ANYTHING ticket VEGAS ... ANYTHING love imagine dragon much',
#  "SouthwestAir thanks attention 've flying southwest 3 year n't issue past",
#  "USAirways never let 's every Single Flight Gets delayed",
#  "USAirways wife flying atlanta vega March 7th since could n't get tricities Tn",
#  'united Flight UA1665 got delayed 2 hour due mechanical issue ... could use free drink 3 make inconvenience',
#  'VirginAmerica DREAM http //t.co/oA2dRfAoQ2 http //t.co/lWWdAc2kHx',
#  "SouthwestAir 'm line airport right cover hotel fair sleep airport",
#  "JetBlue n't know- one would tell coming would guess 's change flight",
#  "AmericanAir worry 're swamped know dmd back THANK U",
#  'SouthwestAir forgot put tsa pre number checked profile boarding pas',
#  'SouthwestAir five people shown yet',
#  "AmericanAir 've never anything bad say love faithful customer",
#  'SouthwestAir Hello .. flight taking DallasLoveField airport noon supposed travel flight 376 San antonio',
#  'SouthwestAir love appreciate fact guy rarely Cancelled Flight flight time need Cancelled Flightlation time 🙏',
#  'AmericanAir Connection US2065',
#  "united good man n't fault plane maintenance issue",
#  "AmericanAir 'm sensitive fact n't believe warrant poor service little help amp compassion go long way",
#  "jetblue online resource say 're time clearly information age ...",
#  'united make hard fly Delayed hour plane turning around amp heading back gate connection',
#  'USAirways people kind hardworking infrastructure given horrid massivefail failphone fail',
#  "JetBlue THANKS 80th bday Saturday 're aviation themed surprise party",
#  "JetBlue Airways Reveals 'Bluemanity Livery TravelPulse http //t.co/fTTfyFMvCO",
#  'USAirways JosephTReis Dont bother dont pick phone Worst customer service going',
#  'AmericanAir expecting delay DFW tomorrow morning',
#  "USAirways flight 1808 leaving 2:45 n't even begun board yet Please update website ASAP",
#  "AmericanAir incredibly arrogant thing say sit O'Hare waiting incompetent airline refuel ...",
#  'JetBlue Airline trouble winter amp getting good customer service contact http //t.co/aQjn4HwNaC negotiate resolution',
#  'united thankful great service Newark Seats fixed seated daughter Fab landing Fort Myers',
#  'united feeling like true united customer stuck.on tarmac dc 2 hr UNITEDFAIL',
#  "united cool customer told n't care either expected",
#  "SouthwestAir today 's scavenger hunt start 'm trying help little brother win DestinationDragons",
#  'united lt lt lt lt lt -- -- -- shoddy customer service use whatsoever unitedairline',
#  'JetBlue option luggage assistance ground HPN Flight 2168 delayed 2+ hour amp 2 sleeping kid land',
#  "SouthwestAir DM 'd",
#  'united yep—used twice case id number assigned tried again-get screen say “ thank submitting request ”',
#  'AmericanAir guy amazing job today Know ’ hard thanks Kate Appleton hard work reFlight Booking Problems friend',
#  'AmericanAir really need customer service training unhappy EEs morning Chicago Gate K20 430 chking schd',
#  'SouthwestAir employee great',
#  "AmericanAir SouljaCoy AA going fix utterly embarrassing customer service wo n't even answer dang phone",
#  'SouthwestAir Please bring back RDU FLL direct route noticed missing starting Late Flight August flight always packed',
#  "USAirways n't want get home",
#  'USAirways phone line disconnect queue answered phone line simply disconnect call',
#  "JetBlue 'm sitting plane many predictable mechanical problem Still onboard getting bad ...",
#  'USAirways shivadelrahim upgrade',
#  'USAirways never received horrible service treated poorly Richard P. today excuse attitude amp ripping ticket',
#  'JetBlue get copy last flight showing original time delay need work Thanks',
#  'JetBlue get honest update departure flite 454 plane infant child',
#  'USAirways US 728 Wait gate opened Back go Good maybe get',
#  'AmericanAir maintenance MD80 sits two day Frozen line found boarded Come faail mci',
#  "SouthwestAir seriously WORST n't remember last time someone knew flight n't delayed Cancelled Flightled etc",
#  "united wont transfer flight ticket accompany 11 yr old 's active military mom emergency brain surgery WOW",
#  'USAirways ticket counter people helping want charge money even horrible day',
#  'united 4 seg flt yvr zurich would credit mile 2 segs full fare',
#  "AmericanAir need know n't done like promised would yesterday",
#  "JetBlue kudos 're done heading warmer weather",
#  "SouthwestAir yall trying fly Chicago n't live Send home Bullshit as customer service",
#  "SouthwestAir stay Chicago overnight meet bag hope stay put n't get put flight",
#  'united severely staffed Iah',
#  'AmericanAir fantastic thanks try tweet photo view',
#  'SouthwestAir love Companion Pass qualified 4th year HollyMais',
#  'AmericanAir said AA provide in-flight wifi route China based federal law United',
#  'SouthwestAir boarding pass compatible iPhone Passbook http //t.co/1ESmMnIZEk',
#  'USAirways disaster Flight 3739 missed passenger count 5 since done manually Really',
#  'JetBlue u suck Big Donkey Balls',
#  'SouthwestAir Thanks Confirmation number DMed Appreciate help',
#  "JetBlue n't made feel like criminal want sit near 5 year old flight jetblue http //t.co/qgtCao1J2U",
#  "AmericanAir 've already made arrangement",
#  'USAirways add frequent flyer number website help',
#  'SouthwestAir ticket booked 1/27 CUN arrival time reflect CUN EST time',
#  'united lot unhappy cold people bridge freezing temp hour given info',
#  "jetblue 'd love help Shanese Bryant-Melton hard-working grandmother DC go Miami 's bucket list flyitforward",
#  'united Want book multi-city fare mile 1of 2 flight option pay 1st flight mile +2nd UMP Visa Thanks',
#  "united email address/username sign-on available 's",
#  "united yes 've waiting four hour one able help",
#  "AmericanAir thank ca n't get flight hold Cancelled Flights",
#  'USAirways flight scheduled 730pm ... told 150am flight Cancelled Flightled sitting cold plane 2 hour',
#  'united Yes PLENTY seat available Vicky Thomas refuse give one million mile flyer',
#  'united UA63 Madrid arrived agent mass confusion sent fro 3 UA employee MaryJo rude unhelpful',
#  'USAirways AmericanAir terminal E Miami still worst smelly airport ever Thanks nothing',
#  "united great decision making skill flight ops IAH bag make 10 minute connection n't flight pushed early Disappointed",
#  'JetBlue checked yesterday looked like something change',
#  'united weighed 45.5 checked bag',
#  'USAirways check online state status closed mean yet able reach live person ...',
#  'united asked DM ignore Please assist changing another flight today- 21 Feb fra mco avoiding IAD',
#  'AmericanAir AmericanAirlines approach mex .... http //t.co/se57dmjHiW',
#  'united amp finally told couldnt use front plane restrm row7 though myself/others row behind used w/no issue',
#  "AmericanAir earlier flight SAP- gt Mia amp Mia gt New York lga 03.03 'm currently booked flight 1504 1102",
#  'united last night waited forever gate someone corporate dispatch FORGOT call crew unfriendlyskies',
#  "united SERIOUSLY 's 2015 WiFi 5hr flight CLE-SFO 1589 're airline without WiFi ...",
#  'united told changed flight im ottawa airport AC cant find reservation Whats wrong',
#  "“ JetBlue Analystdoc Unfortunately 's available option current system Sorry guy 's certain fail Fix plz",
#  "united n't need apology need bag Took 56 minute landing get Unacceptable",
#  'AmericanAir See photo B787 scale model amp PN 320008A wheel deflator specified Chapter 32 B787 AMM http //t.co/kfD4WQRkLW',
#  'united flying STL Saturday expecting ice amp snow start looking travel waiver Thanks',
#  'AmericanAir thanks getting back find airline future',
#  'VirginAmerica know Need spotify stat guiltypleasures',
#  'united patient luxurious middle seat next delayed flight',
#  "USAirways 4 hour tarmac Charleston still ca n't get response week Unacceptable",
#  "SouthwestAir 's happened customer service 2 Cancelled Flightled flight 2 day amp uninformed unapologetic staff nolove cali",
#  'united 777 SFO HNL ZERO entertainment system youareonyourown',
#  'AmericanAir 3078 overweight pull 2 dozen passenger luggage Seriously',
#  'JetBlue disappointed flight back boston PR Cancelled Flightled rebooked 4 next day delayed one compensation',
#  'united better customer service John Wayne airport',
#  "AmericanAir waiting delayed plane sat plane hour waiting Late Flight passenger 's BS ..",
#  'united always Helps communicate customer',
#  "united 're customer service unbelievably bad Abysmal 've phone well 2hrs tonight Hung yr ppl 3x",
#  'SouthwestAir 3rd time flying southwest two year another trip back mx October',
#  'AmericanAir Priority baggage evidently mean come last',
#  "united mention one bag infant car seat amp 've stuck yr poor replacement icy mtn road",
#  'united thanks checking',
#  "AmericanAir understand 'm even put hold say `` try Late Flightr goodbye ''",
#  "united wo n't check carry Watched handler throw bag -- miss conveyer belt -- sat 10 min http //t.co/lyoocx5mSH",
#  "SouthwestAir rerouted bf 's flight 's diabetic little insulin even though tried change agent would n't",
#  "AmericanAir 's lot talk MIA-SFO 20+ year old plane nonewplanes old shame http //t.co/TwETPXUpPN",
#  "AmericanAir flight dca need change asap help ca n't get",
#  'united change Way stick Premiere 1K loyal customer make thing harder loyal',
#  "USAirways ok ... know door close ~10 minute takeoff stop telling flight leave 20 minute n't boarded",
#  'united hope see issue return flight tomorrow',
#  'united customer service 👎',
#  'USAirways wife sick 3yr-old-twins waiting line 2hrs see agent Phone agent said nothing til Tuesday',
#  'JetBlue ruining vacation left right would thought airline Cancelled Flight ticket without telling buyer',
#  "SouthwestAir Guys 've got something inability check online international flight ... 1/2",
#  'USAirways Seriously flight delay Cinci Philly due new ground staff miss connection MAN UK argue hotel WTF',
#  'united line Denver rebook due weather issue BETTER http //t.co/tmccExYaaQ',
#  'USAirways redeem pas admiral club 1 free visit barclay card membership bring companion',
#  'USAirways FAILINGYOURCUSTOMER ONE ONE',
#  'JetBlue guy continue impress crew MCO gate 4helped family seat issue professional',
#  "SouthwestAir n't charge ticket change fee incur mysterious `` cost '' incur united",
#  'AmericanAir taking call need change flight',
#  'USAirways flight 1735 sitting fully loaded hour Air conditioning barely working',
#  'JetBlue dropping passenger small baby 3 infant San Juan terminal unloading baby officer writes ticket 75',
#  'SouthwestAir continue amazed amazing customer service Thank SWA',
#  'SouthwestAir hilarious flight attendant Vegas Detroit tonight http //t.co/nw7vx7DGMF',
#  'AmericanAir people cruel stupid posting personal email damn Internet u lost mind',
#  'AmericanAir narrowly made standby ... lot snag trip',
#  'SouthwestAir Thank thankful feelingtheluv',
#  'AmericanAir Took flight yesterday fron TPA-DFW-AUS Bag went IAH Today bag went IAH-DFW back IAH Still bag',
#  'AmericanAir one agent helping stagnant line almost 100 customer Super',
#  "SouthwestAir pair ticket Imaginedragons show Atlanta 'd love go DestinationDragons",
#  "SouthwestAir got `` duped '' w/ connection 1st flight sneaky u wo n't give seat earlier flight w/ availability Shameful",
#  'SouthwestAir really gon na hear mouth bag situation',
#  "virginamerica phone number ca n't find call flight reservation",
#  'USAirways Thanks would better gate agent C14 Charlotte boarding flight 1791',
#  'JetBlue always pleasure ☺️',
#  'USAirways USAirways disappoints Cancelled Flighted flight Missed appointment Promised refund lie',
#  "united ca n't get anyone deal person Cowardly customer service ca n't looked eye anyone",
#  "AmericanAir something wrong website matter flight select say 's longer available",
#  'SouthwestAir multiple attempt finally able submit Late Flight last night',
#  "SouthwestAir broke stroller wife baby gate checked told 's problem Calling List Preferred line",
#  'JetBlue unfortunately hoping catch one sometime near future',
#  "JetBlue mean take time write physical letter fraud department n't email telephone Right",
#  'AmericanAir Trip cut 7 hr short due flight change/massive layovers/ peanut crackers/ asked H2O received 2oz',
#  'united please follow Dm missing bag',
#  "USAirways please secure 'footrest shelf business class A330 airplane http //t.co/ZL4bVEXmcJ",
#  'AmericanAir maryella_green received actually Thank',
#  'JetBlue Amagrino cover cost car service waiting time',
#  "AmericanAir 've Cancelled Flightled flight First priority ticket bumped 're losing customer People furious",
#  "AmericanAir connect person without wait 2+ hour hold still n't able resolve problem",
#  "USAirways 're reservation number none Hungary phone working make difficult",
#  'SouthwestAir checked right 24hr mark Boarding C group kid age 6 amp 8 dnt want split sld',
#  "JetBlue 'm flight booze served 30 min ... give lostrevenue angryandsober bachelorpartymishap",
#  "AmericanAir sweetmel weather bad would n't folk try extra hard communicate ... load bag onto flight 1320 ... ... anything",
#  'AmericanAir 4369. 4 flight using gate w/buses plane Awful boarding process Hour half Late Flight',
#  'united staff rather efficient got u solution freaked little limbo air',
#  "united flight vega houston Cancelled Flighted morning `` due operation '' mean Thank god woke early today",
#  'USAirways PHL take hour offload bag especially taking 30+ min get jetway get plane landing',
#  "AmericanAir 'd like apologize gate agent flight AA76 aware zone 1 nine precious gem",
#  'AmericanAir 4hrs Late Flightr get call back immediately disconnected',
#  "USAirways wo n't waive 200 fee due neptune Ca n't use credit w/o paying fee Couldnt get destination use tic waivethefee",
#  'insulting USAirways AmericanAir offer `` non required 50 voucher goodwill offering .. least bag fly round trip',
#  "USAirways ca n't even use return flight home change fee charge expensive forcing purchase new ticket",
#  "united 'm rebooked line 300 people deep",
#  'USAirways cust serv rep unable change reservation system Check unaware Cancelled Flights got word night',
#  "united give service terrible n't forced use United certain route never would",
#  'SouthwestAir get kind update delayed flight Boston Houston 7:30 Really need back home tonight',
#  'SouthwestAir impression 8 hour delay flight equipment failure compensation offered',
#  "SouthwestAir Looks like 'On February 19 2015 open schedule sale October 30 2015 know time",
#  "AmericanAir would appreciated please n't send page long form amp limited character Direct email",
#  'USAirways email',
#  "united diverted missed connecting flight told bag 's way MSY people cared",
#  'united need assistance Line door travelling 3 kid',
#  'united 100 put together serious email issue arose vacation due staff post',
#  "AmericanAir upon entering plane 2 USAirways stewardess `` water '' `` n't please take seat ''",
#  "JetBlue amount money spent hotel WEEK bc flight Cancelled Flightlation another flight n't make money lost",
#  'USAirways Flight 830 CLT Phl 1st list.Someone else got spot Rude employee coach Wouldt give ID Said cute red head',
#  "AmericanAir thanks Bummer Poor planning part assume card Passbook wo n't work either",
#  'USAirways still cricket customer service',
#  "united 1k 'm always hoping improvement",
#  'AmericanAir merger USAirways usairwis cluster inefficiency misinformation going done',
#  'SouthwestAir much respect',
#  'SouthwestAir really easy local get strip book',
#  'USAirways Charlotte Staff need prayer .... disappointed response mishap ...... lotttttttt pissed people',
#  'SouthwestAir unscheduled aircraft change please better system place worth paid upgrade REFUND',
#  'united air Another missed cnxn 2day ATC went strike Belize family amp miss cnxn EWR Please see DMs',
#  'USAirways thanks bad make two day train trip look appealing',
#  "united getting ridiculous 're missing connection",
#  'united really clean food coffee stain area around seat new passenger come aboard Gross',
#  "united Missing flight attendant Delayed Flight Prime example 1 person impact 100 's people HNL gt IAH UA252 wastedtime",
#  'USAirways AmericanAir call number listed sure next Friday get real live person line http //t.co/8TJUuM22dD',
#  'AmericanAir change fee price new ticket ... logical',
#  "Stop madness RT JetBlue fleet 's fleek http //t.co/7x9uSbj2FV",
#  'united ok sent u info via DM appreciate help consideration 😊',
#  "SouthwestAir Service rep n't say dumb tone voice like known",
#  'usairways im trying get dad wheelchair one answering Dulles.we tried call back on.multiple time',
#  "usairways 've hold approaching 2 hr issue changed ticket online Frustrating",
#  'united thank',
#  'united thanks effort get earliest Though make complaint refund losing one business day tomorrow',
#  'USAirways lack communication office customer amp yall never update ur system U guy 2 established 4 mess',
#  'JetBlue much paid fee Plus hotel food change could flown reliable airline no2jetblue',
#  'seriously want work JetBlue social team RT JetBlue vincenzolandino http //t.co/eiGaJyzcW2',
#  "SouthwestAir right 're delayed 'm crabby Also allow one family member purchase EarlyBird check hold row",
#  'united guy suck',
#  "united Thank person Houston could get flight routing Newark NJ 'm going SFO",
#  'united lost bag Huston leave Bahamas cruise today nola buy new stuff Customer service non existent',
#  'SouthwestAir Thx customer service rep ALEX patient help reFlight Booking Problems Cancelled Flighted flight getting u tmrw',
#  'usairways faster way get Columbia Sc making stay CLT night delayed flight',
#  'AmericanAir highly disappointed baggage service merge USAirways guy lost 1st bag missing item',
#  "SouthwestAir A-list program complete JOKE company value loyal customers.Time look another `` go-to '' airliner",
#  'AmericanAir understand need drain lavatory fearing freezing policy checking boarding smh come ...',
#  "united n't hope nicer flight time try thing right sold ticket connetion",
#  'SouthwestAir Thank Thank Thank last attempt win DestinationDragons ticket success could happier',
#  'jetblue hate 😒 http //t.co/g4WwR6VBRQ',
#  'AmericanAir CVGairport get together perfect combination delay Cancelled Flightlations',
#  "united may `` dislike delay '' paid .We agreement paid got destination certain time",
#  'SouthwestAir trying get cust relation another use',
#  "JetBlue yesterday flight wanted Chicago sale within point range today n't way guy still honor",
#  'united possible add Known Traveler Number ticket Flight Booking Problems',
#  'VirginAmerica heyyyy guyyyys .. trying get hour someone call please',
#  "😐 “ JetBlue fleet 's fleek http //t.co/QavvlAXLkl ”",
#  'SouthwestAir Thanks opportunity ...',
#  'JetBlue disappointed missed connection ROC SLC reimbursement even tho friend pilot said due ATC',
#  'JetBlue lipstick pig still pig Ur new baggage claim SJU disaster chair 20 mins+ wait baggage fail',
#  "AmericanAir prime ticketed seat get switched AA 343 sure 's going ...",
#  "“ JetBlue fleet 's fleek http //t.co/g12sn5qsqZ ” ... Yall better",
#  "JetBlue 's great Thank",
#  "AmericanAir usual next flight show time 's suppose leave 5 minute n't boarded",
#  'SouthwestAir Opal Dragon book Dragon ALI woven murdering way Philippines Australia http //t.co/c9p2ioSphM',
#  "USAirways happens n't located",
#  'AmericanAir phone call email Cancelled Flight flight would lovely',
#  'USAirways please thank Mellie CAE Tammy baggage claim CLT 4 excellent customer service 2day complaint',
#  'united mean within one week filed 2 compensation complaint website',
#  'united thanks help ... got need issue _austrian guess sit awhile longer',
#  'USAirways airline rather poor right SLC waiting take suppose take 2 hour 3 minute ago',
#  'USAirways three hour hold disconnected Conf EBHSET Need home Sunday interview',
#  "USAirways 's flight 5545 gate agent plane PHX B18 Nice customer service",
#  'united Unfortunately bad experience flying Saturday Inpolite crew bad delay',
#  'USAirways US 728 stated issue plane moving cargo door open plane Umm ok. little strange',
#  'united thanks trying take money without notice industry Cancelled Flight service refund issued Cont…',
#  "united Ca n't leave Tarmac .. united 's gate agent agree head count 20 min counting 100 people max epicfailunited",
#  'USAirways flight delayed 5 hour reason given Sure love flying airline whatajoke',
#  "united vacation 's going ruined w/ 3 day rain change fee 2 u nearly cost original flight help",
#  'SouthwestAir way help entry Vegas event Boyfriend amp Imaginedragons fan since 2009 awesome',
#  'AmericanAir thought guy done messing make worse airline ruin hope dream',
#  'AmericanAir boarded flight 2334 8:30am 11:40 Still sitting runway Lots fun',
#  "USAirways waited hold long n't wait hold forever never received confirm 1st place help",
#  'united interviewed yesterday flight attendant last person recruiter said lost file n came back interview',
#  'united Item mine mysteriously ended checked bag EWR YOW flight Missing black box http //t.co/SJQEmDtQmA',
#  'united thank trying two day set',
#  'SouthwestAir WiFi shit fix jump closest bloody fucking emergency exit',
#  'VirginAmerica jump Dallas-Austin market Dallas_News http //t.co/EwwGi97gdx',
#  "SouthwestAir n't conference number spoke Courtney Texas David finally fixed mine hour",
#  "AmericanAir n't anyone make better effort retain customer easy fix want travel AA",
#  'united Premier desk able rebook friend AmericanAir problem pay checked bag',
#  "“ JetBlue fleet 's fleek http //t.co/g97HAbyeP5 ” SMH",
#  'SouthwestAir guy held flight 330 Thank take MDW Oakland Thanks',
#  "united Flight 211/ORD gate agent tried prevent taking onboard bag 've used 15 year Flight crew reasonable",
#  'USAirways thank',
#  'USAirways success made flight please thank crew 556 great time recovery',
#  "SouthwestAir considered adding `` 'll call back someone free '' feature support line",
#  'SouthwestAir Vegas 5 day ago Miss Warm Weather',
#  "united unsmiling rep. told u hotel shuttle come `` like every 15 minute '' Breezy 30 min Late Flightr 're taking cab going reimburse",
#  'AmericanAir send trusted traveler ID add reservation tsa pre',
#  "AmericanAir thank ... know 's busy today help would appreciated ...",
#  'JetBlue still waiting bag flight 26 landed hour ago',
#  "USAirways 1st reaccommodation delayed flight one amp Gate Agent still n't mumbled word Folks getting anxious",
#  'USAirways Dude named Shaquille desk Charlotte incredibly professional helpful vs. crazy angry people tonight',
#  'SouthwestAir Kudos adding Passbook app LOVE',
#  "united worse oh ca n't delayed reason way Lon flight Cancelled Flighted REASON le 2 day returning",
#  "USAirways find funny PHLAirport responds n't customer service worst wedontcarebecauseyoupaidalready",
#  'jetblue WTF stuck JFK 2+ hr delay Boston cuz u say snow snow weather map WTF',
#  'JetBlue thank guy awesome',
#  'AmericanAir fat man stuck airplane bathroom',
#  'USAirways sorry meant flight 4420 supposed depart 5:00 say 6:30 issue',
#  'united received one previously 11th checked Odd said complaint associated e-mail',
#  'JetBlue definitely new favorite airline',
#  'united baldordash Rebooked arrived 8 hour Late Flightr Last year 9 hr San Diego inflight entertainment',
#  "JetBlue Although n't totally answer looking appreciate prompt response",
#  'SouthwestAir easily get Atlanta show need ticket help',
#  'JetBlue whatever lil mint heart desire http //t.co/WmX12F33ZC',
#  'AmericanAir message pic sent ...',
#  'AmericanAir thanks',
#  "united `` Airport snow removal method 22 ... '' Keep good work folk Cessna 's become 747 's http //t.co/9v8tMUsJvU",
#  'USAirways ability switch flight AmericanAir tell bag',
#  "USAirways made Bahamas work luggage n't know travel happens anyway get help/info",
#  'USAirways NEVER fly u airway american share nightmare story many others know fly',
#  'united Delayed 7 hr flight 5721 PIT/IAD finally board plane sit half hour amp crew hr limit amp deplane Unacceptable',
#  'SouthwestAir hold 90 minute fly answer phone',
#  'AmericanAir AA 2258 Cancelled Flightled flight without courtesy notifying u alternative poor',
#  "USAirways 2nd time occurred 3 week 'm patient choice Antitrust issue",
#  'SouthwestAir hold rebook flight CMH 1.5 hr rebook website crashed',
#  'VirginAmerica YES FYI BFF',
#  "JetBlue 's delay system n't",
#  "VirginAmerica 'm trying check 10:50AM CT flight tmm desktop website 's working sort caching bug SOS",
#  'VirginAmerica beautiful front-end design right cool still book ticket b/c back-end secure',
#  "united 'll hearing sure",
#  'JetBlue Annnndddd booked flight easy',
#  'AmericanAir ’ line waiting 40 minute',
#  'USAirways flt 1820 2rsw could extended courtsey waiting 2min 4 10 u .... gate closed r face Ur fired',
#  'USAirways last name Pordes',
#  'AmericanAir thanks actually made connection flight delayed Guess delay bad thing http //t.co/XGgCNTco8m',
#  "AmericanAir n't know may also working home Thanks nothing",
#  'USAirways know left something last flight literally run make connection retrieve please',
#  'JetBlue offered flight 4/19 paid changed it.This 2nd time done ruin cruise plan',
#  'united saying customer care report anyone response humiliating company serf public',
#  'united sitting middle first time .. Hope work well',
#  'JetBlue Airways Corporation NASDAQ JBLU Update JetBlue say Lufthansa ... Markets Bureau http //t.co/aPY3zLSqUu',
#  'malhoit least got response AmericanAir via Twitter went 0 2 yesterday',
#  'AmericanAir Please help AA 2258 Monday Cancelled Flightled advise reFlight Booking Problems refund child need make plan',
#  'USAirways seat next 19B flight 1943 Seattle tray table falling ... http //t.co/HAJ5lKqjW4',
#  "united flight ua3576 gate b1 tell ray somehow made 736 flight IAH n't wait 917 one",
#  'USAirways comcast airline 2hrs35minOnHold',
#  "“ AmericanAir `` Jason 'll end missing connection Please see DFW agent assistance. ” Nope n't taken yet still",
#  'SouthwestAir hold 2.5 hour waiting speak someone Cancelled Flightled flight Philly ORL',
#  'AmericanAir PatrichRuben profit maximization top priority Nothing else even register dinosaur',
#  "SouthwestAir Flying 2 week bringing blanket bc 's freezing 😜",
#  'united great flight PVD Smallest plane ever smoothest landing ever',
#  'AmericanAir thanks submitted damaged bag complaint online ... anything else goodcustomerservice',
#  'AmericanAir Eagle always Late Flight',
#  'AmericanAir looking status flight 1388 schedule 5:15 tomorrow morning thank',
#  "Hypocrisy RT united gg8929 'm sorry 're able offer full refund exchange rate hoping ^KP",
#  'United terrible illogical re-route Cancelled Flightled connection made pay check bag lost bag ual',
#  'united speaking United customer service rep night flight confirming everything ok reservation ..',
#  'USAirways Good news got fixed',
#  'USAirways word whether flight 1971 Seattle Charlotte connection held ...',
#  'southwestair important accept others SWADiversity',
#  'AmericanAir changed AAdvantage travel plan amp called 800-433-7300 get help sea ur busy amp hang give',
#  'SouthwestAir everyones flight Cancelled Flightled today DESERVE 1',
#  'USAirways airway joke never dealt worse service',
#  "JetBlue reading NYTimes “ JetBlue fleet 's fleek http //t.co/lvIrTDtqly ”",
#  "SouthwestAir really unhelpful ca n't rebook online http //t.co/N5O43sVl8i",
#  'JetBlue Flight 100 full',
#  'USAirways 1-2 Rock hit plane delay Never easy day US Airways Ya never fail let',
#  "JetBlue thank 'm excited fly first time",
#  "united gate DEFINITELY FULL parked wheel chocked Customer service called `` UNMET ARRIVAL ''",
#  'SouthwestAir provide direct assistance colleague re-book b/c ticket booked via corporate account help',
#  'Aww JetBlue guess need book flight somewhere warm ASAP suggestion',
#  'united never flying guy ever customer service piss poor best',
#  "Yes Thanks much 💜 “ united whitterbug see spoke Reservations team 've reinstated flight Thanks ^EY ”",
#  'USAirways AmericanAir anyone answering phone today Listening damn message 1:10 minute',
#  'SouthwestAir Thank',
#  'AmericanAir beyond redemption Jfk Baggage claim look like luggage warehouse',
#  'united know two hour u sitting plane bag loaded plane weight',
#  'AmericanAir Deplaned 3rd fucking time Fuck AA',
#  'united Joni great job flight 5653 LAX Thanks great flight',
#  "AmericanAir 'm willing hold agent n't helpful keep hanging americanairsucks hiremorepoeple",
#  'united delayed another hour',
#  "USAirways `` admiral club '' CLT rude ignorant front desk staff ... AmericanAir fallen far ... THANKS DOUG PARKER",
#  'JetBlue booked work added upgrade seat Need upgrade receipt',
#  "SouthwestAir Hi Janet customer service 'm calling back sitting que 40 min Plz pick frustrated",
#  "AmericanAir flight delayed amp ca n't talk reach anyone customer service high call volume",
#  "united u miss first leg ur flight pay hundred 's keep second leg much keep earned mile",
#  'united standby Denver delayed confirmed Aspen whose flight Cancelled Flighted day 0 confidence',
#  'JetBlue actually flight 1089 1098',
#  "united option co tonight n't look like UA5525 make time UA6259 reserve hotel room",
#  "SouthwestAir thanks much make Cancelled Flightlation 've sent u info",
#  "united 'm aware flight detail thanks Three hour Late Flight crew could give le shit",
#  'united UA1740 admit clue flight leave Denver unfriendlyskies',
#  'JetBlue Thank JetBlue Credit Nice save',
#  'AmericanAir lost customer today Flight today Cancelled Flightled find calling customer service yesterday',
#  'AmericanAir still waiting flight ... get money back',
#  "united already emailed n't know expedient contact Please advise Thanks",
#  'SouthwestAir flight Cancelled Flightled ... tried get refund hold get flight would departed',
#  "SouthwestAir thank help resolving problem Shannon ROCKS even though Rhonda n't",
#  "united still n't received response Please direct message contact information",
#  'USAirways future better harsh weather preparedness plan much staff called everything snowballed',
#  'united airline cause missed connection u would think would take whatever step remedy screw',
#  'united poor old United never seem get response right',
#  "USAirways AmericanAir nvm bad 's hour half thanks",
#  'USAirways 1899 Thanks',
#  "USAirways know 're dealing weather PHLAirport hot mess Pls send reinforcement",
#  'SouthwestAir amp sammi_jon3s best friend Imaginedragons chance could get ticket DestinationDragons',
#  'AmericanAir thx responding cant watch 2 min film w/out cutting 4 prolonged prds time beyond frustrating',
#  "united sure missed mark tonight 's redeye LAX Chicago mess better",
#  'united yes awful weather appears get home',
#  "JetBlue 2nd time row flight jfk disaster Last time n't allowed fly stndby 2 hour delay w/out notification",
#  "USAirways hold 58 minute need help USAIR wo n't help",
#  'AmericanAir flight 2934 dfw gsp going Cancelled Flightled tomorrow',
#  'united flight 1051 2/23 Thx',
#  'USAirways good luck getting cool',
#  'USAirways long departure gate stay open make connecting flight 1861 RDU flight 894',
#  "USAirways mad ca n't even believe guy Cancelled Flight connecting flight leave first stop amp give useless hotel voucher",
#  'SouthwestAir ridiculous want charge 209 change flight even multiple seat available flight needed',
#  'SouthwestAir Another delay Wow',
#  'AmericanAir trying check flight line working amp agent busy take call',
#  "JetBlue 's going 1171 LGA-FLL .. poor communication gate agent",
#  "southwestair ftw ✈️ Hope 'll sing u song flight Phoenix today Terminal 2 Humphrey http //t.co/mAvIgetbBw",
#  'united ... lie lie lie .... still sitting gate moved inch http //t.co/LulGnwEfFH',
#  'united following need follow DM',
#  'USAirways AmericanAir Total lack cust service mom flying solo w. baby flying w. Air',
#  "united n't ever print known traveler number ticket never get use TSA prescreen paid",
#  'AmericanAir still think American Airlines great ... would like treated better Loyal customer first right',
#  'USAirways AmericanAir delay mechanical issue weekend flight Ridiculous tweet long delayed',
#  'united future delay cause 15 hour wait slept night airport ensuring seating choice replacement flight would good',
#  'AmericanAir break whatever want take responsibility .. bad customer medium filmcrew chicagotribune WSJ nytimes CNN',
#  "USAirways called 25 time redeem mile point ca n't get advertise mile make hard use",
#  'jetblue directed mobile website direct link GET TOGETHER',
#  "USAirways 's going CLT",
#  "united could n't possibly messed trip anymore Thanks terrible airline disappointed",
#  'united app say flight UA936 ZRH departed 2:45hrs Late Flight 5 hour Late Flightr still seating inside plane IAD failed',
#  "united mean beyond opaque `` maintenance issue '' yes would basic customer service EWR staff ca n't manage",
#  'SouthwestAir Free TV watching Daytona 500 Boss http //t.co/SbGBN7oUXy',
#  "USAirways screwed big 1st flight 1hr Late Flight Made 2nd flight CSM daryl would n't let plane 1/4",
#  'USAirways option use twitter people working u clue tell go A4 b16',
#  'VirginAmerica hot female pilot Sweet DCA SFO',
#  "southwestair kudos rep `` Patricia '' gate B11 Sunday morning Chicago Midway MDW … http //t.co/MmCWkqp2gy",
#  'JetBlue able watch Oscars flight tomorrow',
#  'JetBlue Airways Covered Bank America JBLU Dakota Financial News http //t.co/WOwxhpU5qv',
#  'VirginAmerica Sent couple message email provided avail try next year Cheers',
#  'USAirways plan support ApplePay board USAirways MC would nice still use forget card',
#  "JetBlue 're home guy recovered laugh extra day barbados open Cuba soon",
#  'united FernHeinig18 delay due making back gate multiple time Maybe take accountability',
#  "RT JetBlue fleet 's fleek http //t.co/ncguZDgDaQ",
#  "AmericanAir 's weather 's logistics hold 90 minute called get desk agent",
#  'JetBlue would prefer similar picture full E190 tail great shot',
#  'USAirways denied mom flight NEEDED breast pumping part full flight Please FIX ASAP freeflight',
#  'USAirways service Philly unacceptable Look better service✌️ 16 yr old shouldnt hard time http //t.co/WDAKTmr7Mj',
#  'JetBlue knew 3-4 hour sounded odd missed flight hit JFK hour early gate attendant told u 3-4',
#  'USAirways 5223 Gainesville FL',
#  'SouthwestAir never got email confirmation ticket credit card charged Phone wait time crazy chat',
#  "JetBlue Gotcha ... `` lessening delay '' ... part 's happening right",
#  'AmericanAir none sample itinerary actually booked http //t.co/mF7rABGn8a Every last leg back US say invalid',
# ...
#  'united ehsanisMpowered lmfao',
#  'SouthwestAir tfw1 JimCramer AARP TY-Spent total 3 hr 20 min holding Cell battery died Finally made arrangement w kind Rep',
#  "united 's allowed 's allowed carried checked baggage",
#  'USAirways US 728 pilot started flight announcing arrival Gatwick Heathrow Moments concern aboard',
#  'united one lady helping 12 u luggage',
#  'United thanks Lea Chicago office help switching Cancelled Flighted flight',
#  'SouthwestAir great flight great view http //t.co/auFM4xdaj2',
#  "AmericanAir lost cat missed flight kept crated 30 hr would-be 5 hr trip 'll never touch pet",
#  'united U BUMS U LOSE BIGGEST BAG FLIGHT',
#  "AmericanAir 's frustrating -- PAID get refund",
#  'AmericanAir Thank info Changes need made phone correct way AA agent call directly',
#  'united made fly list airline wait connector Late Flight Stuck IAH',
#  'JetBlue Sure go south breakfast though Delayed three hour',
#  'AmericanAir respond DM',
#  "AmericanAir 's 16+ extra hour travel time Missed vacation time guy messing professional life",
#  'united USAirways AmericanAir americanone one bag Claim 4016688561 want MGA',
#  "AmericanAir told u drive back drop could attempt fix Really n't time terrible",
#  "united thanks moving dad mom 's flight helped make birthday start FriendlyFriday Awesomeness 4 paw",
#  'VirginAmerica flight 404 delayed 2 hour LA due mechanical problem Handle like pro could tossed u free drink',
#  'AmericanAir thanks',
#  "JetBlue customer service say since wife setup family account ca n't join mine year Help fix please",
#  "AmericanAir giving hard time ... looking basic customer service AA lost bag ETA 's return please",
#  'SouthwestAir yeehaw found u another plane Thx listening vent',
#  'AmericanAir friend flight Cancelled Flightlations LAX CMH Feb 23 Anyway help 800 number help',
#  'SouthwestAir Jackpot legroom http //t.co/ZO2iceG4lI',
#  "USAirways 's point baggage claim ticket n't scan tracking",
#  "united Cancelled Flights flight sends email saying `` think next flight ... '' customer outrage http //t.co/KkwiwI97A4",
#  "united trying go far away King'sCollegeLondon possible charity today Would help u jailbreak RAG",
#  'united live abroad Flight Booking Problems flight come visit state',
#  'united FirstClass London way LondonFashionWeek LFW15 👠🇬🇧👠🇬🇧👠🇬🇧',
#  'JetBlue ask load bag flight',
#  "USAirways AmericanAir 'm stuck airport fresno trying beat storm pittsburgh guy offered nothing HORRID",
#  'SouthwestAir SwagglikeBean take',
#  'SouthwestAir please please please answer phone',
#  "AmericanAir ever wonder find responding many customer complaint twitter 's airline suck",
#  'AmericanAir 3 day BAGs amazing way neglect customer',
#  "USAirways 's deal flight computer network",
#  'SouthwestAir thing changing ticket Cancelled Flighting current ticket amp buying replacement online',
#  'SouthwestAir JasonWhitely flt 947 Emer stop Albuquer heart condition crew awesome pilot Maverick divert',
#  'JetBlue Complete waste entire day Pathetic',
#  'united DM detail back 02/14 started phone number reach reply either online phone',
#  'united go 2 3 segment SFO -- New York RT delayed 2 hr suck BAD Maybe another line bus',
#  "USAirways 'm frequent flyer US airway 'm qantas still get notification Thank",
#  'AmericanAir finally made chicago 13 hour Late Flight get 12 food voucher wait.about 1per/hr Never Good bye',
#  'AmericanAir welcome anyone work condition deserves thank even though side Atlantic lol xx',
#  'SouthwestAir website downnnnn ugh',
#  'united cell phone record need checked see conversed trust FAA handle better',
#  'united 4 u stranded flying New Orleans Huston tonight stuck two day Rather fly wait',
#  'united force u check baby bag overbooked flight complains wife need much baby .. united baby meal',
#  'SouthwestAir IM THO 😭😭💔💔💔💔💔💔💔',
#  'AmericanAir got gate time watch plane push back 5 minute needed Glad ’ relative nearby',
#  "AmericanAir 2 hour 'm patient n't call back feature pay someone answer phone tweet onhold",
#  'AmericanAir Nice AA employee making skillful excuse Late Flightness due catering snafu ... http //t.co/YPVPVdlTYs',
#  'JetBlue safety first lovejetblue',
#  'americanair thanks airline ruined bag refuse anything',
#  "AmericanAir Ca n't unload flight 3322 jetway broken step planB waiting nearly hour",
#  'USAirways six hour even gate agent got fed left u line front empty desk Stay classy US Air',
#  'united tonight made Fred Flintstone happy upgrade 1st class http //t.co/gKgKZLAwpR',
#  'united Asked Flight attendant typical compensation would amp say might get free TV Unacceptable',
#  'SouthwestAir Yes bag came straight hotel Thank ... guy rock',
#  'united Hi flying IAD tomorrow evening expect delay Cancelled Flightlations snow storm',
#  'united CMH gate staff disaster .. 3345 overbooked volunteer boarding 20 min Late Flight trying figure issue bringbackrealstaff',
#  'VirginAmerica problem link email check-in thanks',
#  "SouthwestAir nvm gate said 're holding connection Thanks quick response",
#  "AmericanAir terminal LHR aa5/BA1506 n't say boarding pas",
#  'USAirways charged flight Cancelled Flightled unbelievable unheard',
#  'SouthwestAir Flight Cancelled Flightled BNA .... reschedule travel fund put back account future use',
#  'VirginAmerica match AmericanAirlines status Cool',
#  'USAirways satesq there one flt PHL-CRW per day',
#  'AmericanAir karabuxthomps Yeah lot question number one dare',
#  "SouthwestAir Thank know ya 'll ca n't control weather appreciate ya 'll working get flight rebooked last two day",
#  "JetBlue ca n't n't acces phone rn iPhone broke would rather change Late Flightr",
#  "united service far horrid wanted end trip high note Guess 's option",
#  'united flight 1219 frustration boiled dealing attendant attitude ridiculous',
#  'JetBlue family excited see too😊😊',
#  'united customer service 16hr delay coupon redeemed website 200 higher price Expedia call wait time 55mins',
#  'united thanks keep good work',
#  "SouthwestAir temporary site glitch longer offering flight GRR GEG Feb Ca n't find online",
#  "USAirways AskPayPal completed 's case still say `` progress '' Paypal 's website reserved 13th",
#  "SouthwestAir- Wife 's RR pt expired day ago planning Flight Booking Problems trip today Anything u tight budget ...",
#  'SouthwestAir hold 45 minute trying rebook Cancelled Flightled flight companion ticket Help',
#  'USAirways worst experience time never ever ever travel EVER',
#  'AmericanAir went check flight 24 hr advance husband seated separately 6hr flight happen',
#  'USAirways GregWallace66 Yea give 5 cent dollar',
#  'AmericanAir second pic CDG',
#  'SouthwestAir thank',
#  'united thanks',
#  'united okay Thanks',
#  'AmericanAir really appreciate great customer service ... One service agent hung asking legitimate question',
#  "SouthwestAir Still n't heard thing",
#  'AmericanAir chariot tonight angle look like 787 http //t.co/3ZZKQWWbJz',
#  'USAirways flight4592 LET US PLANE please go gate absurd',
#  'JetBlue sorry specified meant ground traffic trying get terminal',
#  'AmericanAir u air point combined',
#  'USAirways hold reservation 30 min already worstairline',
#  'SouthwestAir contact missing Rapid Rewards credit',
#  "JetBlue 's poop barely work",
#  'USAirways still rep talk 3 day Late Flightr U r asking checkin flight tmrw refund requested Deal w',
#  'JetBlue haha TY know time lane open Logan',
#  "USAirways happened u could n't get u home next day flydelta flysouthwest flyjetblue theyareallbetter stillnobags",
#  "“ JetBlue fleet 's fleek http //t.co/tLGoihqkvS ” 😐 make stop",
#  'JetBlue Customer year http //t.co/epqqONHO2H',
#  'AmericanAir Extend rtn flight bereavement 22nd could change fee dropped told no.Worse day life badcustomerservice',
#  'SouthwestAir App Updated Passbook Support http //t.co/WrWqrUblPs via ubergizmo',
#  'JetBlue sooo earlier said couldnt fly school trip 😏',
#  "united took screenshot emailed Let 's DM figure",
#  'USAirways kidding Oy',
#  'USAirways flight full',
#  "USAirways Stuck Philadelphia airport 32 hour due `` maintenance '' Dreading flight back home Disgusting",
#  'SouthwestAir service promotion moment ModeloDeNegocio innovation innovacion BusinessModel',
#  'united newest delay right http //t.co/96fTLZWtvO',
#  'united Hello United take care call center Mexico City Office Terrible attitude lady helping',
#  'JetBlue offer service Daytona Beach New York Albany Business Review http //t.co/dUhBJ41jHx',
#  "AmericanAir 'm trying choose seat every time go next flight get system error",
#  "JetBlue ... n't heard anyone week nonstop flight baggage lost/stolen customer service 👎",
#  "JetBlue 've delayed almost 2 hr take JetBlue 've good luck today really frustrating",
#  "JetBlue w/ 70 upgrade Unsure ca n't switch someone around called 24 hr advance reason",
#  'JetBlue Great thanks',
#  'united thank getting daughter home americanair Cancelled Flightled flight Nashville',
#  'united yes ... ride home would perfect .. fete one would assume possible charging 1600 domestic flight ... Ps deplaned',
#  'SouthwestAir Totally ruined birthday weekend Cancelled Flighting flight reason offer point drink transport nolove cali',
#  'united nope need little red stamp counter Check wreck son http //t.co/0pRGySvuRm',
#  'united referral program Milageplus explorer card',
#  "AmericanAir guy fail .. need use voucher ticket ca n't online yourphonesystemsucks",
#  "SouthwestAir look like 1 yr anni trip replaced w someone 's itinerary Worried abt c flight http //t.co/BApE6RuMNE",
#  'AmericanAir thanks finally letting get book flight Frustration set ... donedeal talktoahuman',
#  'united took one window Also fun get motion sick http //t.co/m81rV0blxs',
#  'JetBlue keep getting better water plane',
#  "JetBlue thank Hopefully 's soon supposed leave 11:23",
#  "united Thank y'all amazing airline know treat customer guy rock",
#  'SouthwestAir sent looking functionality app though one click action',
#  'AmericanAir need help record locator bringing TWO different flight system One op AA amp one US Airways',
#  "JetBlue 's okay ... 'm actually tea kinda guy anyway Thanks",
#  "united Held almost 45 minute promised free movie n't work neither wifi paid Boo",
#  "AmericanAir 's baggage handler calling DFW today luggage onboard plane",
#  'USAirways would go though entire process get people phone usairwayssucks',
#  'USAirways crazy Treated mom poorly happy usairwaysfail',
#  'SouthwestAir many left',
#  'USAirways work hard making sure thing flow smoothly Keeping positive',
#  "USAirways n't blame weather Rep counter cost entire day weather Printed Boarding Pass Late Flight TakeResponsibility",
#  'united thanks updating 1+ hour delay exact second got ATL 🙅🙅🙅',
#  "united considered `` time '' 's arriving destination half hour Late Flightr scheduled http //t.co/YMFTw1uyHr",
#  "AmericanAir rebooked n't get notified Cancelled Flightled",
#  "USAirways ShoutOut 2 Kristie sp Gate4 PVD today 's RockStar tremendous help tough situation PromoteThatGirl",
#  'united check-in luggage Employee told include wheel dimension',
#  'united 25 minute hold 1 hr 25 min ABC11_WTVD',
#  'USAirways guy screwing trip Thanks nothing lazy',
#  'united passenger waited inside flight runway returned back gate count valid journey',
#  'USAirways Frustrating day flight home changed airline Thank PHL USAirway employee amp united help getting back IAH',
#  "united u guy changed age double booked seat 've even though platinum person none",
#  'USAirways Cancelled Flightled last part ticket confused email received whether value remains someone ask',
#  'united business decision made inconvenience possibly cause lost customer good business decision Cranky',
#  'USAirways flight got Cancelled Flightled Charlotte hold hour pls pick',
#  'VirginAmerica wow blew mind',
#  'AmericanAir AA2416 time awesome flight Great job American',
#  "SouthwestAir n't realize clothes hotel suggestion",
#  'SouthwestAir got mine time wife 15th anniversary',
#  "“ SouthwestAir pancho_joe must 've heard u wrong Sweet mixtape though '' 4 record n't leave 80 's 80 's left",
#  'AmericanAir Sitting gate Flight 719 hour due Sabre backup plan place Sabre fixed',
#  "SouthwestAir favorite airline 've never issue Plus crew entertaining",
#  'USAirways made Thanks help',
#  "USAirways utterly unreliable n't schedule pilot US624 flight Seattle flight delayed usairwaysfail",
#  "southwestair TREMENDOUS job Atlanta Airport saw SW celebrate Mardi Gras Another reason 'm nut guy http //t.co/8WBzOrRn3C",
#  'united seems like one United help Lots finger pointed zero people stepping least gate Oreos',
#  'SouthwestAir 8FKQW conf Thanks reply',
#  'united rebooked 24 hour original flight say handling situation bad would understatement',
#  'AmericanAir flight leaving Dallas right Maui trying figure delayed flight 7 going',
#  'SouthwestAir One heck airline http //t.co/CyoOnZfTdC',
#  "SouthwestAir flying flight 3130 tonight 7:20 PBI- boarding position C-42 overbooked Really n't want bumped",
#  'JetBlue Clients got ZERO 32 year career never thought possible.2 suitcase worth thousand Italian clothing robbed',
#  'USAirways Cancelled Flightled flight ... paying hotel',
#  'AmericanAir response incredible Truly amazed step taken enhance customer relation Big thank 😄',
#  "AmericanAir wow Regina told ca n't file request lost bag statement finish travel get DC argg",
#  "united since international connection 9am 'm hoping thing",
#  'JetBlue day',
#  'united long take mile re-purchased expired show recieved email request ..',
#  "united probably least satisfactory airline 've ever Never fails disappoint",
#  'United Airlines Changing MileagePlus Program Winners Losers http //t.co/F1yvAiO9ul http //t.co/vGlx6Ykwqg',
#  "AmericanAir SeguineJ AA joke right line n't even accepting call right hang",
#  "united nonrefundable hence wrote 200 n't make sense 150 credit nothanks",
#  'JetBlue Even 5 year earthquake ... Haiti still need help rebuilding flyingitforward',
#  'USAirways despite mechanical issue many delay followed Cancelled Flightlation still getting Vegas thanks great gate agent',
#  'JetBlue excuse though 3 gate change though',
#  'JetBlue may need 40 minute layover 15 min delay first flight',
#  'united get reimbursed hotel taxi Cancelled Flightation',
#  'AmericanAir yet receive assistance one agent securing new connection Many miss work tomorrow',
#  'USAirways British_Airways three hour flight delay phone 45min counting',
#  'AmericanAir 2298 Everyone else outstanding',
#  'united think rough moment w/ bad passenger earlier flight Things got considerably better Thanks',
#  'USAirways thanks',
#  'AmericanAir Cancelled Flightled ticket taking two month ++ refund still waiting',
#  'USAirways ’',
#  'USAirways shout pilot FC attendant Eliz US 673 Super strong crosswind landing Eliz super job throughout',
#  'united see coming get AggieMensGolf Hawaii 12thMan http //t.co/G8DKa3Edhf',
#  'AmericanAir dfwairport 2 together best part flying',
#  'united Late Flight future flight train staff better handle emergency situation ground staff Customer Service',
#  'united oh united much despise thee',
#  'United Airlines CEO Jeff Smisek Disloyal Loyal Workers http //t.co/0cevY3P42b via HuffPostBiz',
#  'united 3/10 disappointed service missing connection hour delay cramped seat least app good',
#  'AmericanAir sit airport long periolodicly time plane nasty',
#  'united 618 flight Houston',
#  'united fuck caring 😢',
#  'SouthwestAir info DestinationDragons winner announced amp best friend hoping win thanks',
#  'SouthwestAir Thanks',
#  'SouthwestAir tweet weekend/ bad weather close customer relation center process refund Cancelled Flighted flight',
#  "SouthwestAir missing 6,000 point one account 're spread four assuming create account",
#  'united used committed ContinentalAirlines flyer merger remember switched SouthwestAir CommunicationFail',
#  'united soon done article Thanks ~Tom',
#  "AmericanAir 're finding bc united rebooked u airline realized could n't get u home 're ORD",
#  'USAirways gave http //t.co/2eDgc6TbLs',
#  'USAirways ticket couldnt used bc unable get departing dest RSW bc blizzard BOS Told way use credit 200 fine',
#  ...]

# %%
#using tfidf vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
cv=TfidfVectorizer()
X=cv.fit_transform(x_train3)

# %%
X
# Out:
# <10980x12138 sparse matrix of type '<class 'numpy.float64'>'
# 	with 110467 stored elements in Compressed Sparse Row format>

# %%
# cv.get_feature_names()

# %%
testing_data=pd.read_csv('0000000000002747_test_twitter_x_test.csv')

# %%
testing_data.head(2)
# Out:
#        tweet_id   airline airline_sentiment_gold      name  \
# 0  5.696820e+17  American                    NaN  zsalim03
# 1  5.696080e+17  American                    NaN  sa_craig
#
#   negativereason_gold  retweet_count  \
# 0                 NaN              0
# 1                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @AmericanAir In car gng to DFW. Pulled over 1h...         NaN
# 1  @AmericanAir after all, the plane didn’t land ...         NaN
#
#      tweet_created       tweet_location               user_timezone
# 0  2/22/2015 18:15                Texas  Central Time (US & Canada)
# 1  2/22/2015 13:22  College Station, TX  Central Time (US & Canada)

# %%
testing_data.drop(columns=['retweet_count','tweet_coord','negativereason_gold','airline_sentiment_gold'],axis=1)
# Out:
#           tweet_id         airline             name  \
# 0     5.696820e+17        American         zsalim03
# 1     5.696080e+17        American         sa_craig
# 2     5.678790e+17       Southwest     DanaChristos
# 3     5.697580e+17      US Airways         rossj987
# 4     5.699010e+17        American       tranpham18
# ...            ...             ...              ...
# 3655  5.703040e+17      US Airways   Anthony_Scerri
# 3656  5.678480e+17      US Airways         mttdprkr
# 3657  5.678240e+17  Virgin America      miaerolinea
# 3658  5.702740e+17        American  GoldensPleasure
# 3659  5.693420e+17          United         suntoshi
#
#                                                    text    tweet_created  \
# 0     @AmericanAir In car gng to DFW. Pulled over 1h...  2/22/2015 18:15
# 1     @AmericanAir after all, the plane didn’t land ...  2/22/2015 13:22
# 2     @SouthwestAir can't believe how many paying cu...  2/17/2015 18:52
# 3     @USAirways I can legitimately say that I would...  2/22/2015 23:16
# 4     @AmericanAir still no response from AA. great ...   2/23/2015 8:44
# ...                                                 ...              ...
# 3655  @USAirways Been stuck for 40+ minutes due to l...  2/24/2015 11:28
# 3656  @USAirways 4 hours... 4 hours... FOUR HOURS.  ...  2/17/2015 16:47
# 3657  Nice RT @VirginAmerica: The man of steel might...  2/17/2015 15:11
# 3658  @AmericanAir Aww Thanks AA..DFW was on GMA up ...   2/24/2015 9:27
# 3659  @united the lounge tells us they have no pillo...  2/21/2015 19:43
#
#            tweet_location               user_timezone
# 0                   Texas  Central Time (US & Canada)
# 1     College Station, TX  Central Time (US & Canada)
# 2                      CT  Eastern Time (US & Canada)
# 3        Washington, D.C.  Eastern Time (US & Canada)
# 4           New York City  Eastern Time (US & Canada)
# ...                   ...                         ...
# 3655          Astoria, NY                       Quito
# 3656        Vancouver, WA  Pacific Time (US & Canada)
# 3657            Worldwide                     Caracas
# 3658   East Coast     CT.  Central Time (US & Canada)
# 3659          Bedford, Nh  Eastern Time (US & Canada)
#
# [3660 rows x 7 columns]

# %%
# y_test=list(testing_data['airline_sentiment'])
x_test=list(testing_data['text'])
document_test=[word_tokenize(doc) for doc in x_test]
x_test2=[clean_review(doc) for doc in document_test]

# %%
x_test3=[' '.join(doc) for doc in x_test2]

# %%
X_test=cv.transform(x_test3)

# %%
X_test
# Out:
# <3660x12138 sparse matrix of type '<class 'numpy.float64'>'
# 	with 34483 stored elements in Compressed Sparse Row format>

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(random_state=0)
clf.fit(X,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred=clf.predict(X_test)

# %%
y_pred
# Out:
# array(['negative', 'negative', 'negative', ..., 'neutral', 'positive',
#        'negative'], dtype='<U8')

# %%
arr=list(y_pred)

# %%
import numpy as np
np.savetxt("predictions.csv", y_pred,fmt = '%s')
